# %%
4+6
# Out:
# 10

# %%
6/2
# Out:
# 3.0

# %%
10/3
# Out:
# 3.3333333333333335

# %%
4-1
# Out:
# 3

# %%
4 * 9
# Out:
# 36

# %%
type(4)
# Out:
# int

# %%
8 // 3
# Out:
# 2

# %%
7 ** 2
# Out:
# 49

# %%
7 ^ 2
# Out:
# 5

# %%
round(42.4)
# Out:
# 42

# %%
5 + round(42.4)
# Out:
# 47

# %%
5 + abs(42.4)
# Out:
# 47.4

# %%
5 + abs(-42.4)
# Out:
# 47.4

# %%
abs  (42)
# Out:
# 42

# %%
5 + 42
# Out:
# 47

# %% [raw]
# abs

# %% [raw]
# "George"

# %% [raw]
# "5" + "42"

# %% [raw]
# "5" / "42"

# %% [raw]
# 5 + "42"

# %%
"George," * 5
# Out:
# 'George,George,George,George,George,'

# %%
len("George")
# Out:
# 6

# %%
'George'
# Out:
# 'George'

# %%
"George'
# Out:
#   Cell In[34], line 1
#     "George'
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"George's"
# Out:
# "George's"

# %%
'George said "Let us start class"'
# Out:
# 'George said "Let us start class"'

# %%
type('George said "Let us start class"')
# Out:
# str

# %%
type(5.0)
# Out:
# float
