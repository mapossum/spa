# %%
n = 17
print(n)
# Out:
# 17

# %%
pi = 3.141592653589793

# %%
pi
# Out:
# 3.141592653589793

# %%
n
# Out:
# 17

# %%
message = 'And now for something completely different. '

# %%
repeatmessage = message * n

# %%
repeatmessage
# Out:
# 'And now for something completely different. And now for something completely different. And now for something completely different. And now for something completely different. And now for something completely different. And now for something completely different. And now for something completely different. And now for something completely different. And now for something completely different. And now for something completely different. And now for something completely different. And now for something completely different. And now for something completely different. And now for something completely different. And now for something completely different. And now for something completely different. And now for something completely different. '

# %%
2 * pi
# Out:
# 6.283185307179586

# %%
radius = 3.7
area = 2 * pi * radius
print(area)
# Out:
# 23.24778563656447

# %%
1n = 17
# Out:
#   Cell In[54], line 1
#     1n = 17
#     ^
# SyntaxError: invalid decimal literal

# %%
n! = 17
# Out:
#   Cell In[55], line 1
#     n! = 17
#      ^
# SyntaxError: invalid syntax

# %%
n@ = 17
# Out:
#   Cell In[56], line 1
#     n@ = 17
#        ^
# SyntaxError: invalid syntax

# %%
None = 0
# Out:
#   Cell In[57], line 1
#     None = 0
#     ^
# SyntaxError: cannot assign to None

# %%
or = 7
# Out:
#   Cell In[58], line 1
#     or = 7
#     ^
# SyntaxError: invalid syntax

# %%
def circlearea(radius):
    area = 2 * pi * radius
    return area
    
r = -45
circlearea(r)
# Out:
# -282.7433388230814

# %%
circlearea = 60

# %%
circlearea(r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 circlearea(r)
#
# TypeError: 'int' object is not callable

# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
25 ** 0.5
# Out:
# 5.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
print(math.sqrt(25) * math.pi * 2)
# Out:
# 31.41592653589793

# %%
print("The value of a circle with a radius that is equal to the square root of 25 is:", math.sqrt(25) * math.pi * 2)
# Out:
# The value of a circle with a radius that is equal to the square root of 25 is: 31.41592653589793

# %%
math.sqrt("Five")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 math.sqrt("Five")
#
# TypeError: must be real number, not str

# %%
math.pow(5, 2)
# Out:
# 25.0

# %%
math.pow
# Out:
# <function math.pow(x, y, /)>

# %%
#the next line is something I am still working on
thing1 = 9
print(thing1)    # This prints the value of thing1
# Out:
# 9

# %%
mlinetext = ''' Hello
Does this work?
I don't know"
'''

print("finished")
# Out:
# finished

# %%
mlinetext
# Out:
# ' Hello\nDoes this work?\nI don\'t know"\n'

# %%
x = 1
y = 5 
print(y / x)
name = 'George
print(u)
# Out:
#   Cell In[87], line 4
#     name = 'George
#            ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
circlearea = 3 * math.pi * radius

# %%
circlearea
# Out:
# 34.8716784548467
