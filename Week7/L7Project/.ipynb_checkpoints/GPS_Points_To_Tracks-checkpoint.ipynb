# %%
import arcpy

# A list of features and coordinate pairs
feature_info = [[[1, 2], [2, 4], [3, 7]],
                [[6, 8], [5, 7], [7, 2], [9, 5]]]

# A list that will hold each of the Polyline objects
features = []

for feature in feature_info:
    # Create a Polyline object based on the array of points
    # Append to the list of Polyline objects
    features.append(
        arcpy.Polyline(
            arcpy.Array([arcpy.Point(*coords) for coords in feature])))

# Persist a copy of the Polyline objects using CopyFeatures
arcpy.CopyFeatures_management(features, r"C:\courses\spa\Week7\animaldata\data\polylinesTest.shp")
# Out:
# <Result 'C:\\courses\\spa\\Week7\\animaldata\\data\\polylinesTest.shp'>

# %%
#This one works
import arcpy, os

infc = r"C:\courses\spa\Week7\animaldata\data\GPS_points.shp"
infc2 = r"C:\courses\spa\Week7\animaldata\data\GPS_Tracks4.shp"

outputpathinfo = os.path.split(infc2)
print(outputpathinfo)

arcpy.env.overwriteOutput = True
#Create Empty feature Class to hold the line tracks
arcpy.CreateFeatureclass_management(outputpathinfo[0], outputpathinfo[1], "POLYLINE", infc, "#", "#", infc)

#read (open a search cursor) for the input points and loop through each point
cursor = arcpy.da.InsertCursor(infc2, ['SHAPE@', "Animal"])

panimal = -1
coords = []
for row in arcpy.da.SearchCursor(infc, ["SHAPE@XY", "Time", "Animal"], sql_clause=(None, "ORDER BY ANIMAL TIME DESC")):
    print(row[0], row[1], row[2])
    geom = row[0]

    if row[2] != panimal:
        print("create a new line for the next animal track AND write existing animal track to file")
        print(coords)
        if panimal != -1:
            outputGeom = arcpy.Polyline(arcpy.Array(coords))
            cursor.insertRow((outputGeom, panimal))
            coords = []
        
    coords.append(arcpy.Point(geom[0],geom[1]))
    print("add current point to animal (line track) we are currectly working on") 

    panimal = row[2]

#write (using a insert cursor) a line out into the new feature class everytime we encounter a new animal in the data.
outputGeom = arcpy.Polyline(arcpy.Array(coords))
cursor.insertRow((outputGeom, panimal))

#clean up (del cursors)

del cursor
# Out:
# ('C:\\courses\\spa\\Week7\\animaldata\\data', 'GPS_Tracks4.shp')
# (538615.7508954942, 1170796.9871083638) 1 1
# create a new line for the next animal track AND write existing animal track to file
# []
# add current point to animal (line track) we are currectly working on
# (538495.1993566469, 1170796.9871083638) 2 1
# add current point to animal (line track) we are currectly working on
# (538495.1993566469, 1170622.1873770352) 3 1
# add current point to animal (line track) we are currectly working on
# (538615.7508954942, 1170619.173588564) 4 1
# add current point to animal (line track) we are currectly working on
# (538612.737107023, 1170697.5320888148) 5 1
# add current point to animal (line track) we are currectly working on
# (538549.4475491282, 1170703.559665757) 6 1
# add current point to animal (line track) we are currectly working on
# (538742.3300112841, 1170800.000896835) 7 3
# create a new line for the next animal track AND write existing animal track to file
# [<Point (538615.7508954942, 1170796.9871083638, #, #)>, <Point (538495.1993566469, 1170796.9871083638, #, #)>, <Point (538495.1993566469, 1170622.1873770352, #, #)>, <Point (538615.7508954942, 1170619.173588564, #, #)>, <Point (538612.737107023, 1170697.5320888148, #, #)>, <Point (538549.4475491282, 1170703.559665757, #, #)>]
# add current point to animal (line track) we are currectly working on
# (538883.9780694298, 1170800.000896835) 8 3
# add current point to animal (line track) we are currectly working on
# (538817.6747230637, 1170800.000896835) 9 3
# add current point to animal (line track) we are currectly working on
# (538814.6609345925, 1170607.1184346792) 10 3
# add current point to animal (line track) we are currectly working on
# (538730.2748573993, 1170607.1184346792) 11 3
# add current point to animal (line track) we are currectly working on
# (538883.9780694298, 1170610.1322231502) 12 3
# add current point to animal (line track) we are currectly working on
# (539128.0949355958, 1170796.9871083638) 13 2
# create a new line for the next animal track AND write existing animal track to file
# [<Point (538742.3300112841, 1170800.000896835, #, #)>, <Point (538883.9780694298, 1170800.000896835, #, #)>, <Point (538817.6747230637, 1170800.000896835, #, #)>, <Point (538814.6609345925, 1170607.1184346792, #, #)>, <Point (538730.2748573993, 1170607.1184346792, #, #)>, <Point (538883.9780694298, 1170610.1322231502, #, #)>]
# add current point to animal (line track) we are currectly working on
# (538965.3503581517, 1170803.0146853062) 14 2
# add current point to animal (line track) we are currectly working on
# (538965.3503581517, 1170691.5045118723) 15 2
# add current point to animal (line track) we are currectly working on
# (539122.0673586534, 1170685.4769349298) 16 2
# add current point to animal (line track) we are currectly working on
# (539116.0397817111, 1170592.0494923233) 17 2
# add current point to animal (line track) we are currectly working on
# (538962.3365696806, 1170601.0908577368) 18 2
# add current point to animal (line track) we are currectly working on
# (538486.1579912333, 1170483.5531073606) 19 5
# create a new line for the next animal track AND write existing animal track to file
# [<Point (539128.0949355958, 1170796.9871083638, #, #)>, <Point (538965.3503581517, 1170803.0146853062, #, #)>, <Point (538965.3503581517, 1170691.5045118723, #, #)>, <Point (539122.0673586534, 1170685.4769349298, #, #)>, <Point (539116.0397817111, 1170592.0494923233, #, #)>, <Point (538962.3365696806, 1170601.0908577368, #, #)>]
# add current point to animal (line track) we are currectly working on
# (538627.806049379, 1170477.5255304181) 20 5
# add current point to animal (line track) we are currectly working on
# (538558.4889145418, 1170483.5531073606) 21 5
# add current point to animal (line track) we are currectly working on
# (538552.4613375993, 1170281.6292797911) 22 5
# add current point to animal (line track) we are currectly working on
# (538624.7922609078, 1170281.6292797911) 23 5
# add current point to animal (line track) we are currectly working on
# (538468.0752604061, 1170278.61549132) 24 5
# add current point to animal (line track) we are currectly working on
# (538841.7850308332, 1170465.4703765335) 25 4
# create a new line for the next animal track AND write existing animal track to file
# [<Point (538486.1579912333, 1170483.5531073606, #, #)>, <Point (538627.806049379, 1170477.5255304181, #, #)>, <Point (538558.4889145418, 1170483.5531073606, #, #)>, <Point (538552.4613375993, 1170281.6292797911, #, #)>, <Point (538624.7922609078, 1170281.6292797911, #, #)>, <Point (538468.0752604061, 1170278.61549132, #, #)>]
# add current point to animal (line track) we are currectly working on
# (538709.178338101, 1170471.4979534757) 26 4
# add current point to animal (line track) we are currectly working on
# (538700.1369726874, 1170366.0153569842) 27 4
# add current point to animal (line track) we are currectly working on
# (538838.771242362, 1170353.9602030995) 28 4
# add current point to animal (line track) we are currectly working on
# (538832.7436654196, 1170266.5603374352) 29 4
# add current point to animal (line track) we are currectly working on
# (538703.1507611587, 1170275.6017028487) 30 4
# add current point to animal (line track) we are currectly working on
# (538633.8336263214, 1170179.160471771) 31 6
# create a new line for the next animal track AND write existing animal track to file
# [<Point (538841.7850308332, 1170465.4703765335, #, #)>, <Point (538709.178338101, 1170471.4979534757, #, #)>, <Point (538700.1369726874, 1170366.0153569842, #, #)>, <Point (538838.771242362, 1170353.9602030995, #, #)>, <Point (538832.7436654196, 1170266.5603374352, #, #)>, <Point (538703.1507611587, 1170275.6017028487, #, #)>]
# add current point to animal (line track) we are currectly working on
# (538456.0201065214, 1170185.1880487131) 32 6
# add current point to animal (line track) we are currectly working on
# (538446.9787411079, 1169910.9332978353) 33 6
# add current point to animal (line track) we are currectly working on
# (538449.9925295791, 1170049.5675675098) 34 6
# add current point to animal (line track) we are currectly working on
# (538576.5716453688, 1170046.5537790386) 35 6
# add current point to animal (line track) we are currectly working on
# (538736.3024343416, 1170173.1328948284) 36 9
# create a new line for the next animal track AND write existing animal track to file
# [<Point (538633.8336263214, 1170179.160471771, #, #)>, <Point (538456.0201065214, 1170185.1880487131, #, #)>, <Point (538446.9787411079, 1169910.9332978353, #, #)>, <Point (538449.9925295791, 1170049.5675675098, #, #)>, <Point (538576.5716453688, 1170046.5537790386, #, #)>]
# add current point to animal (line track) we are currectly working on
# (538736.3024343416, 1169898.8781439506) 37 9
# add current point to animal (line track) we are currectly working on
# (538911.1021656704, 1169901.8919324218) 38 9
# add current point to animal (line track) we are currectly working on
# (538905.074588728, 1170173.1328948284) 39 9
# add current point to animal (line track) we are currectly working on
# (538998.5020313348, 1169889.836778537) 40 8
# create a new line for the next animal track AND write existing animal track to file
# [<Point (538736.3024343416, 1170173.1328948284, #, #)>, <Point (538736.3024343416, 1169898.8781439506, #, #)>, <Point (538911.1021656704, 1169901.8919324218, #, #)>, <Point (538905.074588728, 1170173.1328948284, #, #)>]
# add current point to animal (line track) we are currectly working on
# (539007.5433967484, 1170170.1191063572) 41 8
# add current point to animal (line track) we are currectly working on
# (539164.26039725, 1169898.8781439506) 42 8
# add current point to animal (line track) we are currectly working on
# (539158.2328203076, 1170173.1328948284) 43 8
# add current point to animal (line track) we are currectly working on

# %%
#This one got updated wrong does not work

import arcpy

infc = r"C:\temp\spa\data\GPS_points.shp"
infc2 = r"C:\temp\spa\data\GPS_Tracks.shp"

def writeAnimal(pointList, animalnum):
    array = arcpy.Array(pointList)
    polyline = arcpy.Polyline(array)
    cursor.insertRow([polyline, animalnum]) 
    

arcpy.env.overwriteOutput = True
arcpy.CreateFeatureclass_management(r"C:\temp\spa\data", "GPS_Tracks.shp", "POLYLINE", infc, "#", "#", infc)

cursor = arcpy.da.InsertCursor(infc2, ['SHAPE@', "Animal"])

panimal = -1
pointList = []
# Enter for loop for each feature
for row in arcpy.da.SearchCursor(infc, ["SHAPE@XY", "Time", "Animal"], sql_clause=(None, "ORDER BY ANIMAL TIME DESC")):
    geom = row[0]
    animal = row[2]
    print(geom, row[1], row[2], panimal)
    if (animal != panimal) and (panimal != -1):
        print("Write out all points so far to another animal")
        print(pointList)
        writeAnimal(pointList, panimal)
        pointList = []
    pointList.append(arcpy.Point(geom[0],geom[1]))
    panimal = animal
    
writeAnimal(pointList, row[2])   

del cursor
# Out:
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# Cell In[27], line 13
#       9     cursor.insertRow([polyline, animalnum])
#      12 arcpy.env.overwriteOutput = True
# ---> 13 arcpy.CreateFeatureclass_management(r"C:\temp\spa\data", "GPS_Tracks.shp", "POLYLINE", infc, "#", "#", infc)
#      15 cursor = arcpy.da.InsertCursor(infc2, ['SHAPE@', "Animal"])
#      17 panimal = -1
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py:5659, in CreateFeatureclass(out_path, out_name, geometry_type, template, has_m, has_z, spatial_reference, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3, out_alias, oid_type)
#    5657     return retval
#    5658 except Exception as e:
# -> 5659     raise e
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py:5636, in CreateFeatureclass(out_path, out_name, geometry_type, template, has_m, has_z, spatial_reference, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3, out_alias, oid_type)
#    5632 from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    5634 try:
#    5635     retval = convertArcObjectToPythonObject(
# -> 5636         gp.CreateFeatureclass_management(
#    5637             *gp_fixargs(
#    5638                 (
#    5639                     out_path,
#    5640                     out_name,
#    5641                     geometry_type,
#    5642                     template,
#    5643                     has_m,
#    5644                     has_z,
#    5645                     spatial_reference,
#    5646                     config_keyword,
#    5647                     spatial_grid_1,
#    5648                     spatial_grid_2,
#    5649                     spatial_grid_3,
#    5650                     out_alias,
#    5651                     oid_type,
#    5652                 ),
#    5653                 True,
#    5654             )
#    5655         )
#    5656     )
#    5657     return retval
#    5658 except Exception as e:
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py:532, in Geoprocessor.__getattr__.<locals>.<lambda>(*args)
#     530 val = getattr(self._gp, attr)
#     531 if callable(val):
# --> 532     return lambda *args: val(*gp_fixargs(args, True))
#     533 else:
#     534     return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000622: Failed to execute (Create Feature Class). Parameters are not valid.
# ERROR 000628: Cannot set input into parameter spatial_reference.
