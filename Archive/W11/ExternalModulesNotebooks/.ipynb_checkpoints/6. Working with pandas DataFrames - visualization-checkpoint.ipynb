# %% [markdown]
# ---
# <center><h1>Lesson 2 - Basic intro into pandas</h1></center>
# ---
# ---
#
# <center><h2>Part 7. Work with pandas DataFrames: visualization</h2></center>
# ---

# %% [markdown]
# ## Table of Contents
#
# - [Work with pandas DataFrames: visualization](#Work-with-pandas-DataFrames:-visualization)
#     * [Basic Plotting: plot](#Basic-Plotting:-plot)
#     * [Other Plots](#Other-Plots)
#     * [Bar plots](#Bar-plots)
#     * [Histograms](#Histograms)
#     * [Box Plots](#Box-Plots)
#     * [Area Plot](#Area-Plot)
#     * [Scatter Plot](#Scatter-Plot)
#     * [Hexagonal Bin Plot](#Hexagonal-Bin-Plot)
#     * [Pie plot](#Pie-plot)

# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# ## Work with pandas DataFrames: visualization
#
# [[back to top]](#Table-of-Contents)
#
# A primary goal of data visualization is to communicate information clearly and efficiently to users via the statistical graphics, plots, information graphics, tables, and charts selected. Effective visualization helps users in analyzing and reasoning about data and evidence. It makes complex data more accessible, understandable and usable. Users may have particular analytical tasks, such as making comparisons or understanding causality, and the design principle of the graphic (i.e., showing comparisons or showing causality) follows the task. Tables are generally used where users will look-up a specific measure of a variable, while charts of various types are used to show patterns or relationships in the data for one or more variables.

# %% [markdown]
# We use the standard convention for referencing the matplotlib API:

# %%
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# By default plot has fixed size 6 x 5
# But we can change width/height values
plt.rcParams["figure.figsize"] = (18.0, 6.0)

# %%
from arcgis.features import GeoAccessor, GeoSeriesAccessor
#Import a COVID data layer.  This layer contains the updated stats for each county in the United States
from arcgis.features import FeatureLayer
mylayer = FeatureLayer(("https://services9.arcgis.com/RHVPKKiFTONKtxq3/arcgis/rest/services/NOAA_METAR_current_wind_speed_direction_v1/FeatureServer/0"))
sdf2 = pd.DataFrame.spatial.from_layer(mylayer)
sdfUSA = sdf2.loc[sdf2["COUNTRY"].apply(lambda x: "United States Of America" in str(x))]
sdfUSA["State"] = sdfUSA['COUNTRY'].apply(lambda x: str(x).split(",")[0])
sdfUSA["COUNTRY"] = sdfUSA['COUNTRY'].apply(lambda x: str(x).split(",")[1])
sdfUSA
# Out:
# C:/Users/georg/AppData/Local/Temp/ArcGISProTemp21560/xpython_21560/4053346233.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdfUSA["State"] = sdfUSA['COUNTRY'].apply(lambda x: str(x).split(",")[0])
# C:/Users/georg/AppData/Local/Temp/ArcGISProTemp21560/xpython_21560/4053346233.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdfUSA["COUNTRY"] = sdfUSA['COUNTRY'].apply(lambda x: str(x).split(",")[1])
#       OBJECTID  ICAO        OBS_DATETIME      STATION_NAME  \
# 5956      6060  PAEC 2024-01-16 16:51:00          Chulitna
# 5957      3767  PAHP 2022-09-17 01:32:00        Hooper Bay
# 5958      5937  PALR 2023-06-27 00:50:00    Chandalar Lake
# 5959      4180  PAWI 2024-04-29 23:53:00        Wainwright
# 6070      4922  KCQT 2024-05-20 14:47:00       Los Angeles
# 6071       517  KL52 2023-04-09 16:55:00       Oceano Cnty
# 6088      6002  KQBL 2024-06-14 22:55:00          Hurlbert
# 6089      6003  KQHY 2024-06-14 22:55:00          Hurlbert
# 6098      1027  K2J3 2023-11-10 06:10:00        Louisville
# 6099      1014  K3J7 2023-05-03 14:30:00        Greensboro
# 6100      2936  KHME 2023-02-26 13:50:00            Metter
# 6106      5970  PHHN 2023-09-15 03:58:00              Hana
# 6107      5889  PHJH 2023-01-27 04:05:00  Lahaina/West Mau
# 6108      5971  PHMU 2023-09-15 04:00:00    Kamuela/Waimea
# 6109      5840  KNBU 2022-12-13 08:00:00      Glenview Nas
# 6113      5965  KDMX 2023-08-24 17:00:00  Johnston/Desmoin
# 6120      1045  K1K1 2022-12-29 06:10:00            Benton
# 6121       985  K5M9 2022-11-09 15:35:00            Marion
# 6125       107  K7N0 2023-01-26 18:56:00  New Orleans/Supe
# 6126       498  KLNQ 2023-08-25 13:46:00    Boothville Hel
# 6127       150  KVKY 2023-07-03 14:50:00    Main Pass 289C
# 6130      6104  KP61 2024-05-24 06:52:00     Tofte (Ramos)
# 6131      5832  KDLP 2024-02-10 23:05:00    West Delta 27A
# 6132      5683  K1S3 2024-04-30 20:15:00           Forsyth
# 6133      1618  KS59 2024-06-11 22:45:00             Libby
# 6140      5691  KMHN 2022-08-31 01:58:00            Mullen
# 6142      5977  KN12 2023-10-09 15:55:00          Lakewood
# 6143      3856  KMSV 2024-03-05 18:38:00        Monticello
# 6162       585  KI19 2023-11-29 23:55:00    Dayton-Jackson
# 6163       631  KH71 2023-04-14 15:35:00             Pryor
# 6195      4754  KGDP 2023-12-11 00:51:00    Guadalupe Pass
# 6196      2260  KLZZ 2024-04-03 14:35:00          Lampasas
# 6207       175  KU55 2023-08-20 09:55:00         Panguitch
# 6214      1015  K3I2 2022-12-28 09:30:00       Pt Pleasant
#
#                         COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
# 5956   United States Of America      389.0  30.2       32.0         108
# 5957   United States Of America        8.0  51.8       46.4          82
# 5958   United States Of America      579.0  59.0       50.0          72
# 5959   United States Of America       12.0  12.9       10.0          88
# 6070   United States Of America       51.0  60.1       52.0          75
# 6071   United States Of America        3.0  55.4       55.4         100
# 6088   United States Of America     9999.0  86.0       75.7          72
# 6089   United States Of America     9999.0  86.4       76.6          73
# 6098   United States Of America       97.0  57.2       56.7          98
# 6099   United States Of America      207.0  60.8       33.8          36
# 6100   United States Of America       60.0  60.8       35.6          39
# 6106   United States Of America       20.0  75.2       73.4          94
# 6107   United States Of America       67.0  <NA>       <NA>        <NA>
# 6108   United States Of America      809.0  66.2       64.4          94
# 6109   United States Of America       <NA>  48.9       35.1          59
# 6113   United States Of America      299.0  <NA>       <NA>        <NA>
# 6120   United States Of America      411.0  46.9       29.7          51
# 6121   United States Of America      199.0  68.2       37.6          32
# 6125   United States Of America        0.0  52.0       36.0          54
# 6126   United States Of America        1.0 -35.7       <NA>        <NA>
# 6127   United States Of America       32.0  <NA>       <NA>        <NA>
# 6130   United States Of America      241.0  43.0       41.0          93
# 6131   United States Of America       31.0  <NA>       <NA>        <NA>
# 6132   United States Of America      831.0  53.6       17.6          24
# 6133   United States Of America      793.0  80.6       80.6         100
# 6140   United States Of America       <NA>  78.4       53.4          42
# 6142   United States Of America       13.0  68.5       38.5          33
# 6143   United States Of America      427.0  42.8       41.0          93
# 6162   United States Of America      285.0  35.6       26.6          69
# 6163   United States Of America      190.0  71.6       53.6          53
# 6195   United States Of America     1664.0  41.0        8.1          25
# 6196   United States Of America      356.0  60.3       37.9          43
# 6207   United States Of America     2060.0  57.2       55.4          94
# 6214   United States Of America      195.0  18.9       16.7          91
#
#       WIND_DIRECT  ...  PRESSURE  \
# 5956           40  ...    1013.2
# 5957          180  ...     979.0
# 5958           70  ...    1008.1
# 5959           90  ...    1027.1
# 6070            0  ...    1016.3
# 6071          250  ...    1020.3
# 6088         <NA>  ...    1012.5
# 6089          220  ...    1012.2
# 6098            0  ...    1017.3
# 6099          270  ...    1009.8
# 6100          270  ...    1023.9
# 6106            0  ...    1015.9
# 6107           20  ...    1016.2
# 6108           40  ...    1017.3
# 6109          360  ...    1023.4
# 6113         <NA>  ...      <NA>
# 6120          240  ...    1002.4
# 6121            0  ...    1027.1
# 6125            0  ...    1026.7
# 6126           70  ...    1016.2
# 6127          240  ...    1017.3
# 6130            0  ...    1017.6
# 6131          180  ...    1008.8
# 6132          280  ...    1009.5
# 6133          200  ...    1008.8
# 6140           30  ...    1023.0
# 6142          360  ...    1023.0
# 6143           90  ...    1019.0
# 6162          210  ...    1016.3
# 6163          170  ...    1006.8
# 6195          230  ...    1022.7
# 6196          300  ...    1016.9
# 6207            0  ...    1024.7
# 6214            0  ...    1023.4
#
#                                              SKY_CONDTN  \
# 5956             Overcast Cloud Deck at 1300 meters AGL
# 5957              Overcast Cloud Deck at 730 meters AGL
# 5958  Broken Clouds at 1800 meters AGL, Overcast Clo...
# 5959                  Scattered Clouds at 60 meters AGL
# 6070              Overcast Cloud Deck at 760 meters AGL
# 6071                                               <NA>
# 6088                      Few Clouds at 2700 meters AGL
# 6089                      Few Clouds at 2900 meters AGL
# 6098                    Sky Clear below 3700 meters AGL
# 6099                    Sky Clear below 3700 meters AGL
# 6100                Scattered Clouds at 1100 meters AGL
# 6106             Overcast Cloud Deck at 1300 meters AGL
# 6107  Scattered Clouds at 430 meters AGL, Scattered ...
# 6108  Scattered Clouds at 210 meters AGL, Broken Clo...
# 6109             Overcast Cloud Deck at 1200 meters AGL
# 6113                                               <NA>
# 6120                    Sky Clear below 3700 meters AGL
# 6121                    Sky Clear below 3700 meters AGL
# 6125                    Sky Clear below 3700 meters AGL
# 6126                                               <NA>
# 6127                    Sky Clear below 3700 meters AGL
# 6130                                               <NA>
# 6131                    Sky Clear below 3700 meters AGL
# 6132                                               <NA>
# 6133                                               <NA>
# 6140                   Broken Clouds at 4300 meters AGL
# 6142                      Few Clouds at 3700 meters AGL
# 6143              Overcast Cloud Deck at 120 meters AGL
# 6162                    Sky Clear below 3700 meters AGL
# 6163                    Sky Clear below 3700 meters AGL
# 6195                                               <NA>
# 6196                    Sky Clear below 3700 meters AGL
# 6207  Few Clouds at 1700 meters AGL, Few Clouds at 2...
# 6214                    Sky Clear below 3700 meters AGL
#
#                                                 WEATHER  \
# 5956       No significant weather present at this time.
# 5957                                         Light Rain
# 5958       No significant weather present at this time.
# 5959  Automated observation with no human augmentati...
# 6070  Automated observation with no human augmentati...
# 6071  Automated observation with no human augmentati...
# 6088  Automated observation with no human augmentati...
# 6089  Automated observation with no human augmentati...
# 6098  Automated observation with no human augmentati...
# 6099  Automated observation with no human augmentati...
# 6100       No significant weather present at this time.
# 6106  Automated observation with no human augmentati...
# 6107                          Light Drizzle, Sand Storm
# 6108  Automated observation with no human augmentati...
# 6109  Automated observation with no human augmentati...
# 6113       No significant weather present at this time.
# 6120  Automated observation with no human augmentati...
# 6121  Automated observation with no human augmentati...
# 6125  Automated observation with no human augmentati...
# 6126  Automated observation with no human augmentati...
# 6127  Automated observation with no human augmentati...
# 6130  Automated observation with no human augmentati...
# 6131  Automated observation with no human augmentati...
# 6132  Automated observation with no human augmentati...
# 6133  Automated observation with no human augmentati...
# 6140       No significant weather present at this time.
# 6142       No significant weather present at this time.
# 6143                                   Light Rain, Mist
# 6162  Automated observation with no human augmentati...
# 6163  Automated observation with no human augmentati...
# 6195  Automated observation with no human augmentati...
# 6196  Automated observation with no human augmentati...
# 6207  Automated observation with no human augmentati...
# 6214  Automated observation with no human augmentati...
#
#                                                 REMARKS  HEAT_INDEX  LATITUDE  \
# 5956                                               <NA>        <NA>    62.886
# 5957  * Maintenance REQUIRED - readings may be compr...        <NA>     61.52
# 5958                                               <NA>        <NA>      67.5
# 5959  * Maintenance REQUIRED - readings may be compr...        <NA>    70.637
# 6070                 3-Hour Pressure Increasing: 0.1 mb        <NA>    34.024
# 6071                                               <NA>        <NA>      35.1
# 6088                                               <NA>        96.0      30.4
# 6089  * Maintenance REQUIRED - readings may be compr...        97.4      30.4
# 6098                                               <NA>        <NA>    32.986
# 6099                                               <NA>        <NA>      33.6
# 6100                                               <NA>        <NA>     32.37
# 6106                                               <NA>        <NA>      20.8
# 6107                                               <NA>        <NA>     20.97
# 6108                                               <NA>        <NA>      20.0
# 6109                                               <NA>        <NA>  42.08333
# 6113                                               <NA>        <NA>     41.73
# 6120                                               <NA>        <NA>     37.77
# 6121                                               <NA>        <NA>     37.33
# 6125  * Maintenance REQUIRED - readings may be compr...        <NA>     29.95
# 6126                                               <NA>        <NA>     29.35
# 6127                                               <NA>        <NA>     29.25
# 6130  * Maintenance REQUIRED - readings may be compr...        <NA>     47.58
# 6131                                               <NA>        <NA>    29.121
# 6132                                               <NA>        <NA>   46.2695
# 6133                                               <NA>        91.2   48.2834
# 6140  * Maintenance REQUIRED - readings may be compr...        78.9     42.05
# 6142                                               <NA>        <NA>     40.07
# 6143                                               <NA>        <NA>   41.7056
# 6162                                               <NA>        <NA>   39.6935
# 6163                                               <NA>        76.1     36.22
# 6195  * Maintenance REQUIRED - readings may be compr...        <NA>   31.8327
# 6196                                               <NA>        <NA>   31.1059
# 6207                                               <NA>        <NA>     37.85
# 6214                                               <NA>        <NA>     38.92
#
#      LONGITUDE FLT_CATEGORY  \
# 5956  -149.583          VFR
# 5957   -166.15          IFR
# 5958   -148.48          VFR
# 5959  -160.013          VFR
# 6070  -118.291         MVFR
# 6071   -120.62         <NA>
# 6088    -86.65          VFR
# 6089    -86.65          VFR
# 6098  -82.3827          VFR
# 6099    -83.13          VFR
# 6100    -82.07          VFR
# 6106   -156.02         <NA>
# 6107   -156.67         <NA>
# 6108   -155.67          VFR
# 6109 -87.81667          VFR
# 6113    -93.72         <NA>
# 6120    -97.12          VFR
# 6121    -88.12          VFR
# 6125    -90.07          VFR
# 6126    -89.43         <NA>
# 6127    -88.43          VFR
# 6130    -90.83         <NA>
# 6131   -89.547          VFR
# 6132   -106.62          VFR
# 6133  -115.492          IFR
# 6140 -101.0667          VFR
# 6142    -74.18          VFR
# 6143  -74.8004         LIFR
# 6162  -83.9896          VFR
# 6163    -95.33          VFR
# 6195  -104.809          VFR
# 6196  -98.1975          VFR
# 6207   -112.38          VFR
# 6214     -82.1          VFR
#
#                                                   SHAPE          State
# 5956  {"x": -16651503.3913, "y": 9072352.268600002, ...         Alaska
# 5957  {"x": -18495733.3953, "y": 8746212.867399998, ...         Alaska
# 5958  {"x": -16528717.993, "y": 10299995.503399998, ...         Alaska
# 5959  {"x": -17812565.6803, "y": 11279281.076499999,...         Alaska
# 6070  {"x": -13168093.885400001, "y": 4032025.095200...     California
# 6071  {"x": -13427356.9795, "y": 4177479.0622000024,...     California
# 6088  {"x": -9645833.8772, "y": 3555070.433799997, "...        Florida
# 6089  {"x": -9645833.8772, "y": 3555070.433799997, "...        Florida
# 6098  {"x": -9170800.2142, "y": 3893445.844999999, "...        Georgia
# 6099  {"x": -9253989.2696, "y": 3975217.4293000028, ...        Georgia
# 6100  {"x": -9135990.6094, "y": 3811977.4724999964, ...        Georgia
# 6106  {"x": -17368066.9536, "y": 2368046.6396000013,...         Hawaii
# 6107  {"x": -17440424.6226, "y": 2388301.7677999996,...         Hawaii
# 6108  {"x": -17329105.1318, "y": 2273030.927000001, ...         Hawaii
# 6109  {"x": -9775706.6165, "y": 5173470.558499999, "...       Illinois
# 6113  {"x": -10432862.6771, "y": 5120620.167099997, ...           Iowa
# 6120  {"x": -10811348.9458, "y": 4546985.284400001, ...         Kansas
# 6121  {"x": -9809473.5287, "y": 4485204.895800002, "...       Kentucky
# 6125  {"x": -10026546.5358, "y": 3497124.4274000004,...      Louisiana
# 6126  {"x": -9955302.0616, "y": 3420269.0613999963, ...      Louisiana
# 6127  {"x": -9843982.5708, "y": 3407504.076200001, "...      Louisiana
# 6130  {"x": -10111149.3488, "y": 6037264.071999997, ...      Minnesota
# 6131  {"x": -9968326.4421, "y": 3391055.656199999, "...    Mississippi
# 6132  {"x": -11868884.1084, "y": 5823642.465800002, ...        Montana
# 6133  {"x": -12856510.6307, "y": 6154132.6668, "spat...        Montana
# 6140  {"x": -11250689.8695, "y": 5168472.146600001, ...       Nebraska
# 6142  {"x": -8257679.827, "y": 4876119.708899997, "s...     New Jersey
# 6143  {"x": -8326742.439099999, "y": 5116981.2589000...       New York
# 6162  {"x": -9349679.5039, "y": 4821501.988399997, "...           Ohio
# 6163  {"x": -10612087.0573, "y": 4330935.410899997, ...       Oklahoma
# 6195  {"x": -11667284.5106, "y": 3741369.8814999983,...          Texas
# 6196  {"x": -10931295.6972, "y": 3646509.9246999994,...          Texas
# 6207  {"x": -12510084.375300001, "y": 4558257.461000...           Utah
# 6214  {"x": -9139330.1941, "y": 4710218.728799999, "...  West Virginia
#
# [34 rows x 24 columns]

# %%
# Create a dataset for visualisation
sdfUSA_grouped = sdfUSA.groupby('State')
sdfUSA_grouped_Averages = sdfUSA_grouped.mean()
sdfUSA_grouped_Averages
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# --> 959 return cy_op.cython_operation(
#     960     values=values,
#     961     axis=axis,
#     962     min_count=min_count,
#     963     comp_ids=ids,
#     964     ngroups=ngroups,
#     965     **kwargs,
#     966 )
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\ops.py:649, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     647 if not isinstance(values, np.ndarray):
#     648     # i.e. ExtensionArray
# --> 649     return self._ea_wrap_cython_operation(
#     650         values,
#     651         min_count=min_count,
#     652         ngroups=ngroups,
#     653         comp_ids=comp_ids,
#     654         **kwargs,
#     655     )
#     657 return self._cython_op_ndim_compat(
#     658     values,
#     659     min_count=min_count,
#    (...)
#     663     **kwargs,
#     664 )
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\ops.py:367, in WrappedCythonOp._ea_wrap_cython_operation(self, values, min_count, ngroups, comp_ids, **kwargs)
#     365 npvalues = self._ea_to_cython_values(values)
# --> 367 res_values = self._cython_op_ndim_compat(
#     368     npvalues,
#     369     min_count=min_count,
#     370     ngroups=ngroups,
#     371     comp_ids=comp_ids,
#     372     mask=None,
#     373     **kwargs,
#     374 )
#     376 if self.how in self.cast_blocklist:
#     377     # i.e. how in ["rank"], since other cast_blocklist methods don't go
#     378     #  through cython_operation
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\ops.py:482, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     481     result_mask = result_mask[None, :]
# --> 482 res = self._call_cython_op(
#     483     values2d,
#     484     min_count=min_count,
#     485     ngroups=ngroups,
#     486     comp_ids=comp_ids,
#     487     mask=mask,
#     488     result_mask=result_mask,
#     489     **kwargs,
#     490 )
#     491 if res.shape[0] == 1:
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\ops.py:541, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     540 out_shape = self._get_output_shape(ngroups, values)
# --> 541 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     542 values = self._get_cython_vals(values)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\ops.py:173, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     171 if "object" not in f.__signatures__:
#     172     # raise NotImplementedError here rather than TypeError later
# --> 173     raise NotImplementedError(
#     174         f"function is not implemented for this dtype: "
#     175         f"[how->{how},dtype->{dtype_str}]"
#     176     )
#     177 return f
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 3
#       1 # Create a dataset for visualisation
#       2 sdfUSA_grouped = sdfUSA.groupby('State')
# ----> 3 sdfUSA_grouped_Averages = sdfUSA_grouped.mean()
#       4 sdfUSA_grouped_Averages
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:1855, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    1853     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    1854 else:
# -> 1855     result = self._cython_agg_general(
#    1856         "mean",
#    1857         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1858         numeric_only=numeric_only,
#    1859     )
#    1860     return result.__finalize__(self.obj, method="groupby")
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:1507, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1503         result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505     return result
# -> 1507 new_mgr = data.grouped_reduce(array_func)
#    1508 res = self._wrap_agged_manager(new_mgr)
#    1509 out = self._wrap_aggregated_output(res)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\internals\managers.py:1506, in BlockManager.grouped_reduce(self, func)
#    1504             result_blocks = extend_blocks(applied, result_blocks)
#    1505     else:
# -> 1506         applied = blk.apply(func)
#    1507         result_blocks = extend_blocks(applied, result_blocks)
#    1509 if len(result_blocks) == 0:
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\internals\blocks.py:329, in Block.apply(self, func, **kwargs)
#     323 @final
#     324 def apply(self, func, **kwargs) -> list[Block]:
#     325     """
#     326     apply the function to my values; return a block if we are not
#     327     one
#     328     """
# --> 329     result = func(self.values, **kwargs)
#     331     return self._split_op_result(result)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:1503, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    (...)
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
# -> 1503     result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505 return result
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:1457, in GroupBy._agg_py_fallback(self, values, ndim, alt)
#    1452     ser = df.iloc[:, 0]
#    1454 # We do not get here with UDFs, so we know that our dtype
#    1455 #  should always be preserved by the implemented aggregations
#    1456 # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1457 res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1459 if isinstance(values, Categorical):
#    1460     # Because we only get here with known dtype-preserving
#    1461     #  reductions, we cast back to Categorical.
#    1462     # TODO: if we ever get "rank" working, exclude it here.
#    1463     res_values = type(values)._from_sequence(res_values, dtype=values.dtype)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\ops.py:994, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     987 if len(obj) > 0 and not isinstance(obj._values, np.ndarray):
#     988     # we can preserve a little bit more aggressively with EA dtype
#     989     #  because maybe_cast_pointwise_result will do a try/except
#     990     #  with _from_sequence.  NB we are assuming here that _from_sequence
#     991     #  is sufficiently strict that it casts appropriately.
#     992     preserve_dtype = True
# --> 994 result = self._aggregate_series_pure_python(obj, func)
#     996 npvalues = lib.maybe_convert_objects(result, try_float=False)
#     997 if preserve_dtype:
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\ops.py:1015, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1012 splitter = self._get_splitter(obj, axis=0)
#    1014 for i, group in enumerate(splitter):
# -> 1015     res = func(group)
#    1016     res = libreduction.extract_result(res)
#    1018     if not initialized:
#    1019         # We only do this validation on the first iteration
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:1857, in GroupBy.mean.<locals>.<lambda>(x)
#    1853     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    1854 else:
#    1855     result = self._cython_agg_general(
#    1856         "mean",
# -> 1857         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1858         numeric_only=numeric_only,
#    1859     )
#    1860     return result.__finalize__(self.obj, method="groupby")
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\series.py:4656, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4652     self._get_axis_number(axis)
#    4654 if isinstance(delegate, ExtensionArray):
#    4655     # dispatch to ExtensionArray interface
# -> 4656     return delegate._reduce(name, skipna=skipna, **kwds)
#    4658 else:
#    4659     # dispatch to numpy arrays
#    4660     if numeric_only and not is_numeric_dtype(self.dtype):
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\arrays\string_.py:476, in StringArray._reduce(self, name, skipna, axis, **kwargs)
#     473 if name in ["min", "max"]:
#     474     return getattr(self, name)(skipna=skipna, axis=axis)
# --> 476 raise TypeError(f"Cannot perform reduction '{name}' with string dtype")
#
# TypeError: Cannot perform reduction 'mean' with string dtype

# %% [markdown]
# ### Basic Plotting: plot
# [[back to top]](#Table-of-Contents)
#
# The plot method on Series and DataFrame is just a simple wrapper around `plt.plot()`:

# %%
sdfUSA_grouped_Averages["TEMP"].plot()
plt.show()

# %% [markdown]
# On DataFrame, `plot()` is a convenience to plot all of the columns with labels:

# %%
sdfUSA_grouped_Averages[["TEMP", "R_HUMIDITY"]].plot()
plt.show()

# %% [markdown]
# You can plot one column versus another using the `x` and `y` keywords in `plot()`:

# %% [markdown]
# ### Other Plots
#
# [[back to top]](#Table-of-Contents)
#
# Plotting methods allow for a handful of plot styles other than the default Line plot. These methods can be provided as the kind keyword argument to `plot()`. These include:
#
#    - ‘bar’ or ‘barh’ for bar plots
#    - ‘hist’ for histogram
#    - ‘box’ for boxplot
#    - ‘kde’ or 'density' for density plots
#    - ‘area’ for area plots
#    - ‘scatter’ for scatter plots
#    - ‘hexbin’ for hexagonal bin plots
#    - ‘pie’ for pie plots
#
# In addition to these kind s, there are the `DataFrame.hist()`, and `DataFrame.boxplot()` methods, which use a separate interface.
#
# Finally, there are several plotting functions in `pandas.tools.plotting` that take a Series or DataFrame as an argument. These include
#
#    - Scatter Matrix
#    - Andrews Curves
#    - Parallel Coordinates
#    - Lag Plot
#    - Autocorrelation Plot
#    - Bootstrap Plot
#    - RadViz
#
# Plots may also be adorned with errorbars or tables.

# %% [markdown]
# ### Bar plots
#
# [[back to top]](#Table-of-Contents)
#
# For labeled, non-time series data, you may wish to produce a bar plot:

# %%
sdfUSA_grouped_Averages.plot(kind='bar',y='TEMP');
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 sdfUSA_grouped_Averages.plot(kind='bar',y='TEMP');
#       2 plt.show()
#
# NameError: name 'sdfUSA_grouped_Averages' is not defined

# %% [markdown]
# Calling a DataFrame’s `plot()` method with `kind='bar'` produces a multiple bar plot:

# %%
sdfUSA_grouped_Averages[["TEMP", "R_HUMIDITY"]].head().plot(kind='bar')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 sdfUSA_grouped_Averages[["TEMP", "R_HUMIDITY"]].head().plot(kind='bar')
#       2 plt.show()
#
# NameError: name 'sdfUSA_grouped_Averages' is not defined

# %% [markdown]
# To produce a stacked bar plot, pass `stacked=True`:

# %%
sdfUSA_grouped_Averages[["TEMP", "R_HUMIDITY"]].plot(kind='bar', stacked=True);
plt.show()

# %% [markdown]
# To get horizontal bar plots, pass `kind='barh'`:

# %%
plt.rcParams["figure.figsize"] = (18.0, 18.0)
sdfUSA_grouped_Averages[["TEMP", "R_HUMIDITY"]].plot(kind='barh');
plt.show()

# %% [markdown]
# ### Histograms
#
# [[back to top]](#Table-of-Contents)
#
# Histogram can be drawn specifying `kind='hist'`.

# %%
# Reduce plot's size
plt.rcParams["figure.figsize"] = (7.0, 5.0)

sdfUSA_grouped_Averages[["TEMP", "R_HUMIDITY"]].plot(kind='hist', alpha=0.5)
plt.show()

# %% [markdown]
# Histogram can be stacked by `stacked=True`. Bin size can be changed by bins keyword.

# %%
sdfUSA_grouped_Averages[["TEMP", "R_HUMIDITY"]].plot(kind='hist', stacked=True, bins=10)
plt.show()

# %% [markdown]
# You can pass other keywords supported by matplotlib hist. For example, horizontal and cumulative histgram can be drawn by `orientation='horizontal'` and `cumulative='True'`.

# %%
sdfUSA_grouped_Averages[["TEMP"]].hist()
plt.show()

# %% [markdown]
# `DataFrame.hist()` plots the histograms of the columns on multiple subplots:

# %%
sdfUSA_grouped_Averages[["TEMP", "R_HUMIDITY"]].hist(color='k', alpha=0.5, bins=15)
plt.show()

# %% [markdown]
# ### Box Plots
#
# [[back to top]](#Table-of-Contents)
#
# Boxplot can be drawn calling a `Series` and `DataFrame.plot` with `kind='box'`, or `DataFrame.boxplot` to visualize the distribution of values within each column.
#
# `plot` method now supports `kind='box'` to draw boxplot.

# %%
sdfUSA_grouped_Averages[["TEMP", "R_HUMIDITY"]].plot(kind='box')
plt.show()

# %% [markdown]
# Boxplot can be colorized by passing color keyword. You can pass a dict whose keys are boxes, whiskers, medians and caps. If some keys are missing in the dict, default colors are used for the corresponding artists. Also, boxplot has sym keyword to specify fliers style.
#
# When you pass other type of arguments via `color` keyword, it will be directly passed to matplotlib for all the boxes, whiskers, medians and caps colorization.
#
# The colors are applied to every boxes to be drawn. If you want more complicated colorization, you can get each drawn artists by passing `return_type`.

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange',medians='DarkBlue', caps='Gray')
sdfUSA_grouped_Averages[["TEMP", "R_HUMIDITY"]].plot(kind='box', color=color, sym='r+')
plt.show()

# %% [markdown]
# Also, you can pass other keywords supported by matplotlib boxplot. For example, horizontal and custom-positioned boxplot can be drawn by `vert=False` and `positions` keywords.

# %%
sdfUSA_grouped_Averages[["TEMP", "R_HUMIDITY"]].plot(kind='box', vert=False, positions=[1, 4])
plt.show()

# %% [markdown]
# ### Area Plot
#
# [[back to top]](#Table-of-Contents)
#
# You can create area plots with `Series.plot` and `DataFrame.plot` by passing `kind='area'`. Area plots are stacked by default. To produce stacked area plot, each column must be either all positive or all negative values.
#
# When input data contains `NaN`, it will be automatically filled by `0`. If you want to `drop` or `fill` by different values, use `dataframe.dropna()` or `dataframe.fillna()` before calling plot.

# %%
sdfUSA_grouped_Averages[["TEMP", "R_HUMIDITY"]].head(10).plot(kind='area');
plt.show()

# %% [markdown]
# To produce an unstacked plot, pass `stacked=False`. `Alpha` value is set to `0.5` unless otherwise specified:

# %%
sdfUSA_grouped_Averages[["TEMP", "R_HUMIDITY"]].head(10).plot(kind='area', stacked=False)
plt.show()

# %% [markdown]
# ### Scatter Plot
#
# [[back to top]](#Table-of-Contents)
#
# You can create scatter plots with `DataFrame.plot` by passing `kind='scatter'`. Scatter plot requires numeric columns for `x` and `y` axis. These can be specified by `x` and `y` keywords each.

# %%
sdfUSA_grouped_Averages.plot(kind='scatter', x='TEMP', y='R_HUMIDITY');
plt.show()

# %% [markdown]
# The keyword `c` may be given as the name of a column to provide colors for each point:

# %%
sdfUSA_grouped_Averages.plot(kind='scatter', x='ELEVATION', y='TEMP', c="R_HUMIDITY", s=50);
plt.show()

# %% [markdown]
# You can pass other keywords supported by `matplotlib scatter`. Below example shows a bubble chart using a dataframe column values as bubble size.

# %%
sdfUSA_grouped_Averages.plot(kind='scatter', x='ELEVATION', y='TEMP', s="R_HUMIDITY");
plt.show()

# %% [markdown]
# ### Hexagonal Bin Plot
#
# [[back to top]](#Table-of-Contents)
#
# You can create hexagonal bin plots with `DataFrame.plot()` and `kind='hexbin'`. Hexbin plots can be a useful alternative to scatter plots if your data are too dense to plot each point individually.

# %%
sdfUSA_grouped_Averages.plot(kind='hexbin', x='ELEVATION', y='TEMP', gridsize=10);
plt.show()

# %% [markdown]
# ### Pie plot
#
# [[back to top]](#Table-of-Contents)
#
# You can create a pie plot with `DataFrame.plot()` or `Series.plot()` with `kind='pie'`. If your data includes any `NaN`, they will be automatically filled with 0. A `ValueError` will be raised if there are any negative values in your data.
