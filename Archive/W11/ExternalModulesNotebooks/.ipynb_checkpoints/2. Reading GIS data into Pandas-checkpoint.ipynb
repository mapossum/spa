# %% [markdown]
# ---
# <center><h1>Pandas and GIS Data</h1></center>
#
#
# <center><h2> Getting Spatial Data into Pandas</h2></center>
#
# ---

# %% [markdown]
# ArcGIS (and other GIS data) can be converted into a Pandas Dataframe.  The reasons one may want to do this is that it allows for further analysis that may not be able to be done in other GIS software, or is easier to do in the Python programming evironment.  We will cover here in this notebook several ways of accessing ingesting GIS data into a Pandas data frame.  These include:
#
# - The Spatially Enabled Data Frame (Part of the [ArcGIS API for Python](https://developers.arcgis.com/python/guide/introduction-to-the-spatially-enabled-dataframe/));
# - ArcPy - [FeatureClassToNumPyArray](https://pro.arcgis.com/en/pro-app/latest/arcpy/data-access/featureclasstonumpyarray.htm) method;

# %% [markdown]
# The <b>Spatially Enabled Data Frame</b> is a data type created by ESRI that extends a regular Pandas DataFrame.  It extends it in many ways that we will discuss later, but the most fundemental is that it allows you to read in ESRI vector data in a variety of different formats (local and web) into a DataFrame for further manipuation.  This is lines of code you need to import both pandas and the Spatially Enabled Data Frame.

# %%
import pandas as pd
from arcgis.features import GeoAccessor, GeoSeriesAccessor

# %% [markdown]
# From there you can access any local data on your system:
#
# ```python
# sdf = pd.DataFrame.spatial.from_featureclass("path\to\your\data\folder\layername")
# ```
# Here is a live example:

# %%
sdf = pd.DataFrame.spatial.from_featureclass("Gulf_and_Caribbean_Marine_Ecoregions.shp")
sdf.columns.tolist()
sdf["Shape_Area"]
# Out:
# 0     368517.968376
# 1     146257.311201
# 2     222021.281976
# 3     329291.612384
# 4      92333.186987
# 5     553545.983522
# 6     423550.614982
# 7     449703.392457
# 8     445707.530043
# 9     153684.511701
# 10    494395.292123
# Name: Shape_Area, dtype: Float64

# %%
sdf["Shape_Area"] * 0.00386102
# Out:
# 0     1422.855246
# 1      564.702404
# 2       857.22861
# 3     1271.401501
# 4      356.500282
# 5     2137.252113
# 6     1635.337395
# 7     1736.313792
# 8     1720.885688
# 9      593.378973
# 10    1908.870111
# Name: Shape_Area, dtype: Float64

# %% [markdown]
# Notice that there is a field called shape.  This field does contain geometry.  We will look at that later in the course (not today).

# %% [markdown]
# In addition to accessing local data, you can also access feature datasets on ArcGIS online, ESRI living atlas, and any data that has been published as an ArcGIS feature layer.

# %%
#Import a COVID data layer.  This layer contains the updated stats for each county in the United States
from arcgis.features import FeatureLayer
mylayer = FeatureLayer(("https://services1.arcgis.com/0MSEUqKaxRlEPj5g/ArcGIS/rest/services/ncov_cases_US/FeatureServer/0"))
sdf2 = pd.DataFrame.spatial.from_layer(mylayer)
sdf2.head(2)
# Out:
#    OBJECTID Province_State Country_Region         Last_Update        Lat  \
# 0         1        Alabama             US 2023-03-10 13:21:02  32.539527
# 1         2        Alabama             US 2023-03-10 13:21:02   30.72775
#
#        Long_  Confirmed  Recovered  Deaths  Active   Admin2   FIPS  \
# 0 -86.644082      19790       <NA>     232    <NA>  Autauga  01001
# 1 -87.722071      69860       <NA>     727    <NA>  Baldwin  01003
#
#            Combined_Key  Incident_Rate  People_Tested  People_Hospitalized  \
# 0  Autauga, Alabama, US    35422.14824           <NA>                 <NA>
# 1  Baldwin, Alabama, US   31294.516068           <NA>                 <NA>
#
#         UID ISO3                                              SHAPE
# 0  84001001  USA  {"x": -86.64408226999996, "y": 32.539527450000...
# 1  84001003  USA  {"x": -87.72207057999998, "y": 30.727749910000...

# %%
sdf2[sdf2["Province_State"] == 'Mississippi']['Confirmed'].sum()
# Out:
# 990756

# %%
# Marine protected areas of the world
from arcgis.features import FeatureLayer
mylayer = FeatureLayer(("https://services5.arcgis.com/Mj0hjvkNtV7NRhA7/arcgis/rest/services/WDPA_v4/FeatureServer/0"))
sdf3 = pd.DataFrame.spatial.from_layer(mylayer)
sdf3
# Out:
#        OBJECTID       wdpaid   wdpa_pid pa_def  \
# 0             1     159863.0     159863      1
# 1             2     160202.0     160202      1
# 2             3  555681859.0  555681859      1
# 3             4  555681858.0  555681858      1
# 4             5  555681857.0  555681857      1
# ...         ...          ...        ...    ...
# 11932     11933     154167.0     154167      1
# 11933     11934     182519.0     182519      1
# 11934     11935     171451.0     171451      1
# 11935     11936     387130.0     387130      1
# 11936     11937     327059.0     327059      1
#
#                                                     name  \
# 0                                                 Ostriv
# 1                                                  Bilka
# 2                                               Bamézoun
# 3                                                Orozoun
# 4                                               Têdozoun
# ...                                                  ...
# 11932                                         2012013 Ek
# 11933                                   Rrepet e Izvorit
# 11934                 Apollo kivi e Kalevipoja viskekivi
# 11935  Planica - lipa pri lovskem domu - dendrološki ...
# 11936                                Nõmmeveski rändrahn
#
#                                                orig_name  \
# 0                                                 Ostriv
# 1                                                  Bilka
# 2                                               Bamézoun
# 3                                                Orozoun
# 4                                               Têdozoun
# ...                                                  ...
# 11932                                         2012013 Ek
# 11933                                   Rrepet e Izvorit
# 11934                 Apollo kivi e Kalevipoja viskekivi
# 11935  Planica - lipa pri lovskem domu - dendrološki ...
# 11936                                Nõmmeveski rändrahn
#
#                               desig                            desig_eng  \
# 0                 Regional Zakaznik                    Regional Zakaznik
# 1                 Regional Zakaznik                    Regional Zakaznik
# 2                      Forêt Sacrée                        Sacred Forest
# 3                      Forêt Sacrée                        Sacred Forest
# 4                      Forêt Sacrée                        Sacred Forest
# ...                             ...                                  ...
# 11932                    Naturminne                     Natural Monument
# 11933               Monument Natyre  Nature Monument (Category III IUCN)
# 11934  Kaitstav looduse üksikobjekt            Protected nature monument
# 11935              naravni spomenik                     Natural Monument
# 11936  Kaitstav looduse üksikobjekt            Protected nature monument
#
#            desig_type      iucn_cat  ...  \
# 0            National            IV  ...
# 1            National            IV  ...
# 2      Not Applicable            II  ...
# 3      Not Applicable            II  ...
# 4      Not Applicable            II  ...
# ...               ...           ...  ...
# 11932        National  Not Assigned  ...
# 11933        National           III  ...
# 11934        National           III  ...
# 11935        National           III  ...
# 11936        National           III  ...
#
#                                      gov_type      own_type  \
# 0                                Not Reported  Not Reported
# 1                                Not Reported  Not Reported
# 2                          Indigenous peoples      Communal
# 3                          Indigenous peoples      Communal
# 4                          Indigenous peoples      Communal
# ...                                       ...           ...
# 11932  Federal or national ministry or agency  Not Reported
# 11933  Federal or national ministry or agency  Not Reported
# 11934  Federal or national ministry or agency  Not Reported
# 11935  Federal or national ministry or agency  Not Reported
# 11936  Federal or national ministry or agency  Not Reported
#
#                                                mang_auth     mang_plan  \
# 0                                           Not Reported  Not Reported
# 1                                           Not Reported  Not Reported
# 2                    Local management committee Bamézoun  Not Reported
# 3                             Local management committee  Not Reported
# 4                             Local management committee  Not Reported
# ...                                                  ...           ...
# 11932  County Administrative Board and Local Authorities  Not Reported
# 11933  Ministry of Environment, Forests and Water Adm...  Not Reported
# 11934  Ministry of Environment, Narva mnt 7a, Tallinn...  Not Reported
# 11935  Ministry of Agriculture and Environment, Dunaj...  Not Reported
# 11936  Ministry of Environment, Narva mnt 7a, Tallinn...  Not Reported
#
#                  verif  metadataid       sub_loc  parent_iso3 iso3  \
# 0       State Verified         367         UA-35          UKR  UKR
# 1       State Verified         367         UA-77          UKR  UKR
# 2      Expert Verified        1980  Not Reported          BEN  BEN
# 3      Expert Verified        1980  Not Reported          BEN  BEN
# 4      Expert Verified        1980  Not Reported          BEN  BEN
# ...                ...         ...           ...          ...  ...
# 11932   State Verified        2013  Not Reported          SWE  SWE
# 11933   State Verified        2013  Not Reported          ALB  ALB
# 11934   State Verified        2013  Not Reported          EST  EST
# 11935   State Verified        2013  Not Reported          SVN  SVN
# 11936   State Verified        2013  Not Reported          EST  EST
#
#                                                    SHAPE
# 0      {"points": [[3486495.5048, 6227484.1114]], "sp...
# 1      {"points": [[2856458.1338, 6136852.834]], "spa...
# 2      {"points": [[283757.834800001, 723412.8816]], ...
# 3      {"points": [[301116.996199999, 724717.22309999...
# 4      {"points": [[239421.508000001, 743421.65630000...
# ...                                                  ...
# 11932  {"points": [[1724294.5761, 7655718.2255]], "sp...
# 11933  {"points": [[2171535.8066, 4914170.3959]], "sp...
# 11934  {"points": [[3019674.941, 8098704.0328]], "spa...
# 11935  {"points": [[1734274.7379, 5855694.8217]], "sp...
# 11936  {"points": [[2870735.7186, 8290936.3238]], "sp...
#
# [11937 rows x 28 columns]

# %% [markdown]
# You can also use the two arcPy methods called "FeatureClassToNumPyArray" and "TableToNumPyArray"  For each of these methods, the inital result is an array instead of a pandas data frame.  To run these methods, you must specify the location of the local data, and the fields you want to convert, then convert that into a pandas DataFrame:

# %%
import arcpy
fields = ["Shape_Area", "ECOREGION", "REALM"]
array = arcpy.da.FeatureClassToNumPyArray("Gulf_and_Caribbean_Marine_Ecoregions.shp", fields)
array

sdf4 = pd.DataFrame(array[fields])
sdf4
# Out:
#        Shape_Area                ECOREGION                        REALM
# 0   368517.968376                 Bahamian            Tropical Atlantic
# 1   146257.311201                  Bermuda            Tropical Atlantic
# 2   222021.281976               Carolinian  Temperate Northern Atlantic
# 3   329291.612384        Eastern Caribbean            Tropical Atlantic
# 4    92333.186987                Floridian            Tropical Atlantic
# 5   553545.983522  Northern Gulf of Mexico  Temperate Northern Atlantic
# 6   423550.614982       Southern Caribbean            Tropical Atlantic
# 7   449703.392457  Southern Gulf of Mexico            Tropical Atlantic
# 8   445707.530043   Southwestern Caribbean            Tropical Atlantic
# 9   153684.511701        Western Caribbean            Tropical Atlantic
# 10  494395.292123         Greater Antilles            Tropical Atlantic

# %%
import arcpy
fields = ["Crosswalk", "Class", "Match"]
array = arcpy.da.FeatureClassToNumPyArray("aassesmet.shp", fields)
array

sdf5 = pd.DataFrame(array[fields])
sdf5
# Out:
#                    Crosswalk                   Class  Match
# 0                       Sand                    Sand      1
# 1                Coral/Algae             Coral/Algae      1
# 2                Coral/Algae             Coral/Algae      1
# 3     Hardbottom Dense Algae  Hardbottom Dense Algae      1
# 4     Hardbottom Dense Algae  Hardbottom Dense Algae      1
# ...                      ...                     ...    ...
# 2681                    Sand                    Sand      1
# 2682                    Sand                    Sand      1
# 2683  Hardbottom Dense Algae  Hardbottom Dense Algae      1
# 2684             Coral/Algae             Coral/Algae      1
# 2685                    Sand                    Sand      1
#
# [2686 rows x 3 columns]

# %%
sdf5["Crosswalk"] == sdf5["Class"]
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 2681    True
# 2682    True
# 2683    True
# 2684    True
# 2685    True
# Length: 2686, dtype: bool

# %%
sdf5["Match"] = sdf5["Crosswalk"] == sdf5["Class"]
sdf5
# Out:
#                    Crosswalk                   Class  Match
# 0                       Sand                    Sand   True
# 1                Coral/Algae             Coral/Algae   True
# 2                Coral/Algae             Coral/Algae   True
# 3     Hardbottom Dense Algae  Hardbottom Dense Algae   True
# 4     Hardbottom Dense Algae  Hardbottom Dense Algae   True
# ...                      ...                     ...    ...
# 2681                    Sand                    Sand   True
# 2682                    Sand                    Sand   True
# 2683  Hardbottom Dense Algae  Hardbottom Dense Algae   True
# 2684             Coral/Algae             Coral/Algae   True
# 2685                    Sand                    Sand   True
#
# [2686 rows x 3 columns]

# %%
sdf5[sdf5["Match"] == True].count()
# Out:
# Crosswalk    2014
# Class        2014
# Match        2014
# dtype: int64

# %%
sdf5[sdf5["Match"] == False]["Match"].count()
# Out:
# 672

# %%
sdf5[sdf5["Match"] == True]["Match"].count() / (sdf5[sdf5["Match"] == False]["Match"].count() + sdf5[sdf5["Match"] == True]["Match"].count())
# Out:
# 0.7498138495904692
