# %% [markdown]
# ---
# <center><h1>Basic intro into pandas</h1></center>
# ---
# ---
#
# <center><h2>Working with pandas DataFrames: grouping</h2></center>
# ---

# %% [markdown]
# ## Table of Contents
#
# - [Work with pandas DataFrames: grouping](#Work-with-pandas-DataFrames:-grouping)
#     * [Splitting of a DataFrame into groups](#Splitting-of-a-DataFrame-into-groups)
#     * [Selection and filtering](#Selection-and-filtering)
#     * [Aggregation and function application](#Aggregation-and-function-application)
#     - [*Exercise 1*](#Exercise-1)

# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# ## Work with pandas DataFrames: grouping
#
# [[back to top]](#Table-of-Contents)
#
# We will a werather station dataset so that we can see what is going on when we group.

# %%
from arcgis.features import GeoAccessor, GeoSeriesAccessor
#Import a COVID data layer.  This layer contains the updated stats for each county in the United States
from arcgis.features import FeatureLayer
mylayer = FeatureLayer(("https://services9.arcgis.com/RHVPKKiFTONKtxq3/arcgis/rest/services/NOAA_METAR_current_wind_speed_direction_v1/FeatureServer/0"))
sdf2 = pd.DataFrame.spatial.from_layer(mylayer)
sdf2.head(5)
# Out:
#    OBJECTID  ICAO        OBS_DATETIME STATION_NAME COUNTRY  ELEVATION  TEMP  \
# 0      4992  AGGH 2025-04-30 17:00:00         <NA>    <NA>        6.0  75.2
# 1      5233  AGGM 2024-07-05 06:00:00         <NA>    <NA>        6.0  84.2
# 2      5915  AGGR 2023-11-07 23:00:00         <NA>    <NA>       11.0  86.0
# 3      5517  ANYN 2025-04-30 10:00:00         <NA>    <NA>        7.0  82.4
# 4      5224  AYMH 2025-04-30 07:00:00         <NA>    <NA>     1634.0  69.8
#
#    DEW_POINT  R_HUMIDITY  WIND_DIRECT  ...  VISIBILITY  PRESSURE  \
# 0       75.2         100          200  ...        9700    1009.8
# 1       73.4          70          140  ...        9700    1006.8
# 2       80.6          84           90  ...        9700    1008.8
# 3       75.2          79         <NA>  ...        9700    1011.9
# 4       66.2          88          160  ...        9700    1019.0
#
#                                           SKY_CONDTN  \
# 0  Few Clouds at 460 meters AGL, Scattered Clouds...
# 1  Few Clouds at 580 meters AGL, Scattered Clouds...
# 2  Scattered Clouds at 550 meters AGL, Broken Clo...
# 3                       Few Clouds at 610 meters AGL
# 4                Scattered Clouds at 1200 meters AGL
#
#                                         WEATHER  REMARKS HEAT_INDEX LATITUDE  \
# 0  No significant weather present at this time.     <NA>       <NA>    -9.43
# 1  No significant weather present at this time.     <NA>       90.9   -8.327
# 2  No significant weather present at this time.     <NA>      101.9   -11.55
# 3  No significant weather present at this time.     <NA>       89.5   -0.547
# 4  No significant weather present at this time.     <NA>       <NA>   -5.831
#
#   LONGITUDE  FLT_CATEGORY                                              SHAPE
# 0   160.047           VFR  {"x": 17816350.542999998, "y": -1054514.398899...
# 1   157.263           VFR  {"x": 17506437.0806, "y": -930237.9125000015, ...
# 2   160.063           VFR  {"x": 17818131.654799998, "y": -1294537.687800...
# 3   166.919           VFR  {"x": 18581338.0837, "y": -60892.6865000017, "...
# 4     144.3           VFR  {"x": 16063402.521499999, "y": -650227.3401000...
#
# [5 rows x 23 columns]

# %%
sdfUSA = sdf2.loc[sdf2["COUNTRY"].apply(lambda x: "United States Of America" in str(x))]
sdfUSA["State"] = sdfUSA['COUNTRY'].apply(lambda x: str(x).split(",")[0])
sdfUSA["COUNTRY"] = sdfUSA['COUNTRY'].apply(lambda x: str(x).split(",")[1])
sdfUSA
# Out:
# C:/Users/georg/AppData/Local/Temp/ArcGISProTemp21560/xpython_21560/1005894466.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdfUSA["State"] = sdfUSA['COUNTRY'].apply(lambda x: str(x).split(",")[0])
# C:/Users/georg/AppData/Local/Temp/ArcGISProTemp21560/xpython_21560/1005894466.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdfUSA["COUNTRY"] = sdfUSA['COUNTRY'].apply(lambda x: str(x).split(",")[1])
#       OBJECTID  ICAO        OBS_DATETIME      STATION_NAME  \
# 5956      6060  PAEC 2024-01-16 16:51:00          Chulitna
# 5957      3767  PAHP 2022-09-17 01:32:00        Hooper Bay
# 5958      5937  PALR 2023-06-27 00:50:00    Chandalar Lake
# 5959      4180  PAWI 2024-04-29 23:53:00        Wainwright
# 6070      4922  KCQT 2024-05-20 14:47:00       Los Angeles
# 6071       517  KL52 2023-04-09 16:55:00       Oceano Cnty
# 6088      6002  KQBL 2024-06-14 22:55:00          Hurlbert
# 6089      6003  KQHY 2024-06-14 22:55:00          Hurlbert
# 6098      1027  K2J3 2023-11-10 06:10:00        Louisville
# 6099      1014  K3J7 2023-05-03 14:30:00        Greensboro
# 6100      2936  KHME 2023-02-26 13:50:00            Metter
# 6106      5970  PHHN 2023-09-15 03:58:00              Hana
# 6107      5889  PHJH 2023-01-27 04:05:00  Lahaina/West Mau
# 6108      5971  PHMU 2023-09-15 04:00:00    Kamuela/Waimea
# 6109      5840  KNBU 2022-12-13 08:00:00      Glenview Nas
# 6113      5965  KDMX 2023-08-24 17:00:00  Johnston/Desmoin
# 6120      1045  K1K1 2022-12-29 06:10:00            Benton
# 6121       985  K5M9 2022-11-09 15:35:00            Marion
# 6125       107  K7N0 2023-01-26 18:56:00  New Orleans/Supe
# 6126       498  KLNQ 2023-08-25 13:46:00    Boothville Hel
# 6127       150  KVKY 2023-07-03 14:50:00    Main Pass 289C
# 6130      6104  KP61 2024-05-24 06:52:00     Tofte (Ramos)
# 6131      5832  KDLP 2024-02-10 23:05:00    West Delta 27A
# 6132      5683  K1S3 2024-04-30 20:15:00           Forsyth
# 6133      1618  KS59 2024-06-11 22:45:00             Libby
# 6140      5691  KMHN 2022-08-31 01:58:00            Mullen
# 6142      5977  KN12 2023-10-09 15:55:00          Lakewood
# 6143      3856  KMSV 2024-03-05 18:38:00        Monticello
# 6162       585  KI19 2023-11-29 23:55:00    Dayton-Jackson
# 6163       631  KH71 2023-04-14 15:35:00             Pryor
# 6195      4754  KGDP 2023-12-11 00:51:00    Guadalupe Pass
# 6196      2260  KLZZ 2024-04-03 14:35:00          Lampasas
# 6207       175  KU55 2023-08-20 09:55:00         Panguitch
# 6214      1015  K3I2 2022-12-28 09:30:00       Pt Pleasant
#
#                         COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
# 5956   United States Of America      389.0  30.2       32.0         108
# 5957   United States Of America        8.0  51.8       46.4          82
# 5958   United States Of America      579.0  59.0       50.0          72
# 5959   United States Of America       12.0  12.9       10.0          88
# 6070   United States Of America       51.0  60.1       52.0          75
# 6071   United States Of America        3.0  55.4       55.4         100
# 6088   United States Of America     9999.0  86.0       75.7          72
# 6089   United States Of America     9999.0  86.4       76.6          73
# 6098   United States Of America       97.0  57.2       56.7          98
# 6099   United States Of America      207.0  60.8       33.8          36
# 6100   United States Of America       60.0  60.8       35.6          39
# 6106   United States Of America       20.0  75.2       73.4          94
# 6107   United States Of America       67.0  <NA>       <NA>        <NA>
# 6108   United States Of America      809.0  66.2       64.4          94
# 6109   United States Of America       <NA>  48.9       35.1          59
# 6113   United States Of America      299.0  <NA>       <NA>        <NA>
# 6120   United States Of America      411.0  46.9       29.7          51
# 6121   United States Of America      199.0  68.2       37.6          32
# 6125   United States Of America        0.0  52.0       36.0          54
# 6126   United States Of America        1.0 -35.7       <NA>        <NA>
# 6127   United States Of America       32.0  <NA>       <NA>        <NA>
# 6130   United States Of America      241.0  43.0       41.0          93
# 6131   United States Of America       31.0  <NA>       <NA>        <NA>
# 6132   United States Of America      831.0  53.6       17.6          24
# 6133   United States Of America      793.0  80.6       80.6         100
# 6140   United States Of America       <NA>  78.4       53.4          42
# 6142   United States Of America       13.0  68.5       38.5          33
# 6143   United States Of America      427.0  42.8       41.0          93
# 6162   United States Of America      285.0  35.6       26.6          69
# 6163   United States Of America      190.0  71.6       53.6          53
# 6195   United States Of America     1664.0  41.0        8.1          25
# 6196   United States Of America      356.0  60.3       37.9          43
# 6207   United States Of America     2060.0  57.2       55.4          94
# 6214   United States Of America      195.0  18.9       16.7          91
#
#       WIND_DIRECT  ...  PRESSURE  \
# 5956           40  ...    1013.2
# 5957          180  ...     979.0
# 5958           70  ...    1008.1
# 5959           90  ...    1027.1
# 6070            0  ...    1016.3
# 6071          250  ...    1020.3
# 6088         <NA>  ...    1012.5
# 6089          220  ...    1012.2
# 6098            0  ...    1017.3
# 6099          270  ...    1009.8
# 6100          270  ...    1023.9
# 6106            0  ...    1015.9
# 6107           20  ...    1016.2
# 6108           40  ...    1017.3
# 6109          360  ...    1023.4
# 6113         <NA>  ...      <NA>
# 6120          240  ...    1002.4
# 6121            0  ...    1027.1
# 6125            0  ...    1026.7
# 6126           70  ...    1016.2
# 6127          240  ...    1017.3
# 6130            0  ...    1017.6
# 6131          180  ...    1008.8
# 6132          280  ...    1009.5
# 6133          200  ...    1008.8
# 6140           30  ...    1023.0
# 6142          360  ...    1023.0
# 6143           90  ...    1019.0
# 6162          210  ...    1016.3
# 6163          170  ...    1006.8
# 6195          230  ...    1022.7
# 6196          300  ...    1016.9
# 6207            0  ...    1024.7
# 6214            0  ...    1023.4
#
#                                              SKY_CONDTN  \
# 5956             Overcast Cloud Deck at 1300 meters AGL
# 5957              Overcast Cloud Deck at 730 meters AGL
# 5958  Broken Clouds at 1800 meters AGL, Overcast Clo...
# 5959                  Scattered Clouds at 60 meters AGL
# 6070              Overcast Cloud Deck at 760 meters AGL
# 6071                                               <NA>
# 6088                      Few Clouds at 2700 meters AGL
# 6089                      Few Clouds at 2900 meters AGL
# 6098                    Sky Clear below 3700 meters AGL
# 6099                    Sky Clear below 3700 meters AGL
# 6100                Scattered Clouds at 1100 meters AGL
# 6106             Overcast Cloud Deck at 1300 meters AGL
# 6107  Scattered Clouds at 430 meters AGL, Scattered ...
# 6108  Scattered Clouds at 210 meters AGL, Broken Clo...
# 6109             Overcast Cloud Deck at 1200 meters AGL
# 6113                                               <NA>
# 6120                    Sky Clear below 3700 meters AGL
# 6121                    Sky Clear below 3700 meters AGL
# 6125                    Sky Clear below 3700 meters AGL
# 6126                                               <NA>
# 6127                    Sky Clear below 3700 meters AGL
# 6130                                               <NA>
# 6131                    Sky Clear below 3700 meters AGL
# 6132                                               <NA>
# 6133                                               <NA>
# 6140                   Broken Clouds at 4300 meters AGL
# 6142                      Few Clouds at 3700 meters AGL
# 6143              Overcast Cloud Deck at 120 meters AGL
# 6162                    Sky Clear below 3700 meters AGL
# 6163                    Sky Clear below 3700 meters AGL
# 6195                                               <NA>
# 6196                    Sky Clear below 3700 meters AGL
# 6207  Few Clouds at 1700 meters AGL, Few Clouds at 2...
# 6214                    Sky Clear below 3700 meters AGL
#
#                                                 WEATHER  \
# 5956       No significant weather present at this time.
# 5957                                         Light Rain
# 5958       No significant weather present at this time.
# 5959  Automated observation with no human augmentati...
# 6070  Automated observation with no human augmentati...
# 6071  Automated observation with no human augmentati...
# 6088  Automated observation with no human augmentati...
# 6089  Automated observation with no human augmentati...
# 6098  Automated observation with no human augmentati...
# 6099  Automated observation with no human augmentati...
# 6100       No significant weather present at this time.
# 6106  Automated observation with no human augmentati...
# 6107                          Light Drizzle, Sand Storm
# 6108  Automated observation with no human augmentati...
# 6109  Automated observation with no human augmentati...
# 6113       No significant weather present at this time.
# 6120  Automated observation with no human augmentati...
# 6121  Automated observation with no human augmentati...
# 6125  Automated observation with no human augmentati...
# 6126  Automated observation with no human augmentati...
# 6127  Automated observation with no human augmentati...
# 6130  Automated observation with no human augmentati...
# 6131  Automated observation with no human augmentati...
# 6132  Automated observation with no human augmentati...
# 6133  Automated observation with no human augmentati...
# 6140       No significant weather present at this time.
# 6142       No significant weather present at this time.
# 6143                                   Light Rain, Mist
# 6162  Automated observation with no human augmentati...
# 6163  Automated observation with no human augmentati...
# 6195  Automated observation with no human augmentati...
# 6196  Automated observation with no human augmentati...
# 6207  Automated observation with no human augmentati...
# 6214  Automated observation with no human augmentati...
#
#                                                 REMARKS  HEAT_INDEX  LATITUDE  \
# 5956                                               <NA>        <NA>    62.886
# 5957  * Maintenance REQUIRED - readings may be compr...        <NA>     61.52
# 5958                                               <NA>        <NA>      67.5
# 5959  * Maintenance REQUIRED - readings may be compr...        <NA>    70.637
# 6070                 3-Hour Pressure Increasing: 0.1 mb        <NA>    34.024
# 6071                                               <NA>        <NA>      35.1
# 6088                                               <NA>        96.0      30.4
# 6089  * Maintenance REQUIRED - readings may be compr...        97.4      30.4
# 6098                                               <NA>        <NA>    32.986
# 6099                                               <NA>        <NA>      33.6
# 6100                                               <NA>        <NA>     32.37
# 6106                                               <NA>        <NA>      20.8
# 6107                                               <NA>        <NA>     20.97
# 6108                                               <NA>        <NA>      20.0
# 6109                                               <NA>        <NA>  42.08333
# 6113                                               <NA>        <NA>     41.73
# 6120                                               <NA>        <NA>     37.77
# 6121                                               <NA>        <NA>     37.33
# 6125  * Maintenance REQUIRED - readings may be compr...        <NA>     29.95
# 6126                                               <NA>        <NA>     29.35
# 6127                                               <NA>        <NA>     29.25
# 6130  * Maintenance REQUIRED - readings may be compr...        <NA>     47.58
# 6131                                               <NA>        <NA>    29.121
# 6132                                               <NA>        <NA>   46.2695
# 6133                                               <NA>        91.2   48.2834
# 6140  * Maintenance REQUIRED - readings may be compr...        78.9     42.05
# 6142                                               <NA>        <NA>     40.07
# 6143                                               <NA>        <NA>   41.7056
# 6162                                               <NA>        <NA>   39.6935
# 6163                                               <NA>        76.1     36.22
# 6195  * Maintenance REQUIRED - readings may be compr...        <NA>   31.8327
# 6196                                               <NA>        <NA>   31.1059
# 6207                                               <NA>        <NA>     37.85
# 6214                                               <NA>        <NA>     38.92
#
#      LONGITUDE FLT_CATEGORY  \
# 5956  -149.583          VFR
# 5957   -166.15          IFR
# 5958   -148.48          VFR
# 5959  -160.013          VFR
# 6070  -118.291         MVFR
# 6071   -120.62         <NA>
# 6088    -86.65          VFR
# 6089    -86.65          VFR
# 6098  -82.3827          VFR
# 6099    -83.13          VFR
# 6100    -82.07          VFR
# 6106   -156.02         <NA>
# 6107   -156.67         <NA>
# 6108   -155.67          VFR
# 6109 -87.81667          VFR
# 6113    -93.72         <NA>
# 6120    -97.12          VFR
# 6121    -88.12          VFR
# 6125    -90.07          VFR
# 6126    -89.43         <NA>
# 6127    -88.43          VFR
# 6130    -90.83         <NA>
# 6131   -89.547          VFR
# 6132   -106.62          VFR
# 6133  -115.492          IFR
# 6140 -101.0667          VFR
# 6142    -74.18          VFR
# 6143  -74.8004         LIFR
# 6162  -83.9896          VFR
# 6163    -95.33          VFR
# 6195  -104.809          VFR
# 6196  -98.1975          VFR
# 6207   -112.38          VFR
# 6214     -82.1          VFR
#
#                                                   SHAPE          State
# 5956  {"x": -16651503.3913, "y": 9072352.268600002, ...         Alaska
# 5957  {"x": -18495733.3953, "y": 8746212.867399998, ...         Alaska
# 5958  {"x": -16528717.993, "y": 10299995.503399998, ...         Alaska
# 5959  {"x": -17812565.6803, "y": 11279281.076499999,...         Alaska
# 6070  {"x": -13168093.885400001, "y": 4032025.095200...     California
# 6071  {"x": -13427356.9795, "y": 4177479.0622000024,...     California
# 6088  {"x": -9645833.8772, "y": 3555070.433799997, "...        Florida
# 6089  {"x": -9645833.8772, "y": 3555070.433799997, "...        Florida
# 6098  {"x": -9170800.2142, "y": 3893445.844999999, "...        Georgia
# 6099  {"x": -9253989.2696, "y": 3975217.4293000028, ...        Georgia
# 6100  {"x": -9135990.6094, "y": 3811977.4724999964, ...        Georgia
# 6106  {"x": -17368066.9536, "y": 2368046.6396000013,...         Hawaii
# 6107  {"x": -17440424.6226, "y": 2388301.7677999996,...         Hawaii
# 6108  {"x": -17329105.1318, "y": 2273030.927000001, ...         Hawaii
# 6109  {"x": -9775706.6165, "y": 5173470.558499999, "...       Illinois
# 6113  {"x": -10432862.6771, "y": 5120620.167099997, ...           Iowa
# 6120  {"x": -10811348.9458, "y": 4546985.284400001, ...         Kansas
# 6121  {"x": -9809473.5287, "y": 4485204.895800002, "...       Kentucky
# 6125  {"x": -10026546.5358, "y": 3497124.4274000004,...      Louisiana
# 6126  {"x": -9955302.0616, "y": 3420269.0613999963, ...      Louisiana
# 6127  {"x": -9843982.5708, "y": 3407504.076200001, "...      Louisiana
# 6130  {"x": -10111149.3488, "y": 6037264.071999997, ...      Minnesota
# 6131  {"x": -9968326.4421, "y": 3391055.656199999, "...    Mississippi
# 6132  {"x": -11868884.1084, "y": 5823642.465800002, ...        Montana
# 6133  {"x": -12856510.6307, "y": 6154132.6668, "spat...        Montana
# 6140  {"x": -11250689.8695, "y": 5168472.146600001, ...       Nebraska
# 6142  {"x": -8257679.827, "y": 4876119.708899997, "s...     New Jersey
# 6143  {"x": -8326742.439099999, "y": 5116981.2589000...       New York
# 6162  {"x": -9349679.5039, "y": 4821501.988399997, "...           Ohio
# 6163  {"x": -10612087.0573, "y": 4330935.410899997, ...       Oklahoma
# 6195  {"x": -11667284.5106, "y": 3741369.8814999983,...          Texas
# 6196  {"x": -10931295.6972, "y": 3646509.9246999994,...          Texas
# 6207  {"x": -12510084.375300001, "y": 4558257.461000...           Utah
# 6214  {"x": -9139330.1941, "y": 4710218.728799999, "...  West Virginia
#
# [34 rows x 24 columns]

# %%
sdfUSA.dtypes
# Out:
# OBJECTID                 Int64
# ICAO            string[python]
# OBS_DATETIME    datetime64[ns]
# STATION_NAME    string[python]
# COUNTRY                 object
# ELEVATION              Float64
# TEMP                   Float64
# DEW_POINT              Float64
# R_HUMIDITY               Int32
# WIND_DIRECT              Int32
# WIND_SPEED               Int32
# WIND_GUST                Int32
# WIND_CHILL             Float64
# VISIBILITY               Int32
# PRESSURE               Float64
# SKY_CONDTN      string[python]
# WEATHER         string[python]
# REMARKS         string[python]
# HEAT_INDEX             Float64
# LATITUDE               Float64
# LONGITUDE              Float64
# FLT_CATEGORY    string[python]
# SHAPE                 geometry
# State                   object
# dtype: object

# %% [markdown]
# So, let’s shortly describe what you will know after reading the blog post:
# 1.	how to split a DataFrame into a group;
# 2.	how select a group in the grouped DataFrame and filter the grouping data;
# 3.	how aggregate grouping data and how apply many function at once to the grouping data;

# %% [markdown]
# ### Splitting of a DataFrame into groups
#
# [[back to top]](#Table-of-Contents)
#
# pandas DataFrames can be split on any of their axes. Grouping denotes the providence of a mapping of labels to group names. Method `groupby()` is provided in pandas for grouping. The `groupby()` function returns a `GroupBy` object, but essentially describes how the rows of the original data set has been split.

# %%
sdfUSA_grouped = sdfUSA.groupby('State')
sdfUSA_grouped

# %%
sdfUSA_grouped['COUNTRY']

# %% [markdown]
# Use `list()` to show what a grouping looks like

# %%
list(sdfUSA_grouped)
# Out:
# [('Alaska',
#         OBJECTID  ICAO        OBS_DATETIME    STATION_NAME  \
#   5956      6060  PAEC 2024-01-16 16:51:00        Chulitna
#   5957      3767  PAHP 2022-09-17 01:32:00      Hooper Bay
#   5958      5937  PALR 2023-06-27 00:50:00  Chandalar Lake
#   5959      4180  PAWI 2024-04-29 23:53:00      Wainwright
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   5956   United States Of America      389.0  30.2       32.0         108
#   5957   United States Of America        8.0  51.8       46.4          82
#   5958   United States Of America      579.0  59.0       50.0          72
#   5959   United States Of America       12.0  12.9       10.0          88
#
#         WIND_DIRECT  ...  PRESSURE  \
#   5956           40  ...    1013.2
#   5957          180  ...     979.0
#   5958           70  ...    1008.1
#   5959           90  ...    1027.1
#
#                                                SKY_CONDTN  \
#   5956             Overcast Cloud Deck at 1300 meters AGL
#   5957              Overcast Cloud Deck at 730 meters AGL
#   5958  Broken Clouds at 1800 meters AGL, Overcast Clo...
#   5959                  Scattered Clouds at 60 meters AGL
#
#                                                   WEATHER  \
#   5956       No significant weather present at this time.
#   5957                                         Light Rain
#   5958       No significant weather present at this time.
#   5959  Automated observation with no human augmentati...
#
#                                                   REMARKS  HEAT_INDEX LATITUDE  \
#   5956                                               <NA>        <NA>   62.886
#   5957  * Maintenance REQUIRED - readings may be compr...        <NA>    61.52
#   5958                                               <NA>        <NA>     67.5
#   5959  * Maintenance REQUIRED - readings may be compr...        <NA>   70.637
#
#        LONGITUDE FLT_CATEGORY  \
#   5956  -149.583          VFR
#   5957   -166.15          IFR
#   5958   -148.48          VFR
#   5959  -160.013          VFR
#
#                                                     SHAPE   State
#   5956  {"x": -16651503.3913, "y": 9072352.268600002, ...  Alaska
#   5957  {"x": -18495733.3953, "y": 8746212.867399998, ...  Alaska
#   5958  {"x": -16528717.993, "y": 10299995.503399998, ...  Alaska
#   5959  {"x": -17812565.6803, "y": 11279281.076499999,...  Alaska
#
#   [4 rows x 24 columns]),
#  ('California',
#         OBJECTID  ICAO        OBS_DATETIME STATION_NAME  \
#   6070      4922  KCQT 2024-05-20 14:47:00  Los Angeles
#   6071       517  KL52 2023-04-09 16:55:00  Oceano Cnty
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6070   United States Of America       51.0  60.1       52.0          75
#   6071   United States Of America        3.0  55.4       55.4         100
#
#         WIND_DIRECT  ...  PRESSURE                             SKY_CONDTN  \
#   6070            0  ...    1016.3  Overcast Cloud Deck at 760 meters AGL
#   6071          250  ...    1020.3                                   <NA>
#
#                                                   WEATHER  \
#   6070  Automated observation with no human augmentati...
#   6071  Automated observation with no human augmentati...
#
#                                    REMARKS  HEAT_INDEX LATITUDE LONGITUDE  \
#   6070  3-Hour Pressure Increasing: 0.1 mb        <NA>   34.024  -118.291
#   6071                                <NA>        <NA>     35.1   -120.62
#
#        FLT_CATEGORY                                              SHAPE  \
#   6070         MVFR  {"x": -13168093.885400001, "y": 4032025.095200...
#   6071         <NA>  {"x": -13427356.9795, "y": 4177479.0622000024,...
#
#              State
#   6070  California
#   6071  California
#
#   [2 rows x 24 columns]),
#  ('Florida',
#         OBJECTID  ICAO        OBS_DATETIME STATION_NAME  \
#   6088      6002  KQBL 2024-06-14 22:55:00     Hurlbert
#   6089      6003  KQHY 2024-06-14 22:55:00     Hurlbert
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6088   United States Of America     9999.0  86.0       75.7          72
#   6089   United States Of America     9999.0  86.4       76.6          73
#
#         WIND_DIRECT  ...  PRESSURE                     SKY_CONDTN  \
#   6088         <NA>  ...    1012.5  Few Clouds at 2700 meters AGL
#   6089          220  ...    1012.2  Few Clouds at 2900 meters AGL
#
#                                                   WEATHER  \
#   6088  Automated observation with no human augmentati...
#   6089  Automated observation with no human augmentati...
#
#                                                   REMARKS  HEAT_INDEX LATITUDE  \
#   6088                                               <NA>        96.0     30.4
#   6089  * Maintenance REQUIRED - readings may be compr...        97.4     30.4
#
#        LONGITUDE FLT_CATEGORY  \
#   6088    -86.65          VFR
#   6089    -86.65          VFR
#
#                                                     SHAPE    State
#   6088  {"x": -9645833.8772, "y": 3555070.433799997, "...  Florida
#   6089  {"x": -9645833.8772, "y": 3555070.433799997, "...  Florida
#
#   [2 rows x 24 columns]),
#  ('Georgia',
#         OBJECTID  ICAO        OBS_DATETIME STATION_NAME  \
#   6098      1027  K2J3 2023-11-10 06:10:00   Louisville
#   6099      1014  K3J7 2023-05-03 14:30:00   Greensboro
#   6100      2936  KHME 2023-02-26 13:50:00       Metter
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6098   United States Of America       97.0  57.2       56.7          98
#   6099   United States Of America      207.0  60.8       33.8          36
#   6100   United States Of America       60.0  60.8       35.6          39
#
#         WIND_DIRECT  ...  PRESSURE                           SKY_CONDTN  \
#   6098            0  ...    1017.3      Sky Clear below 3700 meters AGL
#   6099          270  ...    1009.8      Sky Clear below 3700 meters AGL
#   6100          270  ...    1023.9  Scattered Clouds at 1100 meters AGL
#
#                                                   WEATHER  REMARKS  HEAT_INDEX  \
#   6098  Automated observation with no human augmentati...     <NA>        <NA>
#   6099  Automated observation with no human augmentati...     <NA>        <NA>
#   6100       No significant weather present at this time.     <NA>        <NA>
#
#        LATITUDE LONGITUDE FLT_CATEGORY  \
#   6098   32.986  -82.3827          VFR
#   6099     33.6    -83.13          VFR
#   6100    32.37    -82.07          VFR
#
#                                                     SHAPE    State
#   6098  {"x": -9170800.2142, "y": 3893445.844999999, "...  Georgia
#   6099  {"x": -9253989.2696, "y": 3975217.4293000028, ...  Georgia
#   6100  {"x": -9135990.6094, "y": 3811977.4724999964, ...  Georgia
#
#   [3 rows x 24 columns]),
#  ('Hawaii',
#         OBJECTID  ICAO        OBS_DATETIME      STATION_NAME  \
#   6106      5970  PHHN 2023-09-15 03:58:00              Hana
#   6107      5889  PHJH 2023-01-27 04:05:00  Lahaina/West Mau
#   6108      5971  PHMU 2023-09-15 04:00:00    Kamuela/Waimea
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6106   United States Of America       20.0  75.2       73.4          94
#   6107   United States Of America       67.0  <NA>       <NA>        <NA>
#   6108   United States Of America      809.0  66.2       64.4          94
#
#         WIND_DIRECT  ...  PRESSURE  \
#   6106            0  ...    1015.9
#   6107           20  ...    1016.2
#   6108           40  ...    1017.3
#
#                                                SKY_CONDTN  \
#   6106             Overcast Cloud Deck at 1300 meters AGL
#   6107  Scattered Clouds at 430 meters AGL, Scattered ...
#   6108  Scattered Clouds at 210 meters AGL, Broken Clo...
#
#                                                   WEATHER  REMARKS  HEAT_INDEX  \
#   6106  Automated observation with no human augmentati...     <NA>        <NA>
#   6107                          Light Drizzle, Sand Storm     <NA>        <NA>
#   6108  Automated observation with no human augmentati...     <NA>        <NA>
#
#        LATITUDE LONGITUDE FLT_CATEGORY  \
#   6106     20.8   -156.02         <NA>
#   6107    20.97   -156.67         <NA>
#   6108     20.0   -155.67          VFR
#
#                                                     SHAPE   State
#   6106  {"x": -17368066.9536, "y": 2368046.6396000013,...  Hawaii
#   6107  {"x": -17440424.6226, "y": 2388301.7677999996,...  Hawaii
#   6108  {"x": -17329105.1318, "y": 2273030.927000001, ...  Hawaii
#
#   [3 rows x 24 columns]),
#  ('Illinois',
#         OBJECTID  ICAO        OBS_DATETIME  STATION_NAME  \
#   6109      5840  KNBU 2022-12-13 08:00:00  Glenview Nas
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6109   United States Of America       <NA>  48.9       35.1          59
#
#         WIND_DIRECT  ...  PRESSURE                              SKY_CONDTN  \
#   6109          360  ...    1023.4  Overcast Cloud Deck at 1200 meters AGL
#
#                                                   WEATHER  REMARKS  HEAT_INDEX  \
#   6109  Automated observation with no human augmentati...     <NA>        <NA>
#
#         LATITUDE LONGITUDE FLT_CATEGORY  \
#   6109  42.08333 -87.81667          VFR
#
#                                                     SHAPE     State
#   6109  {"x": -9775706.6165, "y": 5173470.558499999, "...  Illinois
#
#   [1 rows x 24 columns]),
#  ('Iowa',
#         OBJECTID  ICAO        OBS_DATETIME      STATION_NAME  \
#   6113      5965  KDMX 2023-08-24 17:00:00  Johnston/Desmoin
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6113   United States Of America      299.0  <NA>       <NA>        <NA>
#
#         WIND_DIRECT  ...  PRESSURE  SKY_CONDTN  \
#   6113         <NA>  ...      <NA>        <NA>
#
#                                              WEATHER  REMARKS  HEAT_INDEX  \
#   6113  No significant weather present at this time.     <NA>        <NA>
#
#        LATITUDE LONGITUDE FLT_CATEGORY  \
#   6113    41.73    -93.72         <NA>
#
#                                                     SHAPE  State
#   6113  {"x": -10432862.6771, "y": 5120620.167099997, ...   Iowa
#
#   [1 rows x 24 columns]),
#  ('Kansas',
#         OBJECTID  ICAO        OBS_DATETIME STATION_NAME  \
#   6120      1045  K1K1 2022-12-29 06:10:00       Benton
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6120   United States Of America      411.0  46.9       29.7          51
#
#         WIND_DIRECT  ...  PRESSURE                       SKY_CONDTN  \
#   6120          240  ...    1002.4  Sky Clear below 3700 meters AGL
#
#                                                   WEATHER  REMARKS  HEAT_INDEX  \
#   6120  Automated observation with no human augmentati...     <NA>        <NA>
#
#        LATITUDE LONGITUDE FLT_CATEGORY  \
#   6120    37.77    -97.12          VFR
#
#                                                     SHAPE   State
#   6120  {"x": -10811348.9458, "y": 4546985.284400001, ...  Kansas
#
#   [1 rows x 24 columns]),
#  ('Kentucky',
#         OBJECTID  ICAO        OBS_DATETIME STATION_NAME  \
#   6121       985  K5M9 2022-11-09 15:35:00       Marion
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6121   United States Of America      199.0  68.2       37.6          32
#
#         WIND_DIRECT  ...  PRESSURE                       SKY_CONDTN  \
#   6121            0  ...    1027.1  Sky Clear below 3700 meters AGL
#
#                                                   WEATHER  REMARKS  HEAT_INDEX  \
#   6121  Automated observation with no human augmentati...     <NA>        <NA>
#
#        LATITUDE LONGITUDE FLT_CATEGORY  \
#   6121    37.33    -88.12          VFR
#
#                                                     SHAPE     State
#   6121  {"x": -9809473.5287, "y": 4485204.895800002, "...  Kentucky
#
#   [1 rows x 24 columns]),
#  ('Louisiana',
#         OBJECTID  ICAO        OBS_DATETIME      STATION_NAME  \
#   6125       107  K7N0 2023-01-26 18:56:00  New Orleans/Supe
#   6126       498  KLNQ 2023-08-25 13:46:00    Boothville Hel
#   6127       150  KVKY 2023-07-03 14:50:00    Main Pass 289C
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6125   United States Of America        0.0  52.0       36.0          54
#   6126   United States Of America        1.0 -35.7       <NA>        <NA>
#   6127   United States Of America       32.0  <NA>       <NA>        <NA>
#
#         WIND_DIRECT  ...  PRESSURE                       SKY_CONDTN  \
#   6125            0  ...    1026.7  Sky Clear below 3700 meters AGL
#   6126           70  ...    1016.2                             <NA>
#   6127          240  ...    1017.3  Sky Clear below 3700 meters AGL
#
#                                                   WEATHER  \
#   6125  Automated observation with no human augmentati...
#   6126  Automated observation with no human augmentati...
#   6127  Automated observation with no human augmentati...
#
#                                                   REMARKS  HEAT_INDEX LATITUDE  \
#   6125  * Maintenance REQUIRED - readings may be compr...        <NA>    29.95
#   6126                                               <NA>        <NA>    29.35
#   6127                                               <NA>        <NA>    29.25
#
#        LONGITUDE FLT_CATEGORY  \
#   6125    -90.07          VFR
#   6126    -89.43         <NA>
#   6127    -88.43          VFR
#
#                                                     SHAPE      State
#   6125  {"x": -10026546.5358, "y": 3497124.4274000004,...  Louisiana
#   6126  {"x": -9955302.0616, "y": 3420269.0613999963, ...  Louisiana
#   6127  {"x": -9843982.5708, "y": 3407504.076200001, "...  Louisiana
#
#   [3 rows x 24 columns]),
#  ('Minnesota',
#         OBJECTID  ICAO        OBS_DATETIME   STATION_NAME  \
#   6130      6104  KP61 2024-05-24 06:52:00  Tofte (Ramos)
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6130   United States Of America      241.0  43.0       41.0          93
#
#         WIND_DIRECT  ...  PRESSURE  SKY_CONDTN  \
#   6130            0  ...    1017.6        <NA>
#
#                                                   WEATHER  \
#   6130  Automated observation with no human augmentati...
#
#                                                   REMARKS  HEAT_INDEX LATITUDE  \
#   6130  * Maintenance REQUIRED - readings may be compr...        <NA>    47.58
#
#        LONGITUDE FLT_CATEGORY  \
#   6130    -90.83         <NA>
#
#                                                     SHAPE      State
#   6130  {"x": -10111149.3488, "y": 6037264.071999997, ...  Minnesota
#
#   [1 rows x 24 columns]),
#  ('Mississippi',
#         OBJECTID  ICAO        OBS_DATETIME    STATION_NAME  \
#   6131      5832  KDLP 2024-02-10 23:05:00  West Delta 27A
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6131   United States Of America       31.0  <NA>       <NA>        <NA>
#
#         WIND_DIRECT  ...  PRESSURE                       SKY_CONDTN  \
#   6131          180  ...    1008.8  Sky Clear below 3700 meters AGL
#
#                                                   WEATHER  REMARKS  HEAT_INDEX  \
#   6131  Automated observation with no human augmentati...     <NA>        <NA>
#
#        LATITUDE LONGITUDE FLT_CATEGORY  \
#   6131   29.121   -89.547          VFR
#
#                                                     SHAPE        State
#   6131  {"x": -9968326.4421, "y": 3391055.656199999, "...  Mississippi
#
#   [1 rows x 24 columns]),
#  ('Montana',
#         OBJECTID  ICAO        OBS_DATETIME STATION_NAME  \
#   6132      5683  K1S3 2024-04-30 20:15:00      Forsyth
#   6133      1618  KS59 2024-06-11 22:45:00        Libby
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6132   United States Of America      831.0  53.6       17.6          24
#   6133   United States Of America      793.0  80.6       80.6         100
#
#         WIND_DIRECT  ...  PRESSURE  SKY_CONDTN  \
#   6132          280  ...    1009.5        <NA>
#   6133          200  ...    1008.8        <NA>
#
#                                                   WEATHER  REMARKS  HEAT_INDEX  \
#   6132  Automated observation with no human augmentati...     <NA>        <NA>
#   6133  Automated observation with no human augmentati...     <NA>        91.2
#
#        LATITUDE LONGITUDE FLT_CATEGORY  \
#   6132  46.2695   -106.62          VFR
#   6133  48.2834  -115.492          IFR
#
#                                                     SHAPE    State
#   6132  {"x": -11868884.1084, "y": 5823642.465800002, ...  Montana
#   6133  {"x": -12856510.6307, "y": 6154132.6668, "spat...  Montana
#
#   [2 rows x 24 columns]),
#  ('Nebraska',
#         OBJECTID  ICAO        OBS_DATETIME STATION_NAME  \
#   6140      5691  KMHN 2022-08-31 01:58:00       Mullen
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6140   United States Of America       <NA>  78.4       53.4          42
#
#         WIND_DIRECT  ...  PRESSURE                        SKY_CONDTN  \
#   6140           30  ...    1023.0  Broken Clouds at 4300 meters AGL
#
#                                              WEATHER  \
#   6140  No significant weather present at this time.
#
#                                                   REMARKS  HEAT_INDEX LATITUDE  \
#   6140  * Maintenance REQUIRED - readings may be compr...        78.9    42.05
#
#        LONGITUDE FLT_CATEGORY  \
#   6140 -101.0667          VFR
#
#                                                     SHAPE     State
#   6140  {"x": -11250689.8695, "y": 5168472.146600001, ...  Nebraska
#
#   [1 rows x 24 columns]),
#  ('New Jersey',
#         OBJECTID  ICAO        OBS_DATETIME STATION_NAME  \
#   6142      5977  KN12 2023-10-09 15:55:00     Lakewood
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6142   United States Of America       13.0  68.5       38.5          33
#
#         WIND_DIRECT  ...  PRESSURE                     SKY_CONDTN  \
#   6142          360  ...    1023.0  Few Clouds at 3700 meters AGL
#
#                                              WEATHER  REMARKS  HEAT_INDEX  \
#   6142  No significant weather present at this time.     <NA>        <NA>
#
#        LATITUDE LONGITUDE FLT_CATEGORY  \
#   6142    40.07    -74.18          VFR
#
#                                                     SHAPE       State
#   6142  {"x": -8257679.827, "y": 4876119.708899997, "s...  New Jersey
#
#   [1 rows x 24 columns]),
#  ('New York',
#         OBJECTID  ICAO        OBS_DATETIME STATION_NAME  \
#   6143      3856  KMSV 2024-03-05 18:38:00   Monticello
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6143   United States Of America      427.0  42.8       41.0          93
#
#         WIND_DIRECT  ...  PRESSURE                             SKY_CONDTN  \
#   6143           90  ...    1019.0  Overcast Cloud Deck at 120 meters AGL
#
#                  WEATHER  REMARKS  HEAT_INDEX LATITUDE LONGITUDE FLT_CATEGORY  \
#   6143  Light Rain, Mist     <NA>        <NA>  41.7056  -74.8004         LIFR
#
#                                                     SHAPE     State
#   6143  {"x": -8326742.439099999, "y": 5116981.2589000...  New York
#
#   [1 rows x 24 columns]),
#  ('Ohio',
#         OBJECTID  ICAO        OBS_DATETIME    STATION_NAME  \
#   6162       585  KI19 2023-11-29 23:55:00  Dayton-Jackson
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6162   United States Of America      285.0  35.6       26.6          69
#
#         WIND_DIRECT  ...  PRESSURE                       SKY_CONDTN  \
#   6162          210  ...    1016.3  Sky Clear below 3700 meters AGL
#
#                                                   WEATHER  REMARKS  HEAT_INDEX  \
#   6162  Automated observation with no human augmentati...     <NA>        <NA>
#
#        LATITUDE LONGITUDE FLT_CATEGORY  \
#   6162  39.6935  -83.9896          VFR
#
#                                                     SHAPE  State
#   6162  {"x": -9349679.5039, "y": 4821501.988399997, "...   Ohio
#
#   [1 rows x 24 columns]),
#  ('Oklahoma',
#         OBJECTID  ICAO        OBS_DATETIME STATION_NAME  \
#   6163       631  KH71 2023-04-14 15:35:00        Pryor
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6163   United States Of America      190.0  71.6       53.6          53
#
#         WIND_DIRECT  ...  PRESSURE                       SKY_CONDTN  \
#   6163          170  ...    1006.8  Sky Clear below 3700 meters AGL
#
#                                                   WEATHER  REMARKS  HEAT_INDEX  \
#   6163  Automated observation with no human augmentati...     <NA>        76.1
#
#        LATITUDE LONGITUDE FLT_CATEGORY  \
#   6163    36.22    -95.33          VFR
#
#                                                     SHAPE     State
#   6163  {"x": -10612087.0573, "y": 4330935.410899997, ...  Oklahoma
#
#   [1 rows x 24 columns]),
#  ('Texas',
#         OBJECTID  ICAO        OBS_DATETIME    STATION_NAME  \
#   6195      4754  KGDP 2023-12-11 00:51:00  Guadalupe Pass
#   6196      2260  KLZZ 2024-04-03 14:35:00        Lampasas
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6195   United States Of America     1664.0  41.0        8.1          25
#   6196   United States Of America      356.0  60.3       37.9          43
#
#         WIND_DIRECT  ...  PRESSURE                       SKY_CONDTN  \
#   6195          230  ...    1022.7                             <NA>
#   6196          300  ...    1016.9  Sky Clear below 3700 meters AGL
#
#                                                   WEATHER  \
#   6195  Automated observation with no human augmentati...
#   6196  Automated observation with no human augmentati...
#
#                                                   REMARKS  HEAT_INDEX LATITUDE  \
#   6195  * Maintenance REQUIRED - readings may be compr...        <NA>  31.8327
#   6196                                               <NA>        <NA>  31.1059
#
#        LONGITUDE FLT_CATEGORY  \
#   6195  -104.809          VFR
#   6196  -98.1975          VFR
#
#                                                     SHAPE  State
#   6195  {"x": -11667284.5106, "y": 3741369.8814999983,...  Texas
#   6196  {"x": -10931295.6972, "y": 3646509.9246999994,...  Texas
#
#   [2 rows x 24 columns]),
#  ('Utah',
#         OBJECTID  ICAO        OBS_DATETIME STATION_NAME  \
#   6207       175  KU55 2023-08-20 09:55:00    Panguitch
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6207   United States Of America     2060.0  57.2       55.4          94
#
#         WIND_DIRECT  ...  PRESSURE  \
#   6207            0  ...    1024.7
#
#                                                SKY_CONDTN  \
#   6207  Few Clouds at 1700 meters AGL, Few Clouds at 2...
#
#                                                   WEATHER  REMARKS  HEAT_INDEX  \
#   6207  Automated observation with no human augmentati...     <NA>        <NA>
#
#        LATITUDE LONGITUDE FLT_CATEGORY  \
#   6207    37.85   -112.38          VFR
#
#                                                     SHAPE  State
#   6207  {"x": -12510084.375300001, "y": 4558257.461000...   Utah
#
#   [1 rows x 24 columns]),
#  ('West Virginia',
#         OBJECTID  ICAO        OBS_DATETIME STATION_NAME  \
#   6214      1015  K3I2 2022-12-28 09:30:00  Pt Pleasant
#
#                           COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
#   6214   United States Of America      195.0  18.9       16.7          91
#
#         WIND_DIRECT  ...  PRESSURE                       SKY_CONDTN  \
#   6214            0  ...    1023.4  Sky Clear below 3700 meters AGL
#
#                                                   WEATHER  REMARKS  HEAT_INDEX  \
#   6214  Automated observation with no human augmentati...     <NA>        <NA>
#
#        LATITUDE LONGITUDE FLT_CATEGORY  \
#   6214    38.92     -82.1          VFR
#
#                                                     SHAPE          State
#   6214  {"x": -9139330.1941, "y": 4710218.728799999, "...  West Virginia
#
#   [1 rows x 24 columns])]

# %% [markdown]
# As it can be easily seen, the `GroupBy` object is a dictionary whose keys are the computed unique groups and corresponding values being the axis labels belonging to each group.

# %%
for key, value in list(sdfUSA_grouped)[:3]:
# if you want to see more values uncomment row below and comment the previous row
#for key, value in short_grouped:
    print (key)
    print (value)
# Out:
# Alaska
#       OBJECTID  ICAO        OBS_DATETIME    STATION_NAME  \
# 5956      6060  PAEC 2024-01-16 16:51:00        Chulitna
# 5957      3767  PAHP 2022-09-17 01:32:00      Hooper Bay
# 5958      5937  PALR 2023-06-27 00:50:00  Chandalar Lake
# 5959      4180  PAWI 2024-04-29 23:53:00      Wainwright
#
#                         COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
# 5956   United States Of America      389.0  30.2       32.0         108
# 5957   United States Of America        8.0  51.8       46.4          82
# 5958   United States Of America      579.0  59.0       50.0          72
# 5959   United States Of America       12.0  12.9       10.0          88
#
#       WIND_DIRECT  ...  PRESSURE  \
# 5956           40  ...    1013.2
# 5957          180  ...     979.0
# 5958           70  ...    1008.1
# 5959           90  ...    1027.1
#
#                                              SKY_CONDTN  \
# 5956             Overcast Cloud Deck at 1300 meters AGL
# 5957              Overcast Cloud Deck at 730 meters AGL
# 5958  Broken Clouds at 1800 meters AGL, Overcast Clo...
# 5959                  Scattered Clouds at 60 meters AGL
#
#                                                 WEATHER  \
# 5956       No significant weather present at this time.
# 5957                                         Light Rain
# 5958       No significant weather present at this time.
# 5959  Automated observation with no human augmentati...
#
#                                                 REMARKS  HEAT_INDEX LATITUDE  \
# 5956                                               <NA>        <NA>   62.886
# 5957  * Maintenance REQUIRED - readings may be compr...        <NA>    61.52
# 5958                                               <NA>        <NA>     67.5
# 5959  * Maintenance REQUIRED - readings may be compr...        <NA>   70.637
#
#      LONGITUDE FLT_CATEGORY  \
# 5956  -149.583          VFR
# 5957   -166.15          IFR
# 5958   -148.48          VFR
# 5959  -160.013          VFR
#
#                                                   SHAPE   State
# 5956  {"x": -16651503.3913, "y": 9072352.268600002, ...  Alaska
# 5957  {"x": -18495733.3953, "y": 8746212.867399998, ...  Alaska
# 5958  {"x": -16528717.993, "y": 10299995.503399998, ...  Alaska
# 5959  {"x": -17812565.6803, "y": 11279281.076499999,...  Alaska
#
# [4 rows x 24 columns]
# California
#       OBJECTID  ICAO        OBS_DATETIME STATION_NAME  \
# 6070      4922  KCQT 2024-05-20 14:47:00  Los Angeles
# 6071       517  KL52 2023-04-09 16:55:00  Oceano Cnty
#
#                         COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
# 6070   United States Of America       51.0  60.1       52.0          75
# 6071   United States Of America        3.0  55.4       55.4         100
#
#       WIND_DIRECT  ...  PRESSURE                             SKY_CONDTN  \
# 6070            0  ...    1016.3  Overcast Cloud Deck at 760 meters AGL
# 6071          250  ...    1020.3                                   <NA>
#
#                                                 WEATHER  \
# 6070  Automated observation with no human augmentati...
# 6071  Automated observation with no human augmentati...
#
#                                  REMARKS  HEAT_INDEX LATITUDE LONGITUDE  \
# 6070  3-Hour Pressure Increasing: 0.1 mb        <NA>   34.024  -118.291
# 6071                                <NA>        <NA>     35.1   -120.62
#
#      FLT_CATEGORY                                              SHAPE  \
# 6070         MVFR  {"x": -13168093.885400001, "y": 4032025.095200...
# 6071         <NA>  {"x": -13427356.9795, "y": 4177479.0622000024,...
#
#            State
# 6070  California
# 6071  California
#
# [2 rows x 24 columns]
# Florida
#       OBJECTID  ICAO        OBS_DATETIME STATION_NAME  \
# 6088      6002  KQBL 2024-06-14 22:55:00     Hurlbert
# 6089      6003  KQHY 2024-06-14 22:55:00     Hurlbert
#
#                         COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
# 6088   United States Of America     9999.0  86.0       75.7          72
# 6089   United States Of America     9999.0  86.4       76.6          73
#
#       WIND_DIRECT  ...  PRESSURE                     SKY_CONDTN  \
# 6088         <NA>  ...    1012.5  Few Clouds at 2700 meters AGL
# 6089          220  ...    1012.2  Few Clouds at 2900 meters AGL
#
#                                                 WEATHER  \
# 6088  Automated observation with no human augmentati...
# 6089  Automated observation with no human augmentati...
#
#                                                 REMARKS  HEAT_INDEX LATITUDE  \
# 6088                                               <NA>        96.0     30.4
# 6089  * Maintenance REQUIRED - readings may be compr...        97.4     30.4
#
#      LONGITUDE FLT_CATEGORY  \
# 6088    -86.65          VFR
# 6089    -86.65          VFR
#
#                                                   SHAPE    State
# 6088  {"x": -9645833.8772, "y": 3555070.433799997, "...  Florida
# 6089  {"x": -9645833.8772, "y": 3555070.433799997, "...  Florida
#
# [2 rows x 24 columns]

# %% [markdown]
# Besides, you may to see the first and the last item of each group

# %%
sdfUSA_grouped.first().head(10)
# Out:
#             OBJECTID  ICAO        OBS_DATETIME      STATION_NAME  \
# State
# Alaska          6060  PAEC 2024-01-16 16:51:00          Chulitna
# California      4922  KCQT 2024-05-20 14:47:00       Los Angeles
# Florida         6002  KQBL 2024-06-14 22:55:00          Hurlbert
# Georgia         1027  K2J3 2023-11-10 06:10:00        Louisville
# Hawaii          5970  PHHN 2023-09-15 03:58:00              Hana
# Illinois        5840  KNBU 2022-12-13 08:00:00      Glenview Nas
# Iowa            5965  KDMX 2023-08-24 17:00:00  Johnston/Desmoin
# Kansas          1045  K1K1 2022-12-29 06:10:00            Benton
# Kentucky         985  K5M9 2022-11-09 15:35:00            Marion
# Louisiana        107  K7N0 2023-01-26 18:56:00  New Orleans/Supe
#
#                               COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
# State
# Alaska       United States Of America      389.0  30.2       32.0         108
# California   United States Of America       51.0  60.1       52.0          75
# Florida      United States Of America     9999.0  86.0       75.7          72
# Georgia      United States Of America       97.0  57.2       56.7          98
# Hawaii       United States Of America       20.0  75.2       73.4          94
# Illinois     United States Of America       <NA>  48.9       35.1          59
# Iowa         United States Of America      299.0  <NA>       <NA>        <NA>
# Kansas       United States Of America      411.0  46.9       29.7          51
# Kentucky     United States Of America      199.0  68.2       37.6          32
# Louisiana    United States Of America        0.0  52.0       36.0          54
#
#             WIND_DIRECT  ...  VISIBILITY  PRESSURE  \
# State                    ...
# Alaska               40  ...       11000    1013.2
# California            0  ...       16000    1016.3
# Florida             220  ...       16000    1012.5
# Georgia               0  ...       16000    1017.3
# Hawaii                0  ...       14000    1015.9
# Illinois            360  ...       16000    1023.4
# Iowa               <NA>  ...        <NA>      <NA>
# Kansas              240  ...       16000    1002.4
# Kentucky              0  ...       16000    1027.1
# Louisiana             0  ...       16000    1026.7
#
#                                         SKY_CONDTN  \
# State
# Alaska      Overcast Cloud Deck at 1300 meters AGL
# California   Overcast Cloud Deck at 760 meters AGL
# Florida              Few Clouds at 2700 meters AGL
# Georgia            Sky Clear below 3700 meters AGL
# Hawaii      Overcast Cloud Deck at 1300 meters AGL
# Illinois    Overcast Cloud Deck at 1200 meters AGL
# Iowa                                          <NA>
# Kansas             Sky Clear below 3700 meters AGL
# Kentucky           Sky Clear below 3700 meters AGL
# Louisiana          Sky Clear below 3700 meters AGL
#
#                                                       WEATHER  \
# State
# Alaska           No significant weather present at this time.
# California  Automated observation with no human augmentati...
# Florida     Automated observation with no human augmentati...
# Georgia     Automated observation with no human augmentati...
# Hawaii      Automated observation with no human augmentati...
# Illinois    Automated observation with no human augmentati...
# Iowa             No significant weather present at this time.
# Kansas      Automated observation with no human augmentati...
# Kentucky    Automated observation with no human augmentati...
# Louisiana   Automated observation with no human augmentati...
#
#                                                       REMARKS HEAT_INDEX  \
# State
# Alaska      * Maintenance REQUIRED - readings may be compr...       <NA>
# California                 3-Hour Pressure Increasing: 0.1 mb       <NA>
# Florida     * Maintenance REQUIRED - readings may be compr...       96.0
# Georgia                                                  <NA>       <NA>
# Hawaii                                                   <NA>       <NA>
# Illinois                                                 <NA>       <NA>
# Iowa                                                     <NA>       <NA>
# Kansas                                                   <NA>       <NA>
# Kentucky                                                 <NA>       <NA>
# Louisiana   * Maintenance REQUIRED - readings may be compr...       <NA>
#
#             LATITUDE LONGITUDE  FLT_CATEGORY  \
# State
# Alaska        62.886  -149.583           VFR
# California    34.024  -118.291          MVFR
# Florida         30.4    -86.65           VFR
# Georgia       32.986  -82.3827           VFR
# Hawaii          20.8   -156.02           VFR
# Illinois    42.08333 -87.81667           VFR
# Iowa           41.73    -93.72          <NA>
# Kansas         37.77    -97.12           VFR
# Kentucky       37.33    -88.12           VFR
# Louisiana      29.95    -90.07           VFR
#
#                                                         SHAPE
# State
# Alaska      {"x": -16651503.3913, "y": 9072352.268600002, ...
# California  {"x": -13168093.885400001, "y": 4032025.095200...
# Florida     {"x": -9645833.8772, "y": 3555070.433799997, "...
# Georgia     {"x": -9170800.2142, "y": 3893445.844999999, "...
# Hawaii      {"x": -17368066.9536, "y": 2368046.6396000013,...
# Illinois    {"x": -9775706.6165, "y": 5173470.558499999, "...
# Iowa        {"x": -10432862.6771, "y": 5120620.167099997, ...
# Kansas      {"x": -10811348.9458, "y": 4546985.284400001, ...
# Kentucky    {"x": -9809473.5287, "y": 4485204.895800002, "...
# Louisiana   {"x": -10026546.5358, "y": 3497124.4274000004,...
#
# [10 rows x 23 columns]

# %%
sdfUSA_grouped.last().head(10)
# Out:
#             OBJECTID  ICAO        OBS_DATETIME      STATION_NAME  \
# State
# Alaska          4180  PAWI 2024-04-29 23:53:00        Wainwright
# California       517  KL52 2023-04-09 16:55:00       Oceano Cnty
# Florida         6003  KQHY 2024-06-14 22:55:00          Hurlbert
# Georgia         2936  KHME 2023-02-26 13:50:00            Metter
# Hawaii          5971  PHMU 2023-09-15 04:00:00    Kamuela/Waimea
# Illinois        5840  KNBU 2022-12-13 08:00:00      Glenview Nas
# Iowa            5965  KDMX 2023-08-24 17:00:00  Johnston/Desmoin
# Kansas          1045  K1K1 2022-12-29 06:10:00            Benton
# Kentucky         985  K5M9 2022-11-09 15:35:00            Marion
# Louisiana        150  KVKY 2023-07-03 14:50:00    Main Pass 289C
#
#                               COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
# State
# Alaska       United States Of America       12.0  12.9       10.0          88
# California   United States Of America        3.0  55.4       55.4         100
# Florida      United States Of America     9999.0  86.4       76.6          73
# Georgia      United States Of America       60.0  60.8       35.6          39
# Hawaii       United States Of America      809.0  66.2       64.4          94
# Illinois     United States Of America       <NA>  48.9       35.1          59
# Iowa         United States Of America      299.0  <NA>       <NA>        <NA>
# Kansas       United States Of America      411.0  46.9       29.7          51
# Kentucky     United States Of America      199.0  68.2       37.6          32
# Louisiana    United States Of America       32.0 -35.7       36.0          54
#
#             WIND_DIRECT  ...  VISIBILITY  PRESSURE  \
# State                    ...
# Alaska               90  ...       16000    1027.1
# California          250  ...       13000    1020.3
# Florida             220  ...       16000    1012.2
# Georgia             270  ...       10000    1023.9
# Hawaii               40  ...       14000    1017.3
# Illinois            360  ...       16000    1023.4
# Iowa               <NA>  ...        <NA>      <NA>
# Kansas              240  ...       16000    1002.4
# Kentucky              0  ...       16000    1027.1
# Louisiana           240  ...       16000    1017.3
#
#                                                    SKY_CONDTN  \
# State
# Alaska                      Scattered Clouds at 60 meters AGL
# California              Overcast Cloud Deck at 760 meters AGL
# Florida                         Few Clouds at 2900 meters AGL
# Georgia                   Scattered Clouds at 1100 meters AGL
# Hawaii      Scattered Clouds at 210 meters AGL, Broken Clo...
# Illinois               Overcast Cloud Deck at 1200 meters AGL
# Iowa                                                     <NA>
# Kansas                        Sky Clear below 3700 meters AGL
# Kentucky                      Sky Clear below 3700 meters AGL
# Louisiana                     Sky Clear below 3700 meters AGL
#
#                                                       WEATHER  \
# State
# Alaska      Automated observation with no human augmentati...
# California  Automated observation with no human augmentati...
# Florida     Automated observation with no human augmentati...
# Georgia          No significant weather present at this time.
# Hawaii      Automated observation with no human augmentati...
# Illinois    Automated observation with no human augmentati...
# Iowa             No significant weather present at this time.
# Kansas      Automated observation with no human augmentati...
# Kentucky    Automated observation with no human augmentati...
# Louisiana   Automated observation with no human augmentati...
#
#                                                       REMARKS HEAT_INDEX  \
# State
# Alaska      * Maintenance REQUIRED - readings may be compr...       <NA>
# California                 3-Hour Pressure Increasing: 0.1 mb       <NA>
# Florida     * Maintenance REQUIRED - readings may be compr...       97.4
# Georgia                                                  <NA>       <NA>
# Hawaii                                                   <NA>       <NA>
# Illinois                                                 <NA>       <NA>
# Iowa                                                     <NA>       <NA>
# Kansas                                                   <NA>       <NA>
# Kentucky                                                 <NA>       <NA>
# Louisiana   * Maintenance REQUIRED - readings may be compr...       <NA>
#
#             LATITUDE LONGITUDE  FLT_CATEGORY  \
# State
# Alaska        70.637  -160.013           VFR
# California      35.1   -120.62          MVFR
# Florida         30.4    -86.65           VFR
# Georgia        32.37    -82.07           VFR
# Hawaii          20.0   -155.67           VFR
# Illinois    42.08333 -87.81667           VFR
# Iowa           41.73    -93.72          <NA>
# Kansas         37.77    -97.12           VFR
# Kentucky       37.33    -88.12           VFR
# Louisiana      29.25    -88.43           VFR
#
#                                                         SHAPE
# State
# Alaska      {"x": -17812565.6803, "y": 11279281.076499999,...
# California  {"x": -13427356.9795, "y": 4177479.0622000024,...
# Florida     {"x": -9645833.8772, "y": 3555070.433799997, "...
# Georgia     {"x": -9135990.6094, "y": 3811977.4724999964, ...
# Hawaii      {"x": -17329105.1318, "y": 2273030.927000001, ...
# Illinois    {"x": -9775706.6165, "y": 5173470.558499999, "...
# Iowa        {"x": -10432862.6771, "y": 5120620.167099997, ...
# Kansas      {"x": -10811348.9458, "y": 4546985.284400001, ...
# Kentucky    {"x": -9809473.5287, "y": 4485204.895800002, "...
# Louisiana   {"x": -9843982.5708, "y": 3407504.076200001, "...
#
# [10 rows x 23 columns]

# %% [markdown]
# ### Selection and filtering
#
# [[back to top]](#Table-of-Contents)
#
# Functions of descriptive statistic like `sum()`, `count()`, `max()`, `min()`, `mean()` can be quickly applied to the `GroupBy` object to obtain summary statistics for each group – an immensely useful function. The same statement is valid also for functions like `describe()` which return general information about an object.
#
# Let’s show a few examples of descriptive statistic function application to the `GroupBy` object

# %%
sdfUSA_grouped.count().head(10)
# Out:
#             OBJECTID  ICAO  OBS_DATETIME  STATION_NAME  COUNTRY  ELEVATION  \
# State
# Alaska             4     4             4             4        4          4
# California         2     2             2             2        2          2
# Florida            2     2             2             2        2          2
# Georgia            3     3             3             3        3          3
# Hawaii             3     3             3             3        3          3
# Illinois           1     1             1             1        1          0
# Iowa               1     1             1             1        1          1
# Kansas             1     1             1             1        1          1
# Kentucky           1     1             1             1        1          1
# Louisiana          3     3             3             3        3          3
#
#             TEMP  DEW_POINT  R_HUMIDITY  WIND_DIRECT  ...  VISIBILITY  \
# State                                                 ...
# Alaska         4          4           4            4  ...           4
# California     2          2           2            2  ...           2
# Florida        2          2           2            1  ...           2
# Georgia        3          3           3            3  ...           3
# Hawaii         2          2           2            3  ...           1
# Illinois       1          1           1            1  ...           1
# Iowa           0          0           0            0  ...           0
# Kansas         1          1           1            1  ...           1
# Kentucky       1          1           1            1  ...           1
# Louisiana      2          1           1            3  ...           3
#
#             PRESSURE  SKY_CONDTN  WEATHER  REMARKS  HEAT_INDEX  LATITUDE  \
# State
# Alaska             4           4        4        2           0         4
# California         2           1        2        1           0         2
# Florida            2           2        2        1           2         2
# Georgia            3           3        3        0           0         3
# Hawaii             3           3        3        0           0         3
# Illinois           1           1        1        0           0         1
# Iowa               0           0        1        0           0         1
# Kansas             1           1        1        0           0         1
# Kentucky           1           1        1        0           0         1
# Louisiana          3           2        3        1           0         3
#
#             LONGITUDE  FLT_CATEGORY  SHAPE
# State
# Alaska              4             4      4
# California          2             1      2
# Florida             2             2      2
# Georgia             3             3      3
# Hawaii              3             1      3
# Illinois            1             1      1
# Iowa                1             0      1
# Kansas              1             1      1
# Kentucky            1             1      1
# Louisiana           3             2      3
#
# [10 rows x 23 columns]

# %%
sdfUSA_grouped.sum(numeric_only=True).add_prefix('sum_of_').head(10)  
# calculate the sum only for numeric columns, 
# all columns with other types will be ignored and missed
# we have add also common prefics to all columns. It's very convenient
# Out:
#             sum_of_OBJECTID  sum_of_ELEVATION  sum_of_TEMP  sum_of_DEW_POINT  \
# State
# Alaska                19944             988.0        153.9             138.4
# California             5439              54.0        115.5             107.4
# Florida               12005           19998.0        172.4             152.3
# Georgia                4977             364.0        178.8             126.1
# Hawaii                17830             896.0        141.4             137.8
# Illinois               5840               0.0         48.9              35.1
# Iowa                   5965             299.0          0.0               0.0
# Kansas                 1045             411.0         46.9              29.7
# Kentucky                985             199.0         68.2              37.6
# Louisiana               755              33.0         16.3              36.0
#
#             sum_of_R_HUMIDITY  sum_of_WIND_DIRECT  sum_of_WIND_SPEED  \
# State
# Alaska                    350                 380                120
# California                175                 250                  9
# Florida                   145                 220                 12
# Georgia                   173                 540                 18
# Hawaii                    188                  60                 48
# Illinois                   59                 360                 20
# Iowa                        0                   0                  0
# Kansas                     51                 240                  6
# Kentucky                   32                   0                  0
# Louisiana                  54                 310                 31
#
#             sum_of_WIND_GUST  sum_of_WIND_CHILL  sum_of_VISIBILITY  \
# State
# Alaska                   106               25.8              78200
# California                 0                0.0              29000
# Florida                    0                0.0              32000
# Georgia                    0                0.0              42000
# Hawaii                    72                0.0              14000
# Illinois                   0               43.8              16000
# Iowa                       0                0.0                  0
# Kansas                     0               45.8              16000
# Kentucky                   0                0.0              16000
# Louisiana                  0              -57.7              48000
#
#             sum_of_PRESSURE  sum_of_HEAT_INDEX  sum_of_LATITUDE  \
# State
# Alaska               4027.4                0.0          262.543
# California           2036.6                0.0           69.124
# Florida              2024.7              193.4             60.8
# Georgia              3051.0                0.0           98.956
# Hawaii               3049.4                0.0            61.77
# Illinois             1023.4                0.0         42.08333
# Iowa                    0.0                0.0            41.73
# Kansas               1002.4                0.0            37.77
# Kentucky             1027.1                0.0            37.33
# Louisiana            3060.2                0.0            88.55
#
#             sum_of_LONGITUDE
# State
# Alaska              -624.226
# California          -238.911
# Florida               -173.3
# Georgia            -247.5827
# Hawaii               -468.36
# Illinois           -87.81667
# Iowa                  -93.72
# Kansas                -97.12
# Kentucky              -88.12
# Louisiana            -267.93

# %%
sdfUSA_grouped.mean(numeric_only=True)
# Out:
#                   OBJECTID   ELEVATION    TEMP  DEW_POINT  R_HUMIDITY  \
# State
# Alaska              4986.0       247.0  38.475       34.6        87.5
# California          2719.5        27.0   57.75       53.7        87.5
# Florida             6002.5      9999.0    86.2      76.15        72.5
# Georgia             1659.0  121.333333    59.6  42.033333   57.666667
# Hawaii         5943.333333  298.666667    70.7       68.9        94.0
# Illinois            5840.0        <NA>    48.9       35.1        59.0
# Iowa                5965.0       299.0    <NA>       <NA>        <NA>
# Kansas              1045.0       411.0    46.9       29.7        51.0
# Kentucky             985.0       199.0    68.2       37.6        32.0
# Louisiana       251.666667        11.0    8.15       36.0        54.0
# Minnesota           6104.0       241.0    43.0       41.0        93.0
# Mississippi         5832.0        31.0    <NA>       <NA>        <NA>
# Montana             3650.5       812.0    67.1       49.1        62.0
# Nebraska            5691.0        <NA>    78.4       53.4        42.0
# New Jersey          5977.0        13.0    68.5       38.5        33.0
# New York            3856.0       427.0    42.8       41.0        93.0
# Ohio                 585.0       285.0    35.6       26.6        69.0
# Oklahoma             631.0       190.0    71.6       53.6        53.0
# Texas               3507.0      1010.0   50.65       23.0        34.0
# Utah                 175.0      2060.0    57.2       55.4        94.0
# West Virginia       1015.0       195.0    18.9       16.7        91.0
#
#                WIND_DIRECT  WIND_SPEED  WIND_GUST  WIND_CHILL  VISIBILITY  \
# State
# Alaska                95.0        30.0       26.5        12.9     19550.0
# California           125.0         4.5        0.0        <NA>     14500.0
# Florida              220.0         6.0        0.0        <NA>     16000.0
# Georgia              180.0         6.0        0.0        <NA>     14000.0
# Hawaii                20.0        16.0       24.0        <NA>     14000.0
# Illinois             360.0        20.0        0.0        43.8     16000.0
# Iowa                  <NA>         0.0        0.0        <NA>        <NA>
# Kansas               240.0         6.0        0.0        45.8     16000.0
# Kentucky               0.0         0.0        0.0        <NA>     16000.0
# Louisiana       103.333333   10.333333        0.0       -57.7     16000.0
# Minnesota              0.0         0.0        0.0        62.4        <NA>
# Mississippi          180.0        17.0       31.0        <NA>     16000.0
# Montana              240.0        28.0       41.5        <NA>      9400.0
# Nebraska              30.0        17.0        0.0        <NA>     16000.0
# New Jersey           360.0         0.0        0.0        <NA>     10000.0
# New York              90.0        13.0        0.0        37.9      4800.0
# Ohio                 210.0        13.0        0.0        29.2     16000.0
# Oklahoma             170.0        20.0       35.0        <NA>     16000.0
# Texas                265.0        30.5        0.0        29.6     16000.0
# Utah                   0.0         0.0        0.0        <NA>     16000.0
# West Virginia          0.0         0.0        0.0        47.4     16000.0
#
#                   PRESSURE  HEAT_INDEX   LATITUDE  LONGITUDE
# State
# Alaska             1006.85        <NA>   65.63575  -156.0565
# California          1018.3        <NA>     34.562  -119.4555
# Florida            1012.35        96.7       30.4     -86.65
# Georgia             1017.0        <NA>  32.985333 -82.527567
# Hawaii         1016.466667        <NA>      20.59    -156.12
# Illinois            1023.4        <NA>   42.08333  -87.81667
# Iowa                  <NA>        <NA>      41.73     -93.72
# Kansas              1002.4        <NA>      37.77     -97.12
# Kentucky            1027.1        <NA>      37.33     -88.12
# Louisiana      1020.066667        <NA>  29.516667     -89.31
# Minnesota           1017.6        <NA>      47.58     -90.83
# Mississippi         1008.8        <NA>     29.121    -89.547
# Montana            1009.15        91.2   47.27645   -111.056
# Nebraska            1023.0        78.9      42.05  -101.0667
# New Jersey          1023.0        <NA>      40.07     -74.18
# New York            1019.0        <NA>    41.7056   -74.8004
# Ohio                1016.3        <NA>    39.6935   -83.9896
# Oklahoma            1006.8        76.1      36.22     -95.33
# Texas               1019.8        <NA>    31.4693 -101.50325
# Utah                1024.7        <NA>      37.85    -112.38
# West Virginia       1023.4        <NA>      38.92      -82.1

# %%
sdfUSA.groupby(['State'])['TEMP'].mean()
# calculate sum for a single column
# it works more quickly then movies.groupby(['State']).mean()['TEMP'] becuase it sheads the data it does not need before the mean operation
# Out:
# State
# Alaska           38.475
# California        57.75
# Florida            86.2
# Georgia            59.6
# Hawaii             70.7
# Illinois           48.9
# Iowa               <NA>
# Kansas             46.9
# Kentucky           68.2
# Louisiana          8.15
# Minnesota          43.0
# Mississippi        <NA>
# Montana            67.1
# Nebraska           78.4
# New Jersey         68.5
# New York           42.8
# Ohio               35.6
# Oklahoma           71.6
# Texas             50.65
# Utah               57.2
# West Virginia      18.9
# Name: TEMP, dtype: Float64

# %%
sdfUSA.groupby(['State', 'STATION_NAME']).sum(numeric_only=True)
# it is possible to group by many columns
# pay your attention that the changing of the order of 
# columns for grouping in 
# its list also changes the result table
# Out:
#                                 OBJECTID  ELEVATION   TEMP  DEW_POINT  \
# State         STATION_NAME
# Alaska        Chandalar Lake        5937      579.0   59.0       50.0
#               Chulitna              6060      389.0   30.2       32.0
#               Hooper Bay            3767        8.0   51.8       46.4
#               Wainwright            4180       12.0   12.9       10.0
# California    Los Angeles           4922       51.0   60.1       52.0
#               Oceano Cnty            517        3.0   55.4       55.4
# Florida       Hurlbert             12005    19998.0  172.4      152.3
# Georgia       Greensboro            1014      207.0   60.8       33.8
#               Louisville            1027       97.0   57.2       56.7
#               Metter                2936       60.0   60.8       35.6
# Hawaii        Hana                  5970       20.0   75.2       73.4
#               Kamuela/Waimea        5971      809.0   66.2       64.4
#               Lahaina/West Mau      5889       67.0    0.0        0.0
# Illinois      Glenview Nas          5840        0.0   48.9       35.1
# Iowa          Johnston/Desmoin      5965      299.0    0.0        0.0
# Kansas        Benton                1045      411.0   46.9       29.7
# Kentucky      Marion                 985      199.0   68.2       37.6
# Louisiana     Boothville Hel         498        1.0  -35.7        0.0
#               Main Pass 289C         150       32.0    0.0        0.0
#               New Orleans/Supe       107        0.0   52.0       36.0
# Minnesota     Tofte (Ramos)         6104      241.0   43.0       41.0
# Mississippi   West Delta 27A        5832       31.0    0.0        0.0
# Montana       Forsyth               5683      831.0   53.6       17.6
#               Libby                 1618      793.0   80.6       80.6
# Nebraska      Mullen                5691        0.0   78.4       53.4
# New Jersey    Lakewood              5977       13.0   68.5       38.5
# New York      Monticello            3856      427.0   42.8       41.0
# Ohio          Dayton-Jackson         585      285.0   35.6       26.6
# Oklahoma      Pryor                  631      190.0   71.6       53.6
# Texas         Guadalupe Pass        4754     1664.0   41.0        8.1
#               Lampasas              2260      356.0   60.3       37.9
# Utah          Panguitch              175     2060.0   57.2       55.4
# West Virginia Pt Pleasant           1015      195.0   18.9       16.7
#
#                                 R_HUMIDITY  WIND_DIRECT  WIND_SPEED  \
# State         STATION_NAME
# Alaska        Chandalar Lake            72           70          13
#               Chulitna                 108           40          19
#               Hooper Bay                82          180          81
#               Wainwright                88           90           7
# California    Los Angeles               75            0           0
#               Oceano Cnty              100          250           9
# Florida       Hurlbert                 145          220          12
# Georgia       Greensboro                36          270           7
#               Louisville                98            0           0
#               Metter                    39          270          11
# Hawaii        Hana                      94            0           0
#               Kamuela/Waimea            94           40          28
#               Lahaina/West Mau           0           20          20
# Illinois      Glenview Nas              59          360          20
# Iowa          Johnston/Desmoin           0            0           0
# Kansas        Benton                    51          240           6
# Kentucky      Marion                    32            0           0
# Louisiana     Boothville Hel             0           70          13
#               Main Pass 289C             0          240           9
#               New Orleans/Supe          54            0           9
# Minnesota     Tofte (Ramos)             93            0           0
# Mississippi   West Delta 27A             0          180          17
# Montana       Forsyth                   24          280          37
#               Libby                    100          200          19
# Nebraska      Mullen                    42           30          17
# New Jersey    Lakewood                  33          360           0
# New York      Monticello                93           90          13
# Ohio          Dayton-Jackson            69          210          13
# Oklahoma      Pryor                     53          170          20
# Texas         Guadalupe Pass            25          230          50
#               Lampasas                  43          300          11
# Utah          Panguitch                 94            0           0
# West Virginia Pt Pleasant               91            0           0
#
#                                 WIND_GUST  WIND_CHILL  VISIBILITY  PRESSURE  \
# State         STATION_NAME
# Alaska        Chandalar Lake            0         0.0       48000    1008.1
#               Chulitna                  0        20.7       11000    1013.2
#               Hooper Bay              106         0.0        3200     979.0
#               Wainwright                0         5.1       16000    1027.1
# California    Los Angeles               0         0.0       16000    1016.3
#               Oceano Cnty               0         0.0       13000    1020.3
# Florida       Hurlbert                  0         0.0       32000    2024.7
# Georgia       Greensboro                0         0.0       16000    1009.8
#               Louisville                0         0.0       16000    1017.3
#               Metter                    0         0.0       10000    1023.9
# Hawaii        Hana                      0         0.0           0    1015.9
#               Kamuela/Waimea           41         0.0       14000    1017.3
#               Lahaina/West Mau         31         0.0           0    1016.2
# Illinois      Glenview Nas              0        43.8       16000    1023.4
# Iowa          Johnston/Desmoin          0         0.0           0       0.0
# Kansas        Benton                    0        45.8       16000    1002.4
# Kentucky      Marion                    0         0.0       16000    1027.1
# Louisiana     Boothville Hel            0       -57.7       16000    1016.2
#               Main Pass 289C            0         0.0       16000    1017.3
#               New Orleans/Supe          0         0.0       16000    1026.7
# Minnesota     Tofte (Ramos)             0        62.4           0    1017.6
# Mississippi   West Delta 27A           31         0.0       16000    1008.8
# Montana       Forsyth                  44         0.0       16000    1009.5
#               Libby                    39         0.0        2800    1008.8
# Nebraska      Mullen                    0         0.0       16000    1023.0
# New Jersey    Lakewood                  0         0.0       10000    1023.0
# New York      Monticello                0        37.9        4800    1019.0
# Ohio          Dayton-Jackson            0        29.2       16000    1016.3
# Oklahoma      Pryor                    35         0.0       16000    1006.8
# Texas         Guadalupe Pass            0        29.6       16000    1022.7
#               Lampasas                  0         0.0       16000    1016.9
# Utah          Panguitch                 0         0.0       16000    1024.7
# West Virginia Pt Pleasant               0        47.4       16000    1023.4
#
#                                 HEAT_INDEX  LATITUDE  LONGITUDE
# State         STATION_NAME
# Alaska        Chandalar Lake           0.0      67.5    -148.48
#               Chulitna                 0.0    62.886   -149.583
#               Hooper Bay               0.0     61.52    -166.15
#               Wainwright               0.0    70.637   -160.013
# California    Los Angeles              0.0    34.024   -118.291
#               Oceano Cnty              0.0      35.1    -120.62
# Florida       Hurlbert               193.4      60.8     -173.3
# Georgia       Greensboro               0.0      33.6     -83.13
#               Louisville               0.0    32.986   -82.3827
#               Metter                   0.0     32.37     -82.07
# Hawaii        Hana                     0.0      20.8    -156.02
#               Kamuela/Waimea           0.0      20.0    -155.67
#               Lahaina/West Mau         0.0     20.97    -156.67
# Illinois      Glenview Nas             0.0  42.08333  -87.81667
# Iowa          Johnston/Desmoin         0.0     41.73     -93.72
# Kansas        Benton                   0.0     37.77     -97.12
# Kentucky      Marion                   0.0     37.33     -88.12
# Louisiana     Boothville Hel           0.0     29.35     -89.43
#               Main Pass 289C           0.0     29.25     -88.43
#               New Orleans/Supe         0.0     29.95     -90.07
# Minnesota     Tofte (Ramos)            0.0     47.58     -90.83
# Mississippi   West Delta 27A           0.0    29.121    -89.547
# Montana       Forsyth                  0.0   46.2695    -106.62
#               Libby                   91.2   48.2834   -115.492
# Nebraska      Mullen                  78.9     42.05  -101.0667
# New Jersey    Lakewood                 0.0     40.07     -74.18
# New York      Monticello               0.0   41.7056   -74.8004
# Ohio          Dayton-Jackson           0.0   39.6935   -83.9896
# Oklahoma      Pryor                   76.1     36.22     -95.33
# Texas         Guadalupe Pass           0.0   31.8327   -104.809
#               Lampasas                 0.0   31.1059   -98.1975
# Utah          Panguitch                0.0     37.85    -112.38
# West Virginia Pt Pleasant              0.0     38.92      -82.1

# %% [markdown]
# It is possible also to show all groups

# %%
sdfUSA_grouped.groups
# Out:
# {'Alaska': [5956, 5957, 5958, 5959], 'California': [6070, 6071], 'Florida': [6088, 6089], 'Georgia': [6098, 6099, 6100], 'Hawaii': [6106, 6107, 6108], 'Illinois': [6109], 'Iowa': [6113], 'Kansas': [6120], 'Kentucky': [6121], 'Louisiana': [6125, 6126, 6127], 'Minnesota': [6130], 'Mississippi': [6131], 'Montana': [6132, 6133], 'Nebraska': [6140], 'New Jersey': [6142], 'New York': [6143], 'Ohio': [6162], 'Oklahoma': [6163], 'Texas': [6195, 6196], 'Utah': [6207], 'West Virginia': [6214]}

# %% [markdown]
# and display the content only of necessary group

# %%
sdfUSA_grouped.get_group("California")
# Out:
#       OBJECTID  ICAO        OBS_DATETIME STATION_NAME  \
# 6070      4922  KCQT 2024-05-20 14:47:00  Los Angeles
# 6071       517  KL52 2023-04-09 16:55:00  Oceano Cnty
#
#                         COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
# 6070   United States Of America       51.0  60.1       52.0          75
# 6071   United States Of America        3.0  55.4       55.4         100
#
#       WIND_DIRECT  ...  PRESSURE                             SKY_CONDTN  \
# 6070            0  ...    1016.3  Overcast Cloud Deck at 760 meters AGL
# 6071          250  ...    1020.3                                   <NA>
#
#                                                 WEATHER  \
# 6070  Automated observation with no human augmentati...
# 6071  Automated observation with no human augmentati...
#
#                                  REMARKS  HEAT_INDEX LATITUDE LONGITUDE  \
# 6070  3-Hour Pressure Increasing: 0.1 mb        <NA>   34.024  -118.291
# 6071                                <NA>        <NA>     35.1   -120.62
#
#      FLT_CATEGORY                                              SHAPE  \
# 6070         MVFR  {"x": -13168093.885400001, "y": 4032025.095200...
# 6071         <NA>  {"x": -13427356.9795, "y": 4177479.0622000024,...
#
#            State
# 6070  California
# 6071  California
#
# [2 rows x 24 columns]

# %%
sdfUSA_grouped.get_group("California").mean(numeric_only=True)
# Out:
# OBJECTID         2719.5
# ELEVATION          27.0
# TEMP              57.75
# DEW_POINT          53.7
# R_HUMIDITY         87.5
# WIND_DIRECT       125.0
# WIND_SPEED          4.5
# WIND_GUST           0.0
# WIND_CHILL         <NA>
# VISIBILITY      14500.0
# PRESSURE         1018.3
# HEAT_INDEX         <NA>
# LATITUDE         34.562
# LONGITUDE     -119.4555
# dtype: object

# %% [markdown]
# We have just one helpful and powerful option for you! It is `filter()`.

# %% [markdown]
# Suppose you need remain only those groups where there are less than 5 items. Sure, you may hardly calculate amount of items in each group and then remove not satisfying for condition. But it can be done very easily.

# %%
sdfUSA_grouped.filter(lambda x: len(x) < 5).sort_values("State")
# Out:
#       OBJECTID  ICAO        OBS_DATETIME      STATION_NAME  \
# 5956      6060  PAEC 2024-01-16 16:51:00          Chulitna
# 5957      3767  PAHP 2022-09-17 01:32:00        Hooper Bay
# 5958      5937  PALR 2023-06-27 00:50:00    Chandalar Lake
# 5959      4180  PAWI 2024-04-29 23:53:00        Wainwright
# 6070      4922  KCQT 2024-05-20 14:47:00       Los Angeles
# 6071       517  KL52 2023-04-09 16:55:00       Oceano Cnty
# 6088      6002  KQBL 2024-06-14 22:55:00          Hurlbert
# 6089      6003  KQHY 2024-06-14 22:55:00          Hurlbert
# 6098      1027  K2J3 2023-11-10 06:10:00        Louisville
# 6099      1014  K3J7 2023-05-03 14:30:00        Greensboro
# 6100      2936  KHME 2023-02-26 13:50:00            Metter
# 6106      5970  PHHN 2023-09-15 03:58:00              Hana
# 6107      5889  PHJH 2023-01-27 04:05:00  Lahaina/West Mau
# 6108      5971  PHMU 2023-09-15 04:00:00    Kamuela/Waimea
# 6109      5840  KNBU 2022-12-13 08:00:00      Glenview Nas
# 6113      5965  KDMX 2023-08-24 17:00:00  Johnston/Desmoin
# 6120      1045  K1K1 2022-12-29 06:10:00            Benton
# 6121       985  K5M9 2022-11-09 15:35:00            Marion
# 6125       107  K7N0 2023-01-26 18:56:00  New Orleans/Supe
# 6126       498  KLNQ 2023-08-25 13:46:00    Boothville Hel
# 6127       150  KVKY 2023-07-03 14:50:00    Main Pass 289C
# 6130      6104  KP61 2024-05-24 06:52:00     Tofte (Ramos)
# 6131      5832  KDLP 2024-02-10 23:05:00    West Delta 27A
# 6132      5683  K1S3 2024-04-30 20:15:00           Forsyth
# 6133      1618  KS59 2024-06-11 22:45:00             Libby
# 6140      5691  KMHN 2022-08-31 01:58:00            Mullen
# 6142      5977  KN12 2023-10-09 15:55:00          Lakewood
# 6143      3856  KMSV 2024-03-05 18:38:00        Monticello
# 6162       585  KI19 2023-11-29 23:55:00    Dayton-Jackson
# 6163       631  KH71 2023-04-14 15:35:00             Pryor
# 6195      4754  KGDP 2023-12-11 00:51:00    Guadalupe Pass
# 6196      2260  KLZZ 2024-04-03 14:35:00          Lampasas
# 6207       175  KU55 2023-08-20 09:55:00         Panguitch
# 6214      1015  K3I2 2022-12-28 09:30:00       Pt Pleasant
#
#                         COUNTRY  ELEVATION  TEMP  DEW_POINT  R_HUMIDITY  \
# 5956   United States Of America      389.0  30.2       32.0         108
# 5957   United States Of America        8.0  51.8       46.4          82
# 5958   United States Of America      579.0  59.0       50.0          72
# 5959   United States Of America       12.0  12.9       10.0          88
# 6070   United States Of America       51.0  60.1       52.0          75
# 6071   United States Of America        3.0  55.4       55.4         100
# 6088   United States Of America     9999.0  86.0       75.7          72
# 6089   United States Of America     9999.0  86.4       76.6          73
# 6098   United States Of America       97.0  57.2       56.7          98
# 6099   United States Of America      207.0  60.8       33.8          36
# 6100   United States Of America       60.0  60.8       35.6          39
# 6106   United States Of America       20.0  75.2       73.4          94
# 6107   United States Of America       67.0  <NA>       <NA>        <NA>
# 6108   United States Of America      809.0  66.2       64.4          94
# 6109   United States Of America       <NA>  48.9       35.1          59
# 6113   United States Of America      299.0  <NA>       <NA>        <NA>
# 6120   United States Of America      411.0  46.9       29.7          51
# 6121   United States Of America      199.0  68.2       37.6          32
# 6125   United States Of America        0.0  52.0       36.0          54
# 6126   United States Of America        1.0 -35.7       <NA>        <NA>
# 6127   United States Of America       32.0  <NA>       <NA>        <NA>
# 6130   United States Of America      241.0  43.0       41.0          93
# 6131   United States Of America       31.0  <NA>       <NA>        <NA>
# 6132   United States Of America      831.0  53.6       17.6          24
# 6133   United States Of America      793.0  80.6       80.6         100
# 6140   United States Of America       <NA>  78.4       53.4          42
# 6142   United States Of America       13.0  68.5       38.5          33
# 6143   United States Of America      427.0  42.8       41.0          93
# 6162   United States Of America      285.0  35.6       26.6          69
# 6163   United States Of America      190.0  71.6       53.6          53
# 6195   United States Of America     1664.0  41.0        8.1          25
# 6196   United States Of America      356.0  60.3       37.9          43
# 6207   United States Of America     2060.0  57.2       55.4          94
# 6214   United States Of America      195.0  18.9       16.7          91
#
#       WIND_DIRECT  ...  PRESSURE  \
# 5956           40  ...    1013.2
# 5957          180  ...     979.0
# 5958           70  ...    1008.1
# 5959           90  ...    1027.1
# 6070            0  ...    1016.3
# 6071          250  ...    1020.3
# 6088         <NA>  ...    1012.5
# 6089          220  ...    1012.2
# 6098            0  ...    1017.3
# 6099          270  ...    1009.8
# 6100          270  ...    1023.9
# 6106            0  ...    1015.9
# 6107           20  ...    1016.2
# 6108           40  ...    1017.3
# 6109          360  ...    1023.4
# 6113         <NA>  ...      <NA>
# 6120          240  ...    1002.4
# 6121            0  ...    1027.1
# 6125            0  ...    1026.7
# 6126           70  ...    1016.2
# 6127          240  ...    1017.3
# 6130            0  ...    1017.6
# 6131          180  ...    1008.8
# 6132          280  ...    1009.5
# 6133          200  ...    1008.8
# 6140           30  ...    1023.0
# 6142          360  ...    1023.0
# 6143           90  ...    1019.0
# 6162          210  ...    1016.3
# 6163          170  ...    1006.8
# 6195          230  ...    1022.7
# 6196          300  ...    1016.9
# 6207            0  ...    1024.7
# 6214            0  ...    1023.4
#
#                                              SKY_CONDTN  \
# 5956             Overcast Cloud Deck at 1300 meters AGL
# 5957              Overcast Cloud Deck at 730 meters AGL
# 5958  Broken Clouds at 1800 meters AGL, Overcast Clo...
# 5959                  Scattered Clouds at 60 meters AGL
# 6070              Overcast Cloud Deck at 760 meters AGL
# 6071                                               <NA>
# 6088                      Few Clouds at 2700 meters AGL
# 6089                      Few Clouds at 2900 meters AGL
# 6098                    Sky Clear below 3700 meters AGL
# 6099                    Sky Clear below 3700 meters AGL
# 6100                Scattered Clouds at 1100 meters AGL
# 6106             Overcast Cloud Deck at 1300 meters AGL
# 6107  Scattered Clouds at 430 meters AGL, Scattered ...
# 6108  Scattered Clouds at 210 meters AGL, Broken Clo...
# 6109             Overcast Cloud Deck at 1200 meters AGL
# 6113                                               <NA>
# 6120                    Sky Clear below 3700 meters AGL
# 6121                    Sky Clear below 3700 meters AGL
# 6125                    Sky Clear below 3700 meters AGL
# 6126                                               <NA>
# 6127                    Sky Clear below 3700 meters AGL
# 6130                                               <NA>
# 6131                    Sky Clear below 3700 meters AGL
# 6132                                               <NA>
# 6133                                               <NA>
# 6140                   Broken Clouds at 4300 meters AGL
# 6142                      Few Clouds at 3700 meters AGL
# 6143              Overcast Cloud Deck at 120 meters AGL
# 6162                    Sky Clear below 3700 meters AGL
# 6163                    Sky Clear below 3700 meters AGL
# 6195                                               <NA>
# 6196                    Sky Clear below 3700 meters AGL
# 6207  Few Clouds at 1700 meters AGL, Few Clouds at 2...
# 6214                    Sky Clear below 3700 meters AGL
#
#                                                 WEATHER  \
# 5956       No significant weather present at this time.
# 5957                                         Light Rain
# 5958       No significant weather present at this time.
# 5959  Automated observation with no human augmentati...
# 6070  Automated observation with no human augmentati...
# 6071  Automated observation with no human augmentati...
# 6088  Automated observation with no human augmentati...
# 6089  Automated observation with no human augmentati...
# 6098  Automated observation with no human augmentati...
# 6099  Automated observation with no human augmentati...
# 6100       No significant weather present at this time.
# 6106  Automated observation with no human augmentati...
# 6107                          Light Drizzle, Sand Storm
# 6108  Automated observation with no human augmentati...
# 6109  Automated observation with no human augmentati...
# 6113       No significant weather present at this time.
# 6120  Automated observation with no human augmentati...
# 6121  Automated observation with no human augmentati...
# 6125  Automated observation with no human augmentati...
# 6126  Automated observation with no human augmentati...
# 6127  Automated observation with no human augmentati...
# 6130  Automated observation with no human augmentati...
# 6131  Automated observation with no human augmentati...
# 6132  Automated observation with no human augmentati...
# 6133  Automated observation with no human augmentati...
# 6140       No significant weather present at this time.
# 6142       No significant weather present at this time.
# 6143                                   Light Rain, Mist
# 6162  Automated observation with no human augmentati...
# 6163  Automated observation with no human augmentati...
# 6195  Automated observation with no human augmentati...
# 6196  Automated observation with no human augmentati...
# 6207  Automated observation with no human augmentati...
# 6214  Automated observation with no human augmentati...
#
#                                                 REMARKS  HEAT_INDEX  LATITUDE  \
# 5956                                               <NA>        <NA>    62.886
# 5957  * Maintenance REQUIRED - readings may be compr...        <NA>     61.52
# 5958                                               <NA>        <NA>      67.5
# 5959  * Maintenance REQUIRED - readings may be compr...        <NA>    70.637
# 6070                 3-Hour Pressure Increasing: 0.1 mb        <NA>    34.024
# 6071                                               <NA>        <NA>      35.1
# 6088                                               <NA>        96.0      30.4
# 6089  * Maintenance REQUIRED - readings may be compr...        97.4      30.4
# 6098                                               <NA>        <NA>    32.986
# 6099                                               <NA>        <NA>      33.6
# 6100                                               <NA>        <NA>     32.37
# 6106                                               <NA>        <NA>      20.8
# 6107                                               <NA>        <NA>     20.97
# 6108                                               <NA>        <NA>      20.0
# 6109                                               <NA>        <NA>  42.08333
# 6113                                               <NA>        <NA>     41.73
# 6120                                               <NA>        <NA>     37.77
# 6121                                               <NA>        <NA>     37.33
# 6125  * Maintenance REQUIRED - readings may be compr...        <NA>     29.95
# 6126                                               <NA>        <NA>     29.35
# 6127                                               <NA>        <NA>     29.25
# 6130  * Maintenance REQUIRED - readings may be compr...        <NA>     47.58
# 6131                                               <NA>        <NA>    29.121
# 6132                                               <NA>        <NA>   46.2695
# 6133                                               <NA>        91.2   48.2834
# 6140  * Maintenance REQUIRED - readings may be compr...        78.9     42.05
# 6142                                               <NA>        <NA>     40.07
# 6143                                               <NA>        <NA>   41.7056
# 6162                                               <NA>        <NA>   39.6935
# 6163                                               <NA>        76.1     36.22
# 6195  * Maintenance REQUIRED - readings may be compr...        <NA>   31.8327
# 6196                                               <NA>        <NA>   31.1059
# 6207                                               <NA>        <NA>     37.85
# 6214                                               <NA>        <NA>     38.92
#
#      LONGITUDE FLT_CATEGORY  \
# 5956  -149.583          VFR
# 5957   -166.15          IFR
# 5958   -148.48          VFR
# 5959  -160.013          VFR
# 6070  -118.291         MVFR
# 6071   -120.62         <NA>
# 6088    -86.65          VFR
# 6089    -86.65          VFR
# 6098  -82.3827          VFR
# 6099    -83.13          VFR
# 6100    -82.07          VFR
# 6106   -156.02         <NA>
# 6107   -156.67         <NA>
# 6108   -155.67          VFR
# 6109 -87.81667          VFR
# 6113    -93.72         <NA>
# 6120    -97.12          VFR
# 6121    -88.12          VFR
# 6125    -90.07          VFR
# 6126    -89.43         <NA>
# 6127    -88.43          VFR
# 6130    -90.83         <NA>
# 6131   -89.547          VFR
# 6132   -106.62          VFR
# 6133  -115.492          IFR
# 6140 -101.0667          VFR
# 6142    -74.18          VFR
# 6143  -74.8004         LIFR
# 6162  -83.9896          VFR
# 6163    -95.33          VFR
# 6195  -104.809          VFR
# 6196  -98.1975          VFR
# 6207   -112.38          VFR
# 6214     -82.1          VFR
#
#                                                   SHAPE          State
# 5956  {"x": -16651503.3913, "y": 9072352.268600002, ...         Alaska
# 5957  {"x": -18495733.3953, "y": 8746212.867399998, ...         Alaska
# 5958  {"x": -16528717.993, "y": 10299995.503399998, ...         Alaska
# 5959  {"x": -17812565.6803, "y": 11279281.076499999,...         Alaska
# 6070  {"x": -13168093.885400001, "y": 4032025.095200...     California
# 6071  {"x": -13427356.9795, "y": 4177479.0622000024,...     California
# 6088  {"x": -9645833.8772, "y": 3555070.433799997, "...        Florida
# 6089  {"x": -9645833.8772, "y": 3555070.433799997, "...        Florida
# 6098  {"x": -9170800.2142, "y": 3893445.844999999, "...        Georgia
# 6099  {"x": -9253989.2696, "y": 3975217.4293000028, ...        Georgia
# 6100  {"x": -9135990.6094, "y": 3811977.4724999964, ...        Georgia
# 6106  {"x": -17368066.9536, "y": 2368046.6396000013,...         Hawaii
# 6107  {"x": -17440424.6226, "y": 2388301.7677999996,...         Hawaii
# 6108  {"x": -17329105.1318, "y": 2273030.927000001, ...         Hawaii
# 6109  {"x": -9775706.6165, "y": 5173470.558499999, "...       Illinois
# 6113  {"x": -10432862.6771, "y": 5120620.167099997, ...           Iowa
# 6120  {"x": -10811348.9458, "y": 4546985.284400001, ...         Kansas
# 6121  {"x": -9809473.5287, "y": 4485204.895800002, "...       Kentucky
# 6125  {"x": -10026546.5358, "y": 3497124.4274000004,...      Louisiana
# 6126  {"x": -9955302.0616, "y": 3420269.0613999963, ...      Louisiana
# 6127  {"x": -9843982.5708, "y": 3407504.076200001, "...      Louisiana
# 6130  {"x": -10111149.3488, "y": 6037264.071999997, ...      Minnesota
# 6131  {"x": -9968326.4421, "y": 3391055.656199999, "...    Mississippi
# 6132  {"x": -11868884.1084, "y": 5823642.465800002, ...        Montana
# 6133  {"x": -12856510.6307, "y": 6154132.6668, "spat...        Montana
# 6140  {"x": -11250689.8695, "y": 5168472.146600001, ...       Nebraska
# 6142  {"x": -8257679.827, "y": 4876119.708899997, "s...     New Jersey
# 6143  {"x": -8326742.439099999, "y": 5116981.2589000...       New York
# 6162  {"x": -9349679.5039, "y": 4821501.988399997, "...           Ohio
# 6163  {"x": -10612087.0573, "y": 4330935.410899997, ...       Oklahoma
# 6195  {"x": -11667284.5106, "y": 3741369.8814999983,...          Texas
# 6196  {"x": -10931295.6972, "y": 3646509.9246999994,...          Texas
# 6207  {"x": -12510084.375300001, "y": 4558257.461000...           Utah
# 6214  {"x": -9139330.1941, "y": 4710218.728799999, "...  West Virginia
#
# [34 rows x 24 columns]

# %% [markdown]
# One more example:

# %%
sdfUSA_grouped.filter(lambda x: x['TEMP'].mean(numeric_only=True) > 50 and x['R_HUMIDITY'].mean(numeric_only=True) > 50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 sdfUSA_grouped.dropna().filter(lambda x: x['TEMP'].mean(numeric_only=True) > 50 and x['R_HUMIDITY'].mean(numeric_only=True) > 50)
#
# TypeError: 'bool' object is not callable

# %% [markdown]
# ### Aggregation
#
# [[back to top]](#Table-of-Contents)
#
# We have seen previously, pandas allows to apply any function to a Series or to a DataFrame. Grouping is not an exception and you may use the same method `apply()` directly with `GroupBy` objects.  Aggregation can be done via the `aggregate()` or equivalently `agg()` method

# %%
sdfUSA_grouped.agg(np.sum).head(10)
# or state_grouped.aggregate(np.sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 sdfUSA_grouped.agg(np.sum).head(10)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\generic.py:1269, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1266 func = maybe_mangle_lambdas(func)
#    1268 op = GroupByApply(self, func, args, kwargs)
# -> 1269 result = op.agg()
#    1270 if not is_dict_like(func) and result is not None:
#    1271     return result
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\apply.py:171, in Apply.agg(self)
#     169     f = com.get_cython_func(arg)
#     170     if f and not args and not kwargs:
# --> 171         return getattr(obj, f)()
#     173 # caller can react
#     174 return None
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:2263, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    2258 else:
#    2259     # If we are grouping on categoricals we want unobserved categories to
#    2260     # return zero, rather than the default of NaN which the reindexing in
#    2261     # _agg_general() returns. GH #31422
#    2262     with com.temp_setattr(self, "observed", True):
# -> 2263         result = self._agg_general(
#    2264             numeric_only=numeric_only,
#    2265             min_count=min_count,
#    2266             alias="sum",
#    2267             npfunc=np.sum,
#    2268         )
#    2270     return self._reindex_output(result, fill_value=0)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:1422, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc)
#    1413 @final
#    1414 def _agg_general(
#    1415     self,
#    (...)
#    1420     npfunc: Callable,
#    1421 ):
# -> 1422     result = self._cython_agg_general(
#    1423         how=alias,
#    1424         alt=npfunc,
#    1425         numeric_only=numeric_only,
#    1426         min_count=min_count,
#    1427     )
#    1428     return result.__finalize__(self.obj, method="groupby")
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:1507, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1503         result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505     return result
# -> 1507 new_mgr = data.grouped_reduce(array_func)
#    1508 res = self._wrap_agged_manager(new_mgr)
#    1509 out = self._wrap_aggregated_output(res)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\internals\managers.py:1506, in BlockManager.grouped_reduce(self, func)
#    1504             result_blocks = extend_blocks(applied, result_blocks)
#    1505     else:
# -> 1506         applied = blk.apply(func)
#    1507         result_blocks = extend_blocks(applied, result_blocks)
#    1509 if len(result_blocks) == 0:
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\internals\blocks.py:329, in Block.apply(self, func, **kwargs)
#     323 @final
#     324 def apply(self, func, **kwargs) -> list[Block]:
#     325     """
#     326     apply the function to my values; return a block if we are not
#     327     one
#     328     """
# --> 329     result = func(self.values, **kwargs)
#     331     return self._split_op_result(result)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1488 def array_func(values: ArrayLike) -> ArrayLike:
#    1489     try:
# -> 1490         result = self.grouper._cython_operation(
#    1491             "aggregate",
#    1492             values,
#    1493             how,
#    1494             axis=data.ndim - 1,
#    1495             min_count=min_count,
#    1496             **kwargs,
#    1497         )
#    1498     except NotImplementedError:
#    1499         # generally if we have numeric_only=False
#    1500         # and non-applicable functions
#    1501         # try to python agg
#    1502         # TODO: shouldn't min_count matter?
#    1503         result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     957 ids, _, _ = self.group_info
#     958 ngroups = self.ngroups
# --> 959 return cy_op.cython_operation(
#     960     values=values,
#     961     axis=axis,
#     962     min_count=min_count,
#     963     comp_ids=ids,
#     964     ngroups=ngroups,
#     965     **kwargs,
#     966 )
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\ops.py:645, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     641 is_numeric = is_numeric_dtype(dtype)
#     643 # can we do this operation with our cython functions
#     644 # if not raise NotImplementedError
# --> 645 self._disallow_invalid_ops(dtype, is_numeric)
#     647 if not isinstance(values, np.ndarray):
#     648     # i.e. ExtensionArray
#     649     return self._ea_wrap_cython_operation(
#     650         values,
#     651         min_count=min_count,
#    (...)
#     654         **kwargs,
#     655     )
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\groupby\ops.py:257, in WrappedCythonOp._disallow_invalid_ops(self, dtype, is_numeric)
#     254 elif is_datetime64_any_dtype(dtype):
#     255     # Adding/multiplying datetimes is not valid
#     256     if how in ["sum", "prod", "cumsum", "cumprod"]:
# --> 257         raise TypeError(f"datetime64 type does not support {how} operations")
#     258 elif is_period_dtype(dtype):
#     259     # Adding/multiplying Periods is not valid
#     260     if how in ["sum", "prod", "cumsum", "cumprod"]:
#
# TypeError: datetime64 type does not support sum operations

# %% [markdown]
# Sure, above variant is equivalent to `state_grouped.sum()`.
# One of the advantages of `agg()` method is the possibility of application of many functions to one and same dataset at once

# %%
# at first let's write the function which returns amount of notnull values 
def count_not_null(x):
    return len([i for i in x if pd.notnull(i)])
sdfUSA_grouped[['TEMP', 'R_HUMIDITY', "WIND_SPEED"]].agg([np.sum, np.mean, count_not_null]).head(10)
# Out:
#              TEMP                        R_HUMIDITY                            \
#               sum    mean count_not_null        sum       mean count_not_null
# State
# Alaska      153.9  38.475            4.0        350       87.5              4
# California  115.5   57.75            2.0        175       87.5              2
# Florida     172.4    86.2            2.0        145       72.5              2
# Georgia     178.8    59.6            3.0        173  57.666667              3
# Hawaii      141.4    70.7            2.0        188       94.0              2
# Illinois     48.9    48.9            1.0         59       59.0              1
# Iowa          0.0    <NA>            0.0          0       <NA>              0
# Kansas       46.9    46.9            1.0         51       51.0              1
# Kentucky     68.2    68.2            1.0         32       32.0              1
# Louisiana    16.3    8.15            2.0         54       54.0              1
#
#            WIND_SPEED
#                   sum       mean count_not_null
# State
# Alaska            120       30.0              4
# California          9        4.5              2
# Florida            12        6.0              2
# Georgia            18        6.0              3
# Hawaii             48       16.0              3
# Illinois           20       20.0              1
# Iowa                0        0.0              1
# Kansas              6        6.0              1
# Kentucky            0        0.0              1
# Louisiana          31  10.333333              3

# %% [markdown]
# Sure, you may apply many functions to whole DataFrame at once

# %% [markdown]
# Another simple aggregation example is to compute the size of each group. This is included in `GroupBy` as the `size()` method. It returns a Series whose indexes are the group names and whose values are the sizes of each group.

# %%
sdfUSA_grouped.size()
# Out:
# State
# Alabama                41
# Alaska                128
# Arizona                42
# Arkansas               36
# California            131
# Colorado               64
# Connecticut            10
# Delaware                4
# Florida                95
# Georgia                79
# Guam                    2
# Hawaii                 13
# Idaho                  24
# Illinois               58
# Indiana                41
# Iowa                   60
# Johnston/Wake/Xmas      2
# Kansas                 55
# Kentucky               38
# Louisiana              51
# Maine                  17
# Marshall Islands        1
# Maryland               22
# Massachusetts          23
# Michigan               75
# Minnesota             100
# Mississippi            33
# Missouri               43
# Montana                38
# Nebraska               39
# Nevada                 22
# New Hampshire          13
# New Jersey             17
# New Mexico             32
# New York               46
# North Carolina         69
# North Dakota           36
# Ohio                   56
# Oklahoma               55
# Oregon                 39
# Pennsylvania           45
# Puerto Rico             4
# Rhode Island            6
# South Carolina         45
# South Dakota           21
# Tennessee              49
# Texas                 196
# Utah                   24
# Vermont                11
# Virginia               62
# Washington             44
# Washington D.C.         1
# West Virginia          16
# Wisconsin              70
# Wyoming                39
# dtype: int64

# %% [markdown]
# >### Exercise 1
#
# > Read in the Gulf_and_Caribbean_Marine_Ecoregions.shp file (loaded into map 1) and also included in the data package.
# > Use the groupby functions you learned about to create a dataframe that contains the total area (Shape_Area column) for each of unique values in the Lat_Zone field.

# %%
# type your code here
