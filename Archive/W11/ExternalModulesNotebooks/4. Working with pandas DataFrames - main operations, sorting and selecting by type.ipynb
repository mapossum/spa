# %% [markdown]
# ---
# <center><h1>Basic intro into pandas</h1></center>
#
# <center><h2>Working with pandas DataFrames: main operations, sorting and selecting by type</h2></center>
#
# ---

# %% [markdown]
# ## Table of Contents
# - [Work with pandas DataFrames: main operations, sorting and selecting by type](#Work-with-pandas-DataFrames:-main-operations,-sorting-and-selecting-by-type)
#     * [Flexible comparisons and boolean reductions](#Flexible-comparisons-and-boolean-reductions)
#     * [Descriptive statistics](#Descriptive-statistics)
#     * [Function application](#Function-application)
#     * [Sorting](#Sorting)
#     * [Selecting by type](#Selecting-by-type)

# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# ## Work with pandas DataFrames: main operations, sorting and selecting by type
#
# [[back to top]](#Table-of-Contents)

# %% [markdown]
# In this part we will consider the following questions:
# 1.	how quickly compare two or more DataFrames or check if Dataframe’s items satisfy any condition.
# 2.	what main mathematical (computational) and statistical operations may be easily applied to pandas DataFrame's data, i.e. what such operations are build in pandas;
# 3.	how to apply an arbitrary function to DataFrame’s items, rows, columns and whole DataFrame and change its data type;
# 4.	how sort rows and columns data;
# 5.	how select any column by its type.
#
# At first, let’s find all unique values in `‘Province_State’` column of the COVID 19 dataset

# %%
from arcgis.features import GeoAccessor, GeoSeriesAccessor
#Import a COVID data layer.  This layer contains the updated stats for each county in the United States
from arcgis.features import FeatureLayer
mylayer = FeatureLayer(("https://services1.arcgis.com/0MSEUqKaxRlEPj5g/ArcGIS/rest/services/ncov_cases_US/FeatureServer/0"))
sdf2 = pd.DataFrame.spatial.from_layer(mylayer)
sdf2.head(4)
# Out:
#    OBJECTID Province_State Country_Region         Last_Update        Lat  \
# 0         1        Alabama             US 2023-03-10 13:21:02  32.539527
# 1         2        Alabama             US 2023-03-10 13:21:02   30.72775
# 2         3        Alabama             US 2023-03-10 13:21:02  31.868263
# 3         4        Alabama             US 2023-03-10 13:21:02  32.996421
#
#        Long_  Confirmed  Recovered  Deaths  Active   Admin2   FIPS  \
# 0 -86.644082      19790       <NA>     232    <NA>  Autauga  01001
# 1 -87.722071      69860       <NA>     727    <NA>  Baldwin  01003
# 2 -85.387129       7485       <NA>     103    <NA>  Barbour  01005
# 3 -87.125115       8091       <NA>     109    <NA>     Bibb  01007
#
#            Combined_Key  Incident_Rate  People_Tested  People_Hospitalized  \
# 0  Autauga, Alabama, US    35422.14824           <NA>                 <NA>
# 1  Baldwin, Alabama, US   31294.516068           <NA>                 <NA>
# 2  Barbour, Alabama, US    30320.82962           <NA>                 <NA>
# 3     Bibb, Alabama, US    36130.21345           <NA>                 <NA>
#
#         UID ISO3                                              SHAPE
# 0  84001001  USA  {"x": -86.64408226999996, "y": 32.539527450000...
# 1  84001003  USA  {"x": -87.72207057999998, "y": 30.727749910000...
# 2  84001005  USA  {"x": -85.38712859999998, "y": 31.868263000000...
# 3  84001007  USA  {"x": -87.12511459999996, "y": 32.996420640000...

# %%
sdf2.dtypes
# Out:
# OBJECTID                        Int64
# Province_State         string[python]
# Country_Region         string[python]
# Last_Update            datetime64[ns]
# Lat                           Float64
# Long_                         Float64
# Confirmed                       Int32
# Recovered                       Int32
# Deaths                          Int32
# Active                          Int32
# Admin2                 string[python]
# FIPS                   string[python]
# Combined_Key           string[python]
# Incident_Rate                 Float64
# People_Tested                   Int32
# People_Hospitalized             Int32
# UID                             Int32
# ISO3                   string[python]
# SHAPE                        geometry
# dtype: object

# %%
# get unique values
unique_states = sdf2['Province_State'].drop_duplicates().dropna()
unique_states
# Out:
# 0                    Alabama
# 69                    Alaska
# 100                  Arizona
# 117                 Arkansas
# 193               California
# 253                 Colorado
# 319              Connecticut
# 328                 Delaware
# 332     District of Columbia
# 333                  Florida
# 401                  Georgia
# 562                   Hawaii
# 568                    Idaho
# 613                 Illinois
# 717                  Indiana
# 810                     Iowa
# 910                   Kansas
# 1017                Kentucky
# 1138               Louisiana
# 1204                   Maine
# 1222                Maryland
# 1247           Massachusetts
# 1261                Michigan
# 1348               Minnesota
# 1436             Mississippi
# 1519                Missouri
# 1636                 Montana
# 1693                Nebraska
# 1787                  Nevada
# 1805           New Hampshire
# 1816              New Jersey
# 1838              New Mexico
# 1872                New York
# 1936          North Carolina
# 2037            North Dakota
# 2091                    Ohio
# 2180                Oklahoma
# 2259                  Oregon
# 2296            Pennsylvania
# 2364             Puerto Rico
# 2444            Rhode Island
# 2450          South Carolina
# 2497            South Dakota
# 2564               Tennessee
# 2661                   Texas
# 2916                    Utah
# 2930                 Vermont
# 2945                Virginia
# 3079              Washington
# 3119           West Virginia
# 3175               Wisconsin
# 3248                 Wyoming
# Name: Province_State, dtype: string

# %% [markdown]
# Above we have used `drop_duplicates()` method to select only `unique` Series values.
# Below we can filter the same data frame with respect to `specific states` using isin.

# %%
SouthCentraldf = sdf2[sdf2['Province_State'].isin(["Mississippi", "Alabama", "Louisiana"])]
SouthCentraldf
# Out:
#       OBJECTID Province_State Country_Region         Last_Update        Lat  \
# 0            1        Alabama             US 2023-03-10 13:21:02  32.539527
# 1            2        Alabama             US 2023-03-10 13:21:02   30.72775
# 2            3        Alabama             US 2023-03-10 13:21:02  31.868263
# 3            4        Alabama             US 2023-03-10 13:21:02  32.996421
# 4            5        Alabama             US 2023-03-10 13:21:02  33.982109
# ...        ...            ...            ...                 ...        ...
# 1514      1515    Mississippi             US 2023-03-10 13:21:02  33.613005
# 1515      1516    Mississippi             US 2023-03-10 13:21:02  31.160782
# 1516      1517    Mississippi             US 2023-03-10 13:21:02  33.087479
# 1517      1518    Mississippi             US 2023-03-10 13:21:02  34.028242
# 1518      1519    Mississippi             US 2023-03-10 13:21:02  32.778904
#
#           Long_  Confirmed  Recovered  Deaths  Active     Admin2   FIPS  \
# 0    -86.644082      19790       <NA>     232    <NA>    Autauga  01001
# 1    -87.722071      69860       <NA>     727    <NA>    Baldwin  01003
# 2    -85.387129       7485       <NA>     103    <NA>    Barbour  01005
# 3    -87.125115       8091       <NA>     109    <NA>       Bibb  01007
# 4    -86.567906      18704       <NA>     261    <NA>     Blount  01009
# ...         ...        ...        ...     ...     ...        ...    ...
# 1514 -89.283929       4069       <NA>      76    <NA>    Webster  28155
# 1515 -91.310188       1943       <NA>      47    <NA>  Wilkinson  28157
# 1516 -89.033914       6747       <NA>     105    <NA>    Winston  28159
# 1517 -89.707621       4831       <NA>      63    <NA>  Yalobusha  28161
# 1518 -90.396561      10078       <NA>     118    <NA>      Yazoo  28163
#
#                     Combined_Key  Incident_Rate  People_Tested  \
# 0           Autauga, Alabama, US    35422.14824           <NA>
# 1           Baldwin, Alabama, US   31294.516068           <NA>
# 2           Barbour, Alabama, US    30320.82962           <NA>
# 3              Bibb, Alabama, US    36130.21345           <NA>
# 4            Blount, Alabama, US   32345.311797           <NA>
# ...                          ...            ...            ...
# 1514    Webster, Mississippi, US   41996.078027           <NA>
# 1515  Wilkinson, Mississippi, US   22514.484357           <NA>
# 1516    Winston, Mississippi, US   37577.276525           <NA>
# 1517  Yalobusha, Mississippi, US   39899.240172           <NA>
# 1518      Yazoo, Mississippi, US   33944.088919           <NA>
#
#       People_Hospitalized       UID ISO3  \
# 0                    <NA>  84001001  USA
# 1                    <NA>  84001003  USA
# 2                    <NA>  84001005  USA
# 3                    <NA>  84001007  USA
# 4                    <NA>  84001009  USA
# ...                   ...       ...  ...
# 1514                 <NA>  84028155  USA
# 1515                 <NA>  84028157  USA
# 1516                 <NA>  84028159  USA
# 1517                 <NA>  84028161  USA
# 1518                 <NA>  84028163  USA
#
#                                                   SHAPE
# 0     {"x": -86.64408226999996, "y": 32.539527450000...
# 1     {"x": -87.72207057999998, "y": 30.727749910000...
# 2     {"x": -85.38712859999998, "y": 31.868263000000...
# 3     {"x": -87.12511459999996, "y": 32.996420640000...
# 4     {"x": -86.56790592999994, "y": 33.982109180000...
# ...                                                 ...
# 1514  {"x": -89.28392911999998, "y": 33.613004860000...
# 1515  {"x": -91.31018818999996, "y": 31.160782250000...
# 1516  {"x": -89.03391384999998, "y": 33.087479080000...
# 1517  {"x": -89.70762049999996, "y": 34.028241750000...
# 1518  {"x": -90.39656147999995, "y": 32.778903650000...
#
# [218 rows x 19 columns]

# %% [markdown]
# Now we may filter the resulting DataFrame `SouthCentraldf` by `deaths`

# %%
lowDeathsSouthCentraldf = SouthCentraldf[SouthCentraldf['Deaths'] < 50]
print(lowDeathsSouthCentraldf.count() / SouthCentraldf.count())
# Out:
# OBJECTID               0.096330
# Province_State         0.096330
# Country_Region         0.096330
# Last_Update            0.096330
# Lat                    0.075117
# Long_                  0.075117
# Confirmed              0.096330
# Recovered                   NaN
# Deaths                 0.096330
# Active                      NaN
# Admin2                 0.096330
# FIPS                   0.096330
# Combined_Key           0.096330
# Incident_Rate          0.075117
# People_Tested               NaN
# People_Hospitalized         NaN
# UID                    0.096330
# ISO3                   0.096330
# SHAPE                  0.075117
# dtype: float64

# %% [markdown]
# We are going to take a break from real data and just show some examples using made up data.  These examples basically compare different data frames (or series).

# %%
df_ABC = pd.DataFrame({'A': [1,2,3], 'B': [3,4,5], 'C': [-1,9,-4]})
df_ABC
# Out:
#    A  B  C
# 0  1  3 -1
# 1  2  4  9
# 2  3  5 -4

# %%
df_ACD = pd.DataFrame({'A': [0,4,9], 'C': [-1,-3,-2], 'D': [0,1,-2]})
df_ACD
# Out:
#    A  C  D
# 0  0 -1  0
# 1  4 -3  1
# 2  9 -2 -2

# %%
df_ABC.le(df_ACD)
# Out:
#        A      B      C      D
# 0  False  False   True  False
# 1   True  False  False  False
# 2   True  False   True  False

# %% [markdown]
# As was mentioned above pandas compare elements from the same row and column.
#
# You can also apply the reductions: `empty`, `any()`, `all()`, and `bool()` to provide a way to summarize a boolean result:

# %%
# here vertical direction for comparison is taking into account and we check all column’s items
(df_ACD < 0).all()
# Out:
# A    False
# C     True
# D    False
# dtype: bool

# %%
# here horizontal direction for comparison is taking into account and we check all row’s items
(df_ACD < 0).all(axis=1)
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
# here vertical direction for comparison is taking into 
# account and we check if just one column’s item satisfies the condition
(df_ACD < 0).any()
# Out:
# A    False
# C     True
# D     True
# dtype: bool

# %%
# here we check if all DataFrame's items satisfy the condition
(df_ACD < 0).any().any()
# Out:
# True

# %%
# here we check if DataFrame is empty (no elements)
df_ACD.empty
# Out:
# False

# %% [markdown]
# Based on the provided above way you can determine the necessary columns with respect to any condition. It’s helpful when need to quickly check if a DataFrame or its some row or columns contain, for instance, all positive values but it does not matter exactly what the elements – it is the main difference between filtering and flexible comparisons.  Remember you can reverse a boolean condition by using the not keyword.

# %% [markdown]
# ### Descriptive statistics
#
# [[back to top]](#Table-of-Contents)
#
# pandas provides a large number of methods for computing descriptive statistics and other related mathematical operations on Series and DataFrame. Most of these are aggregations but some of them produce an object of the same size. Most of these functions are collected in summary table of common functions:
#
# |Function|Description|
# |--|-------------------------------|
# |abs|absolute value|
# |count|number of non-null observations|
# |sum|sum of values|
# |mean|mean of values|
# |mad|mean absolute deviation|
# |median|arithmetic median of values|
# |min|minimum value|
# |max|maximum value|
# |idxmin|position of minimum value|
# |idxmax|position of maximum value|
# |mode|mode|
# |prod|product of values|
# |std|unbiased standard deviation|
# |var|unbiased variance|
# |cumsum|cumulative sum (a sequence of partial sums of a given sequence)|
#
# Let’s demonstrate how you can use these methods:

# %%
SouthCentraldf['Deaths'].sum()
# Out:
# 53168

# %%
SouthCentraldf['Deaths'].mean()
# Out:
# 243.88990825688074

# %%
# returns average value for each numerical column  (in scientific notation)
SouthCentraldf.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[186], line 2
#       1 # returns average value for each numerical column  (in scientific notation)
# ----> 2 SouthCentraldf.mean()
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\frame.py:10519, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10515     df = df.T
#   10517 # After possibly _get_data and transposing, we are now in the
#   10518 #  simple case where we can use BlockManager.reduce
# > 10519 res = df._mgr.reduce(blk_func)
#   10520 out = df._constructor(res).iloc[0]
#   10521 if out_dtype is not None:
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\internals\managers.py:1534, in BlockManager.reduce(self, func)
#    1532 res_blocks: list[Block] = []
#    1533 for blk in self.blocks:
# -> 1534     nbs = blk.reduce(func)
#    1535     res_blocks.extend(nbs)
#    1537 index = Index([None])  # placeholder
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\internals\blocks.py:339, in Block.reduce(self, func)
#     333 @final
#     334 def reduce(self, func) -> list[Block]:
#     335     # We will apply the function and reshape the result into a single-row
#     336     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     337     assert self.ndim == 2
# --> 339     result = func(self.values)
#     341     if self.values.ndim == 1:
#     342         # TODO(EA2D): special case not needed with 2D EAs
#     343         res_values = np.array([[result]])
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\frame.py:10480, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   10476     if not is_1d_only_ea_dtype(values.dtype) and not isinstance(
#   10477         self._mgr, ArrayManager
#   10478     ):
#   10479         return values._reduce(name, axis=1, skipna=skipna, **kwds)
# > 10480     return values._reduce(name, skipna=skipna, **kwds)
#   10481 else:
#   10482     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\pandas\core\arrays\string_.py:476, in StringArray._reduce(self, name, skipna, axis, **kwargs)
#     473 if name in ["min", "max"]:
#     474     return getattr(self, name)(skipna=skipna, axis=axis)
# --> 476 raise TypeError(f"Cannot perform reduction '{name}' with string dtype")
#
# TypeError: Cannot perform reduction 'mean' with string dtype

# %%
# average value for numeric
sdf2.mean(numeric_only=True)
# Out:
# OBJECTID                        1636.5
# Lat                           37.97145
# Long_                       -91.575549
# Confirmed                 31692.011308
# Recovered                         <NA>
# Deaths                      343.278729
# Active                            <NA>
# Incident_Rate             30629.390382
# People_Tested                     <NA>
# People_Hospitalized               <NA>
# UID                    83519075.055623
# dtype: object

# %%
sdf2['Deaths'].max(), sdf2['Deaths'].idxmax()
# Out:
# (35545, 211)

# %%
#Which County has had the most deaths?
sdf2.iloc[sdf2['Deaths'].idxmax()]
# Out:
# OBJECTID                                                             212
# Province_State                                                California
# Country_Region                                                        US
# Last_Update                                          2023-03-10 13:21:02
# Lat                                                            34.308284
# Long_                                                        -118.228241
# Confirmed                                                        3710586
# Recovered                                                           <NA>
# Deaths                                                             35545
# Active                                                              <NA>
# Admin2                                                       Los Angeles
# FIPS                                                               06037
# Combined_Key                                 Los Angeles, California, US
# Incident_Rate                                               36961.315384
# People_Tested                                                       <NA>
# People_Hospitalized                                                 <NA>
# UID                                                             84006037
# ISO3                                                                 USA
# SHAPE                  {'x': -118.22824109999999, 'y': 34.30828379000...
# Name: 211, dtype: object

# %% [markdown]
# You can also apply any your own function set before using method `apply`

# %%
def my_own_func(x, power, delta=0):
    if x < 20:
        return (x - delta)**power
    elif x >= 20:
        return round(power/x, 2)
    else:
        return  np.nan
    
sdf2['Deaths'].apply(my_own_func, args=(2,), delta=1).head(10)
# Out:
# 0    0.01
# 1    0.00
# 2    0.02
# 3    0.02
# 4    0.01
# 5    0.04
# 6    0.02
# 7    0.00
# 8    0.01
# 9    0.02
# Name: Deaths, dtype: float64

# %% [markdown]
# where the first argument of `apply` method is the function name, the second are `tuple` of all variables without default values, the follow all variables with default values.
#
# To apply any function to each Series element (row or column of a DataFrame) you may use method `map` (please see the type of `'age'` column before; do you remember how it can be done?)

# %%
# get 'Deaths' column where NaN replaced by 0
sdf2['Deaths'].map(lambda x: int(x) if pd.notnull(x) else 0).head(10)
# Out:
# 0    232
# 1    727
# 2    103
# 3    109
# 4    261
# 5     54
# 6    132
# 7    680
# 8    172
# 9     89
# Name: Deaths, dtype: int64

# %%
sdf2['Deaths'].fillna(0).astype(int).head(10)
# Out:
# 0    232
# 1    727
# 2    103
# 3    109
# 4    261
# 5     54
# 6    132
# 7    680
# 8    172
# 9     89
# Name: Deaths, dtype: int32

# %% [markdown]
# Here we have used method `astype()` to change type of column’s elements. But why we have written `fillna(0)`?

# %% [markdown]
# ### Sorting
#
# [[back to top]](#Table-of-Contents)
#
# pandas functionality proposes two kinds of very fast sorting: sorting by label using `sort_index()` and sorting by actual values `order()` for Series and `sort()` for DataFrame. Let’s note that both sorting procedures don’t return a new object by default, except by passing attribute `inplace=True`. For applying of `sort()` method to a DataFrame you should set an arbitrary vector or a column name of the DataFrame to determine the sort order. Otherwise `sort()` works as well as `sort_index()`. By default pandas return an object in ascending order. For changing it to descending order you should set attribute `ascending=False`.

# %%
sdf2.sort_index().head(10)
# Out:
#    OBJECTID Province_State Country_Region         Last_Update        Lat  \
# 0         1        Alabama             US 2023-03-10 13:21:02  32.539527
# 1         2        Alabama             US 2023-03-10 13:21:02   30.72775
# 2         3        Alabama             US 2023-03-10 13:21:02  31.868263
# 3         4        Alabama             US 2023-03-10 13:21:02  32.996421
# 4         5        Alabama             US 2023-03-10 13:21:02  33.982109
# 5         6        Alabama             US 2023-03-10 13:21:02  32.100305
# 6         7        Alabama             US 2023-03-10 13:21:02  31.753001
# 7         8        Alabama             US 2023-03-10 13:21:02  33.774837
# 8         9        Alabama             US 2023-03-10 13:21:02  32.913601
# 9        10        Alabama             US 2023-03-10 13:21:02   34.17806
#
#        Long_  Confirmed  Recovered  Deaths  Active    Admin2   FIPS  \
# 0 -86.644082      19790       <NA>     232    <NA>   Autauga  01001
# 1 -87.722071      69860       <NA>     727    <NA>   Baldwin  01003
# 2 -85.387129       7485       <NA>     103    <NA>   Barbour  01005
# 3 -87.125115       8091       <NA>     109    <NA>      Bibb  01007
# 4 -86.567906      18704       <NA>     261    <NA>    Blount  01009
# 5 -85.712655       3030       <NA>      54    <NA>   Bullock  01011
# 6 -86.680575       6551       <NA>     132    <NA>    Butler  01013
# 7 -85.826304      41421       <NA>     680    <NA>   Calhoun  01015
# 8 -85.390727      10859       <NA>     172    <NA>  Chambers  01017
# 9  -85.60639       6755       <NA>      89    <NA>  Cherokee  01019
#
#             Combined_Key  Incident_Rate  People_Tested  People_Hospitalized  \
# 0   Autauga, Alabama, US    35422.14824           <NA>                 <NA>
# 1   Baldwin, Alabama, US   31294.516068           <NA>                 <NA>
# 2   Barbour, Alabama, US    30320.82962           <NA>                 <NA>
# 3      Bibb, Alabama, US    36130.21345           <NA>                 <NA>
# 4    Blount, Alabama, US   32345.311797           <NA>                 <NA>
# 5   Bullock, Alabama, US   29997.029997           <NA>                 <NA>
# 6    Butler, Alabama, US   33684.697655           <NA>                 <NA>
# 7   Calhoun, Alabama, US    36460.54311           <NA>                 <NA>
# 8  Chambers, Alabama, US   32654.718229           <NA>                 <NA>
# 9  Cherokee, Alabama, US     25786.3796           <NA>                 <NA>
#
#         UID ISO3                                              SHAPE
# 0  84001001  USA  {"x": -86.64408226999996, "y": 32.539527450000...
# 1  84001003  USA  {"x": -87.72207057999998, "y": 30.727749910000...
# 2  84001005  USA  {"x": -85.38712859999998, "y": 31.868263000000...
# 3  84001007  USA  {"x": -87.12511459999996, "y": 32.996420640000...
# 4  84001009  USA  {"x": -86.56790592999994, "y": 33.982109180000...
# 5  84001011  USA  {"x": -85.71265534999998, "y": 32.100305330000...
# 6  84001013  USA  {"x": -86.68057477999997, "y": 31.753000950000...
# 7  84001015  USA  {"x": -85.82630385999994, "y": 33.774837270000...
# 8  84001017  USA  {"x": -85.39072748999996, "y": 32.913600790000...
# 9  84001019  USA  {"x": -85.60638967999995, "y": 34.178059830000...

# %%
sdf2.sort_index(axis=1).sort_index(ascending=False).head(10)
# Out:
#       Active      Admin2             Combined_Key  Confirmed Country_Region  \
# 3271    <NA>      Weston      Weston, Wyoming, US       1905             US
# 3270    <NA>    Washakie    Washakie, Wyoming, US       2755             US
# 3269    <NA>  Unassigned  Unassigned, Wyoming, US          0             US
# 3268    <NA>       Uinta       Uinta, Wyoming, US       6406             US
# 3267    <NA>       Teton       Teton, Wyoming, US      12134             US
# 3266    <NA>  Sweetwater  Sweetwater, Wyoming, US      12507             US
# 3265    <NA>    Sublette    Sublette, Wyoming, US       2316             US
# 3264    <NA>    Sheridan    Sheridan, Wyoming, US      10008             US
# 3263    <NA>      Platte      Platte, Wyoming, US       2299             US
# 3262    <NA>        Park        Park, Wyoming, US       7713             US
#
#       Deaths   FIPS ISO3  Incident_Rate         Last_Update        Lat  \
# 3271      23  56045  USA    27501.08272 2023-03-10 13:21:02  43.839612
# 3270      51  56043  USA   35297.885971 2023-03-10 13:21:02  43.904516
# 3269       0  90056  USA           <NA> 2023-01-08 23:21:00       <NA>
# 3268      43  56041  USA   31672.105211 2023-03-10 13:21:02  41.287818
# 3267      16  56039  USA   51713.262871 2023-03-10 13:21:02  43.935225
# 3266     139  56037  USA   29537.349739 2023-03-10 13:21:02  41.659439
# 3265      28  56035  USA   23558.132438 2023-03-10 13:21:02  42.765583
# 3264      90  56033  USA   32829.260292 2023-03-10 13:21:02  44.790489
# 3263      44  56031  USA   27391.874181 2023-03-10 13:21:02  42.132991
# 3262     153  56029  USA    26419.81229 2023-03-10 13:21:02  44.521575
#
#            Long_  OBJECTID  People_Hospitalized  People_Tested Province_State  \
# 3271 -104.567488      3272                 <NA>           <NA>        Wyoming
# 3270 -107.680187      3271                 <NA>           <NA>        Wyoming
# 3269        <NA>      3270                 <NA>           <NA>        Wyoming
# 3268 -110.547578      3269                 <NA>           <NA>        Wyoming
# 3267  -110.58908      3268                 <NA>           <NA>        Wyoming
# 3266 -108.882788      3267                 <NA>           <NA>        Wyoming
# 3265 -109.913092      3266                 <NA>           <NA>        Wyoming
# 3264 -106.886239      3265                 <NA>           <NA>        Wyoming
# 3263 -104.966331      3264                 <NA>           <NA>        Wyoming
# 3262 -109.585283      3263                 <NA>           <NA>        Wyoming
#
#       Recovered                                              SHAPE       UID
# 3271       <NA>  {"x": -104.56748809999999, "y": 43.83961191000...  84056045
# 3270       <NA>  {"x": -107.68018699999999, "y": 43.90451606000...  84056043
# 3269       <NA>                                               None  84090056
# 3268       <NA>  {"x": -110.54757819999998, "y": 41.28781830000...  84056041
# 3267       <NA>  {"x": -110.58908009999999, "y": 43.93522482000...  84056039
# 3266       <NA>  {"x": -108.8827882, "y": 41.659438960000045, "...  84056037
# 3265       <NA>  {"x": -109.91309219999994, "y": 42.76558279000...  84056035
# 3264       <NA>  {"x": -106.88623889999997, "y": 44.79048913000...  84056033
# 3263       <NA>  {"x": -104.96633099999997, "y": 42.13299116000...  84056031
# 3262       <NA>  {"x": -109.58528249999995, "y": 44.52157546000...  84056029

# %%
sdf2.sort_values(['Deaths', 'Active'], ascending=[0, 1], na_position='first').head(20)
# Out:
#       OBJECTID Province_State Country_Region         Last_Update        Lat  \
# 211        212     California             US 2023-03-10 13:21:02  34.308284
# 107        108        Arizona             US 2023-03-10 13:21:02  33.348359
# 628        629       Illinois             US 2023-03-10 13:21:02  41.841448
# 1895      1896       New York             US 2023-03-10 13:21:02  40.636182
# 1913      1914       New York             US 2023-03-10 13:21:02  40.710881
# 375        376        Florida             US 2023-03-10 13:21:02  25.611236
# 2761      2762          Texas             US 2023-03-10 13:21:02  29.858649
# 1789      1790         Nevada             US 2023-03-10 13:21:02  36.214589
# 1346      1347       Michigan             US 2023-03-10 13:21:02  42.280984
# 1874      1875       New York             US 2023-03-10 13:21:02  40.852093
# 229        230     California             US 2023-03-10 13:21:02  34.840603
# 222        223     California             US 2023-03-10 13:21:02  33.701475
# 2717      2718          Texas             US 2023-03-10 13:21:02  32.766706
# 226        227     California             US 2023-03-10 13:21:02   33.74315
# 338        339        Florida             US 2023-03-10 13:21:02  26.151847
# 2675      2676          Texas             US 2023-03-10 13:21:02  29.449287
# 2880      2881          Texas             US 2023-03-10 13:21:02  32.771438
# 1902      1903       New York             US 2023-03-10 13:21:02  40.767273
# 382        383        Florida             US 2023-03-10 13:21:02  26.646763
# 2436      2437    Puerto Rico             US 2023-03-10 13:21:02       <NA>
#
#            Long_  Confirmed  Recovered  Deaths  Active          Admin2   FIPS  \
# 211  -118.228241    3710586       <NA>   35545    <NA>     Los Angeles  06037
# 107  -112.491815    1530296       <NA>   18846    <NA>        Maricopa  04013
# 628   -87.816588    1533935       <NA>   15289    <NA>            Cook  17031
# 1895  -73.949356     963672       <NA>   14205    <NA>           Kings  36047
# 1913  -73.816847     904779       <NA>   13415    <NA>          Queens  36081
# 375   -80.551706    1552197       <NA>   12285    <NA>      Miami-Dade  12086
# 2761  -95.393395    1275028       <NA>   11623    <NA>          Harris  48201
# 1789 -115.013024     671243       <NA>    9313    <NA>           Clark  32003
# 1346  -83.281255     537017       <NA>    9107    <NA>           Wayne  26163
# 1874  -73.862828     553117       <NA>    8529    <NA>           Bronx  36005
# 229  -116.177469     745179       <NA>    8170    <NA>  San Bernardino  06071
# 222    -117.7646     788663       <NA>    7971    <NA>          Orange  06059
# 2717  -96.777961     696583       <NA>    7133    <NA>          Dallas  48113
# 226  -115.993358     776620       <NA>    6853    <NA>       Riverside  06065
# 338   -80.487256     774980       <NA>    6770    <NA>         Broward  12011
# 2675  -98.520197     698806       <NA>    6512    <NA>           Bexar  48029
# 2880  -97.291016     687595       <NA>    6387    <NA>         Tarrant  48439
# 1902  -73.971526     596334       <NA>    6168    <NA>        New York  36061
# 382    -80.46536     481679       <NA>    6031    <NA>      Palm Beach  12099
# 2436        <NA>      25651       <NA>    5823    <NA>      Unassigned  72999
#
#                         Combined_Key  Incident_Rate  People_Tested  \
# 211      Los Angeles, California, US   36961.315384           <NA>
# 107            Maricopa, Arizona, US   34117.162875           <NA>
# 628               Cook, Illinois, US   29783.798131           <NA>
# 1895             Kings, New York, US   37644.863887           <NA>
# 1913            Queens, New York, US   40143.567164           <NA>
# 375          Miami-Dade, Florida, US   57130.337807           <NA>
# 2761               Harris, Texas, US   27051.561265           <NA>
# 1789               Clark, Nevada, US    29613.03031           <NA>
# 1346             Wayne, Michigan, US     30698.2107           <NA>
# 1874             Bronx, New York, US   39001.147223           <NA>
# 229   San Bernardino, California, US   34181.190183           <NA>
# 222           Orange, California, US   24834.366809           <NA>
# 2717               Dallas, Texas, US    26430.61169           <NA>
# 226        Riverside, California, US   31435.156439           <NA>
# 338             Broward, Florida, US   39686.026778           <NA>
# 2675                Bexar, Texas, US   34878.321223           <NA>
# 2880              Tarrant, Texas, US    32703.45277           <NA>
# 1902          New York, New York, US   36613.974529           <NA>
# 382          Palm Beach, Florida, US   32181.230249           <NA>
# 2436     Unassigned, Puerto Rico, US           <NA>           <NA>
#
#       People_Hospitalized       UID ISO3  \
# 211                  <NA>  84006037  USA
# 107                  <NA>  84004013  USA
# 628                  <NA>  84017031  USA
# 1895                 <NA>  84036047  USA
# 1913                 <NA>  84036081  USA
# 375                  <NA>  84012086  USA
# 2761                 <NA>  84048201  USA
# 1789                 <NA>  84032003  USA
# 1346                 <NA>  84026163  USA
# 1874                 <NA>  84036005  USA
# 229                  <NA>  84006071  USA
# 222                  <NA>  84006059  USA
# 2717                 <NA>  84048113  USA
# 226                  <NA>  84006065  USA
# 338                  <NA>  84012011  USA
# 2675                 <NA>  84048029  USA
# 2880                 <NA>  84048439  USA
# 1902                 <NA>  84036061  USA
# 382                  <NA>  84012099  USA
# 2436                 <NA>  63072999  PRI
#
#                                                   SHAPE
# 211   {"x": -118.22824109999999, "y": 34.30828379000...
# 107   {"x": -112.49181539999995, "y": 33.34835867000...
# 628   {"x": -87.81658793999998, "y": 41.841448490000...
# 1895  {"x": -73.94935551999998, "y": 40.636182500000...
# 1913  {"x": -73.81684711999998, "y": 40.710881240000...
# 375   {"x": -80.55170586999998, "y": 25.611236200000...
# 2761  {"x": -95.39339520999994, "y": 29.858649390000...
# 1789  {"x": -115.01302409999994, "y": 36.21458855000...
# 1346  {"x": -83.28125499999999, "y": 42.280984050000...
# 1874  {"x": -73.86282754999996, "y": 40.852093010000...
# 229   {"x": -116.17746849999997, "y": 34.84060306000...
# 222   {"x": -117.76459979999998, "y": 33.70147516000...
# 2717  {"x": -96.77796049999995, "y": 32.766705990000...
# 226   {"x": -115.99335779999996, "y": 33.74314981000...
# 338   {"x": -80.48725555999994, "y": 26.151846510000...
# 2675  {"x": -98.52019747999998, "y": 29.449287230000...
# 2880  {"x": -97.29101613999995, "y": 32.771438180000...
# 1902  {"x": -73.97152636999994, "y": 40.767272600000...
# 382   {"x": -80.46536001999993, "y": 26.646762720000...
# 2436                                               None

# %% [markdown]
# Here the first argument represent `list` of DataFrame’s columns, the seconds one denotes sorting order for corresponding column and the last one defines the position where null values will be placed.
#
# And let’s give an example of Series sorting:

# %%
sdf2['Combined_Key'].sort_values()
# Out:
# 2450    Abbeville, South Carolina, US
# 1138            Acadia, Louisiana, US
# 2945           Accomack, Virginia, US
# 568                    Ada, Idaho, US
# 810                   Adair, Iowa, US
#                     ...
# 116                 Yuma, Arizona, US
# 318                Yuma, Colorado, US
# 2914                Zapata, Texas, US
# 2915                Zavala, Texas, US
# 2563        Ziebach, South Dakota, US
# Name: Combined_Key, Length: 3272, dtype: string

# %% [markdown]
# Let’s note that previous pandas versions (before 0.17.0) contain other method for sorting by values: `sort_values(inplace=True)` for Series and `sort_values(by=[“column’s name”])` for DataFrame.
#
# It is important to note that Series has the `nsmallest()` and `nlargest()` methods which return the smallest or largest `n` values. For a large Series this can be much faster than sorting the entire Series and calling `head(n)` on the result.

# %%
sdf2['Deaths'].nlargest(3)
# Out:
# 211    35545
# 107    18846
# 628    15289
# Name: Deaths, dtype: Int32

# %%
sdf2['Deaths'].nsmallest(5)
# Out:
# 52    0
# 64    0
# 73    0
# 93    0
# 95    0
# Name: Deaths, dtype: Int32

# %% [markdown]
# ### Selecting by type
#
# [[back to top]](#Table-of-Contents)
#
# You already know how to see types of each column of a DataFrame (with the help of `dtypes`, for example) and how to change type of any DataFrames’s column or row (by using `astype()` method). But what to do if you need to select a specific column of a certain type? Method `select_dtypes()` makes this issue very easy. Let’s create a DataFrame with data of many different types to demonstrate its work rather than use one of the provided datasets.

# %%
import datetime
types_df = pd.DataFrame({  'int': list(range(3)),
                           'float': [1.1, 2.2, 3.3],
                           'bool': [False, True, False],
                           'string': list('abc'),
                           'undefined': [2>1, pd.isnull(np.inf),isinstance([],list)],
                           'shuffled': [datetime.datetime.now(), [np.nan, np.inf], type('A')],
                           'date': pd.date_range('20151120', periods=3).values
                        })
types_df
# Out:
#    int  float   bool string  undefined                    shuffled       date
# 0    0    1.1  False      a       True  2025-04-16 12:47:49.165862 2015-11-20
# 1    1    2.2   True      b      False                  [nan, inf] 2015-11-21
# 2    2    3.3  False      c       True               <class 'str'> 2015-11-22

# %%
types_df.dtypes
# Out:
# int                   int64
# float               float64
# bool                   bool
# string               object
# undefined              bool
# shuffled             object
# date         datetime64[ns]
# dtype: object

# %% [markdown]
# Pay attention that pandas defines Python type str as type object.
#
# Let’s select only boolean columns

# %%
types_df.select_dtypes(include=['bool'])   
# or types_df.select_dtypes(include=[bool])
# Out:
#     bool  undefined
# 0  False       True
# 1   True      False
# 2  False       True

# %% [markdown]
# or remain all columns which are have no bool or object types

# %%
types_df.select_dtypes(exclude=['bool', 'object']) 
# or types_df.select_dtypes(include=['datetime64[ns]','float64', 'int64'])
# Out:
#    int  float       date
# 0    0    1.1 2015-11-20
# 1    1    2.2 2015-11-21
# 2    2    3.3 2015-11-22
