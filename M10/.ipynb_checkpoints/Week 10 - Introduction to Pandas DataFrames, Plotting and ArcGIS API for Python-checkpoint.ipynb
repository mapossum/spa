# %% [markdown]
# <h1> What is Pandas?</h1>
# <img src='https://media.giphy.com/media/AGl4BWvZNfvby/giphy.gif'>
# <ul>
# <li>Pandas is a package providing fast, flexible, and expressive data structures designed to make working with table (relational and labeled) data both easy and intuitive.</li>
# <li>Data feels like excel spreadsheets, but you can update it and manipulate it using python code.</li>
# </ul>

# %% [markdown]
# <h1> Why use Pandas? </h1>
# <ul>
# <li> Easy handling of missing data</li>
# <li> Size mutabilty (harder with numpy arrays) </li>
# <li> Automatic and explicit data alignment </li>
# <li> Database like query ability </li>
# <li> Powerful, flexible group by functionality </li>
# </ul>

# %% [markdown]
# <h2> Other Reasons? </h2>
# <ul>
# <li> Intelligent label-based slicing</li>
# <li> Fancy Indexing and Subsetting </li>
# <li> Intuitive Merging and Joining data sets </li>
# <li> Database like query ability </li>
# <li> Flexible reshaping and pivoting of data sets </li>
# </ul>

# %% [markdown]
# <h1> The ArcGIS API for Python </h1>
# <h2> A powerful Python library for spatial analysis, mapping and GIS </h2>
# <p>
# <a href='https://developers.arcgis.com/python/' target='_blank'>ArcGIS API for Python </a> is another ESRI Python library (besides arcpy) for working with maps and geospatial data, powered by web GIS. Arcpy installes with ArcGIS for Desktop (ArcGIS Pro).  </p>
# <p> It provides simple and efficient tools for sophisticated vector and raster analysis, geocoding, map making, routing and directions, as well as for organizing and managing a GIS with users, groups and information items. In addition to working with your own data, the library enables access to ready to use maps and curated geographic data from Esri and other authoritative sources. We will introduce these concepts this week, but get into more details next week.
# </p>
# <p>It also integrates well with the scientific Python ecosystem and includes rich support for Pandas and Jupyter notebook. We will cover this this week</p>

# %%
#This loads one of the libraries we are introducing this week, the ArcGIS API for Python explained above
from arcgis import GIS

#This loads arcpy which we can use for running ArcGIS Pro tools and manipulating low level data (e.g. through cursors)
import arcpy

#This libary is for reading web resources using a URL
import urllib.request as rq

#This loads the pandas library which we are also introducing today.
#The basic unit of pandas is a "DataFrame" which you can think of kinda like a speadsheet.
#Read more here: https://pandas.pydata.org/
import pandas as pd

#This little line of code makes to so plots show up inline
#we will talk a little about matplotlib this week and next
#It is a library for plotting
# %matplotlib inline

#This loads a specific part of the ArcGIS API for Python 
#(The features sub module for manipulation of GIS vector data)
#It allows you to create an ESRI specific data frame (called a spatially enabled data frame)
#Read more here: https://developers.arcgis.com/python/guide/introduction-to-the-spatially-enabled-dataframe/
from arcgis.features import GeoAccessor, GeoSeriesAccessor

# %%
#Make an anon connection to ArcGIS Online
gis = GIS()

#Make a secure connection with ArcGIS Online
gis = GIS("https://arcgis.com","graber")

# %% [markdown]
# <h1> A "Series" is a basic structure in pandas </h1>
# <p> A series can be any datatype, but everything in a series is the same datatype</p>

# %%
import numpy as np
data = np.random.randn(10)
data

# %%
series = pd.Series(data)
series
# Out:
# 0    0.846878
# 1   -1.512262
# 2    1.777756
# 3    0.545946
# 4   -1.179268
# 5    0.432614
# 6   -1.666608
# 7   -0.169737
# 8    0.094565
# 9    0.368779
# dtype: float64

# %% [markdown]
# <h1> DataFrames </h1>
# <p> Series are kinda cool, but DataFrames are really useful.  As mentioned above they are 2d data structures that all you to manipulate data in a table.</p>
# <p> Here is an example:</p>

# %%
#DataFrames are built Row by row not column by column.
data1 = np.random.rand(10).tolist()
data2 = np.random.rand(10).tolist()
data3 = np.random.rand(10).tolist()
tdata = np.random.rand(10)
data4 = (tdata * 100).astype(int).tolist()

fields = {0:"red",1:"green", 2:"blue", 3:"height"}
data = [data1,data2,data3,data4]
data, fields
# Out:
# ([[0.5106802523769677,
#    0.24011727747423184,
#    0.3077676376194092,
#    0.8853828173583593,
#    0.44304251684469054,
#    0.26699648577308877,
#    0.6801623308315802,
#    0.5535113772799677,
#    0.32463421807560466,
#    0.12487613829398769],
#   [0.4384351315028141,
#    0.0805462979019026,
#    0.4565087429760404,
#    0.6186613880886188,
#    0.014309553423076493,
#    0.9788014037448128,
#    0.5462162916490129,
#    0.08504793432548263,
#    0.8531568894026206,
#    0.743654194939412],
#   [0.2275488066433825,
#    0.9545022040930271,
#    0.8641501529040524,
#    0.514626591870945,
#    0.21578923654361426,
#    0.20908828882204156,
#    0.11467423645650221,
#    0.6575007804774298,
#    0.4492816057849299,
#    0.6899937750396304],
#   [91, 67, 91, 17, 15, 56, 24, 58, 44, 79]],
#  {0: 'red', 1: 'green', 2: 'blue', 3: 'height'})

# %% [markdown]
# DataFrame Methods can be chained together.  Break down what each method does.

# %%
mydf = pd.DataFrame(data).transpose().rename(columns=fields).astype({'height': 'int32'})
mydf
# Out:
#         red     green      blue  height
# 0  0.510680  0.438435  0.227549      91
# 1  0.240117  0.080546  0.954502      67
# 2  0.307768  0.456509  0.864150      91
# 3  0.885383  0.618661  0.514627      17
# 4  0.443043  0.014310  0.215789      15
# 5  0.266996  0.978801  0.209088      56
# 6  0.680162  0.546216  0.114674      24
# 7  0.553511  0.085048  0.657501      58
# 8  0.324634  0.853157  0.449282      44
# 9  0.124876  0.743654  0.689994      79

# %% [markdown]
# Charting in Pandas is avalible through the matplotlib library

# %%
#Scatter Plot
myplot = mydf.plot.scatter(x='red',y='green',c='DarkBlue')

# %%
#Bar Plot
barchart = mydf.plot.bar(y='height', rot=0)

# %%
#You can create columns and make them equal to functions of other columns
#Use numpy.where to add conditionals
mydf['majority'] = np.where(mydf['red']>mydf['green'], 'red', 'green')
mydf['majority'] = np.where(mydf['blue']>mydf['red'], 'blue', mydf['majority'])
mydf
# Out:
#         red     green      blue  height majority
# 0  0.510680  0.438435  0.227549      91      red
# 1  0.240117  0.080546  0.954502      67     blue
# 2  0.307768  0.456509  0.864150      91     blue
# 3  0.885383  0.618661  0.514627      17      red
# 4  0.443043  0.014310  0.215789      15      red
# 5  0.266996  0.978801  0.209088      56    green
# 6  0.680162  0.546216  0.114674      24      red
# 7  0.553511  0.085048  0.657501      58     blue
# 8  0.324634  0.853157  0.449282      44     blue
# 9  0.124876  0.743654  0.689994      79     blue

# %%
groupedDF = mydf.groupby("majority")['red', 'green', "blue", "height"].mean()
groupedDF
# Out:
#                red     green      blue  height
# majority
# blue      0.310181  0.443783  0.723086   67.80
# green     0.266996  0.978801  0.209088   56.00
# red       0.629817  0.404406  0.268160   36.75

# %%
#Bar Plot of Grouped Data
barchart = groupedDF.plot.bar(y='height', rot=0, color=['blue', 'green', 'red'])

# %%
mydf.describe()
# Out:
#              red      green       blue     height
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.433717   0.481534   0.489716  54.200000
# std     0.229376   0.335964   0.296258  28.754903
# min     0.124876   0.014310   0.114674  15.000000
# 25%     0.277189   0.173395   0.218729  29.000000
# 50%     0.383838   0.501363   0.481954  57.000000
# 75%     0.542804   0.712406   0.681871  76.000000
# max     0.885383   0.978801   0.954502  91.000000

# %%
boxplot = mydf.boxplot(column=['red', 'green', 'blue'])

# %%
print(mydf.columns)
print('*******')
print(mydf.dtypes)
# Out:
# Index(['red', 'green', 'blue', 'height', 'majority'], dtype='object')
# *******
# red         float64
# green       float64
# blue        float64
# height        int32
# majority     object
# dtype: object

# %% [markdown]
# <h2>Accessing Data in a DataFrame</h2>
# <ul>
#     <li>Zero based indexing (like most of Python)</li>
#     <li>Use "iloc" to access a row.</li>
#     <li>Use the ["column name"] to access just a column, like a dictionary. (Think of a Dataframe as a dictionary of columns.)</li>
# </ul>

# %%
mydf[['red', 'green']].iloc[4:7]
# Out:
#         red     green
# 4  0.443043  0.014310
# 5  0.266996  0.978801
# 6  0.680162  0.546216

# %% [markdown]
# <h1>Now let's try with some real geographic data!</h1>

# %%
#Read from URL (Must not be to big)
#url = 'https://data.cityofchicago.org/api/views/ijzp-q8t2/rows.csv?accessType=DOWNLOAD'
#f = rq.urlopen(url)

#Read from file -- Better if Big
f = r"C:\Users\George\Downloads\Crimes_2015_2019.csv"

#This is how to read a CSV into Pandas Data Frame that ArcGIS can read
#then fill any missing values with a value of your choice
#Finally convert the dataFrame into a spatial Data Frame (ArcGIS API for Python)
chiCrimedata = pd.read_csv(f).fillna(0)
sdfchiCrimedata = pd.DataFrame.spatial.from_xy(chiCrimedata, "Latitude", "Longitude", sr=4326)

# %%
sdfchiCrimedata.head()
# Out:
#          ID Case Number                    Date                    Block  \
# 0  10183157    HY370946  08/06/2015 02:13:00 AM  033XX W WASHINGTON BLVD
# 1  11885231    JC502478  04/24/2015 09:00:00 AM   014XX W WELLINGTON AVE
# 2  11885599    JC501907  05/31/2015 12:00:00 AM     002XX S LAVERGNE AVE
# 3  10158068    HY347630  07/20/2015 01:10:00 AM       044XX N KEDZIE AVE
# 4  11883609    JC500009  12/26/2015 12:01:00 AM    050XX S WASHTENAW AVE
#
#    IUCR         Primary Type                              Description  \
# 0  0330              ROBBERY                               AGGRAVATED
# 1  1585          SEX OFFENSE                                    OTHER
# 2  1154   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  041A              BATTERY                      AGGRAVATED: HANDGUN
# 4  0266  CRIM SEXUAL ASSAULT                                PREDATORY
#
#         Location Description  Arrest  Domestic  ...  Community Area  FBI Code  \
# 0                     STREET    True     False  ...            27.0        03
# 1  SCHOOL, PRIVATE, BUILDING   False     False  ...             6.0        17
# 2                  RESIDENCE   False     False  ...            25.0        11
# 3                   SIDEWALK    True     False  ...            14.0       04B
# 4                  RESIDENCE   False      True  ...            63.0        02
#
#    X Coordinate  Y Coordinate  Year              Updated On   Latitude  \
# 0     1154099.0     1900484.0  2015  11/09/2019 03:52:30 PM  41.882757
# 1           0.0           0.0  2015  11/08/2019 03:49:29 PM   0.000000
# 2           0.0           0.0  2015  11/08/2019 03:49:29 PM   0.000000
# 3     1154257.0     1929142.0  2015  11/08/2019 03:45:49 PM  41.961394
# 4           0.0           0.0  2015  11/07/2019 03:51:53 PM   0.000000
#
#    Longitude                       Location  \
# 0 -87.709603  (41.882757453, -87.709603286)
# 1   0.000000                              0
# 2   0.000000                              0
# 3 -87.708256   (41.96139421, -87.708256028)
# 4   0.000000                              0
#
#                                                SHAPE
# 0  {"x": 41.882757453, "y": -87.709603286, "spati...
# 1  {"x": 0.0, "y": 0.0, "spatialReference": {"wki...
# 2  {"x": 0.0, "y": 0.0, "spatialReference": {"wki...
# 3  {"x": 41.96139421, "y": -87.708256028, "spatia...
# 4  {"x": 0.0, "y": 0.0, "spatialReference": {"wki...
#
# [5 rows x 23 columns]

# %%
sdfchiCrimedata

# %%
m1 = GIS().map('United States')
m1

# %%
sdfchiCrimedataq = sdfchiCrimedata.query('Year == 2019')
sdf1 = sdfchiCrimedataq.groupby('Primary Type')['Latitude', 'Longitude'].mean()
sdf2 = sdfchiCrimedataq.groupby('Primary Type')['ID'].count()

# %%
dfGrouped = pd.merge(sdf2, sdf1, on=['Primary Type'])
dfGrouped.rename(columns={"ID": "Count"}, inplace = True)
sdfGrouped = pd.DataFrame.spatial.from_xy(dfGrouped, "Latitude", "Longitude", sr=4326)
sdfGroupedSorted = sdfGrouped.sort_values(by=['Count'])
sdfGroupedSorted
# Out:
#                                    Count   Latitude  Longitude  \
# Primary Type
# NON-CRIMINAL                           3  41.901688 -87.755989
# OTHER NARCOTIC VIOLATION               4  41.911039 -87.699233
# PUBLIC INDECENCY                       9  41.831162 -87.697129
# HUMAN TRAFFICKING                     11  41.818443 -87.673364
# OBSCENITY                             44  41.882106 -87.680960
# KIDNAPPING                           136  41.826202 -87.666576
# GAMBLING                             136  41.839967 -87.689953
# INTIMIDATION                         147  41.563137 -87.079563
# STALKING                             188  41.845502 -87.673037
# CONCEALED CARRY LICENSE VIOLATION    191  41.828852 -87.706095
# LIQUOR LAW VIOLATION                 206  41.864121 -87.667749
# ARSON                                310  41.698546 -87.398076
# HOMICIDE                             438  41.720260 -87.471257
# PROSTITUTION                         564  41.845235 -87.714374
# SEX OFFENSE                         1043  41.809189 -87.588144
# INTERFERENCE WITH PUBLIC OFFICER    1343  41.775955 -87.591480
# PUBLIC PEACE VIOLATION              1345  41.780837 -87.547090
# CRIM SEXUAL ASSAULT                 1349  41.789611 -87.538418
# OFFENSE INVOLVING CHILDREN          1963  41.756335 -87.533965
# WEAPONS VIOLATION                   5396  41.806509 -87.664842
# CRIMINAL TRESPASS                   5815  41.760278 -87.485982
