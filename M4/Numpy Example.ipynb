# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np

fc = r"C:\temp\LabData.gdb\watersheds"

import arcpy
array = arcpy.da.FeatureClassToNumPyArray(fc, ["*"])

print(array["HUC_8"])

plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
watersheds = array["HUC_8"]
y_pos = np.arange(len(watersheds))
areatot = array["Shape_Area"]
ax.barh(y_pos, areatot, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(watersheds)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Watershed Area')
ax.set_title('Area of the Watershed of South Mississippi')

plt.show()

array
# Out:
# ['03170006' '03170007' '03170008' '03170009' '03180004']
# <img src="data:image/png;base64,..." width="640">
# array([(1, [ 603649.7068262 , 1102783.86327908], '03170006', 363697.09081272, 1.58048969e+09),
#        (2, [ 554338.83267348, 1133863.97609093], '03170007', 453311.07532189, 3.28144686e+09),
#        (3, [ 630340.48626172, 1125688.20743829], '03170008', 454950.4980818 , 2.70498723e+09),
#        (4, [ 568102.54200175, 1074819.20818689], '03170009', 647109.08817334, 6.34009829e+09),
#        (5, [ 499526.60517083, 1117821.67051574], '03180004', 491667.75669009, 4.71620424e+09)],
#       dtype=[('OBJECTID', '<i4'), ('Shape', '<f8', (2,)), ('HUC_8', '<U8'), ('Shape_Length', '<f8'), ('Shape_Area', '<f8')])
